# %%
# %load_ext autoreload
# %autoreload 2
#Reloads import libraries before every piece of code is run so that changes in function.py reflect immediately


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import time
import random
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

#import functions

from dataset_import import prepareFMNISTData, prepareRailwayData, prepareMedicalData
from distance_metrics import euclideanDistance, manhattenDistance, chebyschevDistance
from PCA import PCA, project
from evaluation_metrics import accuracy, precision, recall, f1Score
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Assignment
# Algorithms to implement:
# - Linear Models:
# - Logistic Models
# - Perceptron
# - FLDA
# - Multi-Class Discriminative Models
# - Support Vector Machines

# %% [markdown]
# # Linear Models
# We'll try to find an aribitrary hyperplane that works for linearly seperable data
#
# ##### Kernel:
#     - Can project data onto a greater polynomial space
#     - Can also try to reduce the data to a small dimensional subspace [PCA]
# ##### Training:
#     - Solve Normal Equations of W*
#     - Search for W* using Gradient Descent
#     - Search for W* using Perceptron algorithm
# ##### Expectation:
#     - When data is projected upward onto a very large polynomial superspace, the data will become linearly seperable and hence we'll be able to find a good hyperplane : Overfitting
#     - When data is projected inward onto a very small subspace, there is no linear seperability and these algos stop working

# %% [markdown]
# # Adaptations
# When the data isn't perfectly linearly seperable, say there is a region in between that contains both classes, then we need quantifications of linear seperability, and updates in our algorithms.
# ##### Logistic Models
#     - Sigmoid of WX is the cost of misclassification, rather than 1 as for linear model (under both 0-1 and MS loss)
#     VERIFY
#     - Works best when class-conditional densities are gaussians
#     - reduces to a linear model for linearly seperable data
#
# ##### Fischer Discriminant Analysis
#     - Is another way of choosing the classifying hyperplane. This method tries to maximize the projected intra-class variance with respect to the projected inter-class variance.
#
# ##### Support Vector Machines
#     - Choose that hyper plane that maximizes distance from points, and also seperates them.

# %%
def gradientDescent(x, y, W, alpha, numIterations):
    m = x.shape[0]
    for i in range(0, numIterations):
        hypothesis = np.dot(x, W)
        loss = hypothesis - y
        cost = np.sum(loss ** 2) / (2 * m)
        print("Iteration %d | Cost: %f" % (i, cost))
        # avg gradient per example
        gradient = np.dot(x.transpose(), loss) / m
        # update
        W = W - alpha * gradient
    return W    
    
    
    
def genData(numPoints, bias, variance):
    x = np.zeros(shape=(numPoints, 2))
    y = np.zeros(shape=numPoints)
    # basically a straight line with added noise
    for i in range(0, numPoints):
        x[i][0] = 1
        x[i][1] = i
        y[i] = (i + bias) + random.uniform(0, 1) * variance
    return x, y

x, y = genData(100, 25, 10)
m, n = np.shape(x)
numIterations= 10000
alpha = 0.0005
W = np.ones(n)
W = gradientDescent(x, y, W, alpha, numIterations)
print(W)
# Out:
# Iteration 0 | Cost: 418.903804
# Iteration 1 | Cost: 234.676136
# Iteration 2 | Cost: 158.699909
# Iteration 3 | Cost: 127.358150
# Iteration 4 | Cost: 114.420175
# Iteration 5 | Cost: 109.070490
# Iteration 6 | Cost: 106.849630
# Iteration 7 | Cost: 105.918856
# Iteration 8 | Cost: 105.520018
# Iteration 9 | Cost: 105.340513
# Iteration 10 | Cost: 105.251447
# Iteration 11 | Cost: 105.199675
# Iteration 12 | Cost: 105.163284
# Iteration 13 | Cost: 105.133239
# Iteration 14 | Cost: 105.105814
# Iteration 15 | Cost: 105.079474
# Iteration 16 | Cost: 105.053584
# Iteration 17 | Cost: 105.027884
# Iteration 18 | Cost: 105.002266
# Iteration 19 | Cost: 104.976685
# Iteration 20 | Cost: 104.951124
# Iteration 21 | Cost: 104.925575
# Iteration 22 | Cost: 104.900034
# Iteration 23 | Cost: 104.874501
# Iteration 24 | Cost: 104.848974
# Iteration 25 | Cost: 104.823455
# Iteration 26 | Cost: 104.797941
# Iteration 27 | Cost: 104.772435
# Iteration 28 | Cost: 104.746934
# Iteration 29 | Cost: 104.721441
# Iteration 30 | Cost: 104.695953
# Iteration 31 | Cost: 104.670472
# Iteration 32 | Cost: 104.644998
# Iteration 33 | Cost: 104.619530
# Iteration 34 | Cost: 104.594068
# Iteration 35 | Cost: 104.568613
# Iteration 36 | Cost: 104.543165
# Iteration 37 | Cost: 104.517723
# Iteration 38 | Cost: 104.492287
# Iteration 39 | Cost: 104.466858
# Iteration 40 | Cost: 104.441435
# Iteration 41 | Cost: 104.416019
# Iteration 42 | Cost: 104.390609
# Iteration 43 | Cost: 104.365206
# Iteration 44 | Cost: 104.339809
# Iteration 45 | Cost: 104.314418
# Iteration 46 | Cost: 104.289034
# Iteration 47 | Cost: 104.263656
# Iteration 48 | Cost: 104.238285
# Iteration 49 | Cost: 104.212921
# Iteration 50 | Cost: 104.187562
# Iteration 51 | Cost: 104.162210
# Iteration 52 | Cost: 104.136865
# Iteration 53 | Cost: 104.111526
# Iteration 54 | Cost: 104.086193
# Iteration 55 | Cost: 104.060867
# Iteration 56 | Cost: 104.035547
# Iteration 57 | Cost: 104.010234
# Iteration 58 | Cost: 103.984927
# Iteration 59 | Cost: 103.959627
# Iteration 60 | Cost: 103.934333
# Iteration 61 | Cost: 103.909045
# Iteration 62 | Cost: 103.883764
# Iteration 63 | Cost: 103.858489
# Iteration 64 | Cost: 103.833220
# Iteration 65 | Cost: 103.807958
# Iteration 66 | Cost: 103.782703
# Iteration 67 | Cost: 103.757454
# Iteration 68 | Cost: 103.732211
# Iteration 69 | Cost: 103.706975
# Iteration 70 | Cost: 103.681745
# Iteration 71 | Cost: 103.656521
# Iteration 72 | Cost: 103.631304
# Iteration 73 | Cost: 103.606093
# Iteration 74 | Cost: 103.580889
# Iteration 75 | Cost: 103.555691
# Iteration 76 | Cost: 103.530499
# Iteration 77 | Cost: 103.505314
# Iteration 78 | Cost: 103.480135
# Iteration 79 | Cost: 103.454963
# Iteration 80 | Cost: 103.429797
# Iteration 81 | Cost: 103.404637
# Iteration 82 | Cost: 103.379484
# Iteration 83 | Cost: 103.354337
# Iteration 84 | Cost: 103.329196
# Iteration 85 | Cost: 103.304062
# Iteration 86 | Cost: 103.278934
# Iteration 87 | Cost: 103.253813
# Iteration 88 | Cost: 103.228698
# Iteration 89 | Cost: 103.203589
# Iteration 90 | Cost: 103.178487
# Iteration 91 | Cost: 103.153391
# Iteration 92 | Cost: 103.128302
# Iteration 93 | Cost: 103.103219
# Iteration 94 | Cost: 103.078142
# Iteration 95 | Cost: 103.053071
# Iteration 96 | Cost: 103.028007
# Iteration 97 | Cost: 103.002950
# Iteration 98 | Cost: 102.977898
# Iteration 99 | Cost: 102.952853
# Iteration 100 | Cost: 102.927815
# Iteration 101 | Cost: 102.902782
# Iteration 102 | Cost: 102.877756
# Iteration 103 | Cost: 102.852737
# Iteration 104 | Cost: 102.827723
# Iteration 105 | Cost: 102.802717
# Iteration 106 | Cost: 102.777716
# Iteration 107 | Cost: 102.752722
# Iteration 108 | Cost: 102.727734
# Iteration 109 | Cost: 102.702752
# Iteration 110 | Cost: 102.677777
# Iteration 111 | Cost: 102.652808
# Iteration 112 | Cost: 102.627846
# Iteration 113 | Cost: 102.602890
# Iteration 114 | Cost: 102.577940
# Iteration 115 | Cost: 102.552996
# Iteration 116 | Cost: 102.528059
# Iteration 117 | Cost: 102.503128
# Iteration 118 | Cost: 102.478204
# Iteration 119 | Cost: 102.453285
# Iteration 120 | Cost: 102.428373
# Iteration 121 | Cost: 102.403468
# Iteration 122 | Cost: 102.378569
# Iteration 123 | Cost: 102.353676
# Iteration 124 | Cost: 102.328789
# Iteration 125 | Cost: 102.303909
# Iteration 126 | Cost: 102.279035
# Iteration 127 | Cost: 102.254167
# Iteration 128 | Cost: 102.229305
# Iteration 129 | Cost: 102.204450
# Iteration 130 | Cost: 102.179602
# Iteration 131 | Cost: 102.154759
# Iteration 132 | Cost: 102.129923
# Iteration 133 | Cost: 102.105093
# Iteration 134 | Cost: 102.080269
# Iteration 135 | Cost: 102.055452
# Iteration 136 | Cost: 102.030641
# Iteration 137 | Cost: 102.005837
# Iteration 138 | Cost: 101.981038
# Iteration 139 | Cost: 101.956246
# Iteration 140 | Cost: 101.931460
# Iteration 141 | Cost: 101.906681
# Iteration 142 | Cost: 101.881907
# Iteration 143 | Cost: 101.857140
# Iteration 144 | Cost: 101.832380
# Iteration 145 | Cost: 101.807625
# Iteration 146 | Cost: 101.782877
# Iteration 147 | Cost: 101.758135
# Iteration 148 | Cost: 101.733400
# Iteration 149 | Cost: 101.708671
# Iteration 150 | Cost: 101.683948
# Iteration 151 | Cost: 101.659231
# Iteration 152 | Cost: 101.634520
# Iteration 153 | Cost: 101.609816
# Iteration 154 | Cost: 101.585118
# Iteration 155 | Cost: 101.560427
# Iteration 156 | Cost: 101.535741
# Iteration 157 | Cost: 101.511062
# Iteration 158 | Cost: 101.486389
# Iteration 159 | Cost: 101.461723
# Iteration 160 | Cost: 101.437062
# Iteration 161 | Cost: 101.412408
# Iteration 162 | Cost: 101.387760
# Iteration 163 | Cost: 101.363119
# Iteration 164 | Cost: 101.338483
# Iteration 165 | Cost: 101.313854
# Iteration 166 | Cost: 101.289231
# Iteration 167 | Cost: 101.264615
# Iteration 168 | Cost: 101.240004
# Iteration 169 | Cost: 101.215400
# Iteration 170 | Cost: 101.190802
# Iteration 171 | Cost: 101.166211
# Iteration 172 | Cost: 101.141625
# Iteration 173 | Cost: 101.117046
# Iteration 174 | Cost: 101.092473
# Iteration 175 | Cost: 101.067907
# Iteration 176 | Cost: 101.043346
# Iteration 177 | Cost: 101.018792
# Iteration 178 | Cost: 100.994244
# Iteration 179 | Cost: 100.969702
# Iteration 180 | Cost: 100.945167
# Iteration 181 | Cost: 100.920637
# Iteration 182 | Cost: 100.896114
# Iteration 183 | Cost: 100.871598
# Iteration 184 | Cost: 100.847087
# Iteration 185 | Cost: 100.822582
# Iteration 186 | Cost: 100.798084
# Iteration 187 | Cost: 100.773592
# Iteration 188 | Cost: 100.749106
# Iteration 189 | Cost: 100.724627
# Iteration 190 | Cost: 100.700154
# Iteration 191 | Cost: 100.675686
# Iteration 192 | Cost: 100.651225
# Iteration 193 | Cost: 100.626771
# Iteration 194 | Cost: 100.602322
# Iteration 195 | Cost: 100.577880
# Iteration 196 | Cost: 100.553444
# Iteration 197 | Cost: 100.529014
# Iteration 198 | Cost: 100.504590
# Iteration 199 | Cost: 100.480172
# Iteration 200 | Cost: 100.455761
# Iteration 201 | Cost: 100.431356
# Iteration 202 | Cost: 100.406957
# Iteration 203 | Cost: 100.382564
# Iteration 204 | Cost: 100.358178
# Iteration 205 | Cost: 100.333797
# Iteration 206 | Cost: 100.309423
# Iteration 207 | Cost: 100.285055
# Iteration 208 | Cost: 100.260693
# Iteration 209 | Cost: 100.236338
# Iteration 210 | Cost: 100.211988
# Iteration 211 | Cost: 100.187645
# Iteration 212 | Cost: 100.163308
# Iteration 213 | Cost: 100.138977
# Iteration 214 | Cost: 100.114652
# Iteration 215 | Cost: 100.090333
# Iteration 216 | Cost: 100.066021
# Iteration 217 | Cost: 100.041715
# Iteration 218 | Cost: 100.017414
# Iteration 219 | Cost: 99.993120
# Iteration 220 | Cost: 99.968833
# Iteration 221 | Cost: 99.944551
# Iteration 222 | Cost: 99.920276
# Iteration 223 | Cost: 99.896006
# Iteration 224 | Cost: 99.871743
# Iteration 225 | Cost: 99.847486
# Iteration 226 | Cost: 99.823235
# Iteration 227 | Cost: 99.798991
# Iteration 228 | Cost: 99.774752
# Iteration 229 | Cost: 99.750520
# Iteration 230 | Cost: 99.726294
# Iteration 231 | Cost: 99.702073
# Iteration 232 | Cost: 99.677860
# Iteration 233 | Cost: 99.653652
# Iteration 234 | Cost: 99.629450
# Iteration 235 | Cost: 99.605255
# Iteration 236 | Cost: 99.581065
# Iteration 237 | Cost: 99.556882
# Iteration 238 | Cost: 99.532705
# Iteration 239 | Cost: 99.508534
# Iteration 240 | Cost: 99.484369
# Iteration 241 | Cost: 99.460210
# Iteration 242 | Cost: 99.436058
# Iteration 243 | Cost: 99.411911
# Iteration 244 | Cost: 99.387771
# Iteration 245 | Cost: 99.363637
# Iteration 246 | Cost: 99.339509
# Iteration 247 | Cost: 99.315387
# Iteration 248 | Cost: 99.291271
# Iteration 249 | Cost: 99.267161
# Iteration 250 | Cost: 99.243057
# Iteration 251 | Cost: 99.218960
# Iteration 252 | Cost: 99.194869
# Iteration 253 | Cost: 99.170783
# Iteration 254 | Cost: 99.146704
# Iteration 255 | Cost: 99.122631
# Iteration 256 | Cost: 99.098564
# Iteration 257 | Cost: 99.074503
# Iteration 258 | Cost: 99.050449
# Iteration 259 | Cost: 99.026400
# Iteration 260 | Cost: 99.002357
# Iteration 261 | Cost: 98.978321
# Iteration 262 | Cost: 98.954291
# Iteration 263 | Cost: 98.930266
# Iteration 264 | Cost: 98.906248
# Iteration 265 | Cost: 98.882236
# Iteration 266 | Cost: 98.858230
# Iteration 267 | Cost: 98.834230
# Iteration 268 | Cost: 98.810237
# Iteration 269 | Cost: 98.786249
# Iteration 270 | Cost: 98.762267
# Iteration 271 | Cost: 98.738292
# Iteration 272 | Cost: 98.714322
# Iteration 273 | Cost: 98.690359
# Iteration 274 | Cost: 98.666402
# Iteration 275 | Cost: 98.642451
# Iteration 276 | Cost: 98.618505
# Iteration 277 | Cost: 98.594566
# Iteration 278 | Cost: 98.570633
# Iteration 279 | Cost: 98.546707
# Iteration 280 | Cost: 98.522786
# Iteration 281 | Cost: 98.498871
# Iteration 282 | Cost: 98.474962
# Iteration 283 | Cost: 98.451060
# Iteration 284 | Cost: 98.427163
# Iteration 285 | Cost: 98.403273
# Iteration 286 | Cost: 98.379388
# Iteration 287 | Cost: 98.355510
# Iteration 288 | Cost: 98.331637
# Iteration 289 | Cost: 98.307771
# Iteration 290 | Cost: 98.283911
# Iteration 291 | Cost: 98.260057
# Iteration 292 | Cost: 98.236209
# Iteration 293 | Cost: 98.212367
# Iteration 294 | Cost: 98.188531
# Iteration 295 | Cost: 98.164701
# Iteration 296 | Cost: 98.140877
# Iteration 297 | Cost: 98.117059
# Iteration 298 | Cost: 98.093247
# Iteration 299 | Cost: 98.069441
# Iteration 300 | Cost: 98.045641
# Iteration 301 | Cost: 98.021848
# Iteration 302 | Cost: 97.998060
# Iteration 303 | Cost: 97.974278
# Iteration 304 | Cost: 97.950503
# Iteration 305 | Cost: 97.926733
# Iteration 306 | Cost: 97.902970
# Iteration 307 | Cost: 97.879212
# Iteration 308 | Cost: 97.855461
# Iteration 309 | Cost: 97.831715
# Iteration 310 | Cost: 97.807976
# Iteration 311 | Cost: 97.784242
# Iteration 312 | Cost: 97.760515
# Iteration 313 | Cost: 97.736793
# Iteration 314 | Cost: 97.713078
# Iteration 315 | Cost: 97.689369
# Iteration 316 | Cost: 97.665665
# Iteration 317 | Cost: 97.641968
# Iteration 318 | Cost: 97.618277
# Iteration 319 | Cost: 97.594592
# Iteration 320 | Cost: 97.570912
# Iteration 321 | Cost: 97.547239
# Iteration 322 | Cost: 97.523572
# Iteration 323 | Cost: 97.499910
# Iteration 324 | Cost: 97.476255
# Iteration 325 | Cost: 97.452606
# Iteration 326 | Cost: 97.428963
# Iteration 327 | Cost: 97.405325
# Iteration 328 | Cost: 97.381694
# Iteration 329 | Cost: 97.358069
# Iteration 330 | Cost: 97.334450
# Iteration 331 | Cost: 97.310836
# Iteration 332 | Cost: 97.287229
# Iteration 333 | Cost: 97.263628
# Iteration 334 | Cost: 97.240032
# Iteration 335 | Cost: 97.216443
# Iteration 336 | Cost: 97.192860
# Iteration 337 | Cost: 97.169282
# Iteration 338 | Cost: 97.145711
# Iteration 339 | Cost: 97.122145
# Iteration 340 | Cost: 97.098586
# Iteration 341 | Cost: 97.075033
# Iteration 342 | Cost: 97.051485
# Iteration 343 | Cost: 97.027944
# Iteration 344 | Cost: 97.004408
# Iteration 345 | Cost: 96.980879
# Iteration 346 | Cost: 96.957355
# Iteration 347 | Cost: 96.933837
# Iteration 348 | Cost: 96.910326
# Iteration 349 | Cost: 96.886820
# Iteration 350 | Cost: 96.863320
# Iteration 351 | Cost: 96.839826
# Iteration 352 | Cost: 96.816339
# Iteration 353 | Cost: 96.792857
# Iteration 354 | Cost: 96.769381
# Iteration 355 | Cost: 96.745911
# Iteration 356 | Cost: 96.722447
# Iteration 357 | Cost: 96.698989
# Iteration 358 | Cost: 96.675537
# Iteration 359 | Cost: 96.652091
# Iteration 360 | Cost: 96.628651
# Iteration 361 | Cost: 96.605216
# Iteration 362 | Cost: 96.581788
# Iteration 363 | Cost: 96.558366
# Iteration 364 | Cost: 96.534949
# Iteration 365 | Cost: 96.511539
# Iteration 366 | Cost: 96.488134
# Iteration 367 | Cost: 96.464736
# Iteration 368 | Cost: 96.441343
# Iteration 369 | Cost: 96.417956
# Iteration 370 | Cost: 96.394576
# Iteration 371 | Cost: 96.371201
# Iteration 372 | Cost: 96.347832
# Iteration 373 | Cost: 96.324469
# Iteration 374 | Cost: 96.301112
# Iteration 375 | Cost: 96.277761
# Iteration 376 | Cost: 96.254415
# Iteration 377 | Cost: 96.231076
# Iteration 378 | Cost: 96.207743
# Iteration 379 | Cost: 96.184415
# Iteration 380 | Cost: 96.161094
# Iteration 381 | Cost: 96.137778
# Iteration 382 | Cost: 96.114469
# Iteration 383 | Cost: 96.091165
# Iteration 384 | Cost: 96.067867
# Iteration 385 | Cost: 96.044575
# Iteration 386 | Cost: 96.021289
# Iteration 387 | Cost: 95.998009
# Iteration 388 | Cost: 95.974734
# Iteration 389 | Cost: 95.951466
# Iteration 390 | Cost: 95.928204
# Iteration 391 | Cost: 95.904947
# Iteration 392 | Cost: 95.881697
# Iteration 393 | Cost: 95.858452
# Iteration 394 | Cost: 95.835213
# Iteration 395 | Cost: 95.811980
# Iteration 396 | Cost: 95.788753
# Iteration 397 | Cost: 95.765532
# Iteration 398 | Cost: 95.742317
# Iteration 399 | Cost: 95.719107
# Iteration 400 | Cost: 95.695904
# Iteration 401 | Cost: 95.672706
# Iteration 402 | Cost: 95.649514
# Iteration 403 | Cost: 95.626329
# Iteration 404 | Cost: 95.603149
# Iteration 405 | Cost: 95.579975
# Iteration 406 | Cost: 95.556806
# Iteration 407 | Cost: 95.533644
# Iteration 408 | Cost: 95.510488
# Iteration 409 | Cost: 95.487337
# Iteration 410 | Cost: 95.464192
# Iteration 411 | Cost: 95.441054
# Iteration 412 | Cost: 95.417921
# Iteration 413 | Cost: 95.394794
# Iteration 414 | Cost: 95.371672
# Iteration 415 | Cost: 95.348557
# Iteration 416 | Cost: 95.325448
# Iteration 417 | Cost: 95.302344
# Iteration 418 | Cost: 95.279246
# Iteration 419 | Cost: 95.256154
# Iteration 420 | Cost: 95.233068
# Iteration 421 | Cost: 95.209988
# Iteration 422 | Cost: 95.186914
# Iteration 423 | Cost: 95.163845
# Iteration 424 | Cost: 95.140783
# Iteration 425 | Cost: 95.117726
# Iteration 426 | Cost: 95.094675
# Iteration 427 | Cost: 95.071630
# Iteration 428 | Cost: 95.048591
# Iteration 429 | Cost: 95.025557
# Iteration 430 | Cost: 95.002530
# Iteration 431 | Cost: 94.979508
# Iteration 432 | Cost: 94.956492
# Iteration 433 | Cost: 94.933482
# Iteration 434 | Cost: 94.910478
# Iteration 435 | Cost: 94.887480
# Iteration 436 | Cost: 94.864487
# Iteration 437 | Cost: 94.841500
# Iteration 438 | Cost: 94.818520
# Iteration 439 | Cost: 94.795545
# Iteration 440 | Cost: 94.772575
# Iteration 441 | Cost: 94.749612
# Iteration 442 | Cost: 94.726655
# Iteration 443 | Cost: 94.703703
# Iteration 444 | Cost: 94.680757
# Iteration 445 | Cost: 94.657817
# Iteration 446 | Cost: 94.634883
# Iteration 447 | Cost: 94.611954
# Iteration 448 | Cost: 94.589032
# Iteration 449 | Cost: 94.566115
# Iteration 450 | Cost: 94.543204
# Iteration 451 | Cost: 94.520299
# Iteration 452 | Cost: 94.497399
# Iteration 453 | Cost: 94.474506
# Iteration 454 | Cost: 94.451618
# Iteration 455 | Cost: 94.428736
# Iteration 456 | Cost: 94.405860
# Iteration 457 | Cost: 94.382990
# Iteration 458 | Cost: 94.360125
# Iteration 459 | Cost: 94.337266
# Iteration 460 | Cost: 94.314414
# Iteration 461 | Cost: 94.291566
# Iteration 462 | Cost: 94.268725
# Iteration 463 | Cost: 94.245890
# Iteration 464 | Cost: 94.223060
# Iteration 465 | Cost: 94.200236
# Iteration 466 | Cost: 94.177418
# Iteration 467 | Cost: 94.154605
# Iteration 468 | Cost: 94.131799
# Iteration 469 | Cost: 94.108998
# Iteration 470 | Cost: 94.086203
# Iteration 471 | Cost: 94.063414
# Iteration 472 | Cost: 94.040630
# Iteration 473 | Cost: 94.017853
# Iteration 474 | Cost: 93.995081
# Iteration 475 | Cost: 93.972315
# Iteration 476 | Cost: 93.949554
# Iteration 477 | Cost: 93.926800
# Iteration 478 | Cost: 93.904051
# Iteration 479 | Cost: 93.881308
# Iteration 480 | Cost: 93.858571
# Iteration 481 | Cost: 93.835839
# Iteration 482 | Cost: 93.813114
# Iteration 483 | Cost: 93.790394
# Iteration 484 | Cost: 93.767679
# Iteration 485 | Cost: 93.744971
# Iteration 486 | Cost: 93.722268
# Iteration 487 | Cost: 93.699571
# Iteration 488 | Cost: 93.676880
# Iteration 489 | Cost: 93.654195
# Iteration 490 | Cost: 93.631515
# Iteration 491 | Cost: 93.608841
# Iteration 492 | Cost: 93.586173
# Iteration 493 | Cost: 93.563511
# Iteration 494 | Cost: 93.540854
# Iteration 495 | Cost: 93.518203
# Iteration 496 | Cost: 93.495558
# Iteration 497 | Cost: 93.472919
# Iteration 498 | Cost: 93.450285
# Iteration 499 | Cost: 93.427657
# Iteration 500 | Cost: 93.405035
# Iteration 501 | Cost: 93.382419
# Iteration 502 | Cost: 93.359808
# Iteration 503 | Cost: 93.337203
# Iteration 504 | Cost: 93.314604
# Iteration 505 | Cost: 93.292011
# Iteration 506 | Cost: 93.269423
# Iteration 507 | Cost: 93.246841
# Iteration 508 | Cost: 93.224265
# Iteration 509 | Cost: 93.201694
# Iteration 510 | Cost: 93.179129
# Iteration 511 | Cost: 93.156570
# Iteration 512 | Cost: 93.134017
# Iteration 513 | Cost: 93.111469
# Iteration 514 | Cost: 93.088927
# Iteration 515 | Cost: 93.066391
# Iteration 516 | Cost: 93.043860
# Iteration 517 | Cost: 93.021336
# Iteration 518 | Cost: 92.998816
# Iteration 519 | Cost: 92.976303
# Iteration 520 | Cost: 92.953795
# Iteration 521 | Cost: 92.931294
# Iteration 522 | Cost: 92.908797
# Iteration 523 | Cost: 92.886307
# Iteration 524 | Cost: 92.863822
# Iteration 525 | Cost: 92.841343
# Iteration 526 | Cost: 92.818869
# Iteration 527 | Cost: 92.796402
# Iteration 528 | Cost: 92.773940
# Iteration 529 | Cost: 92.751483
# Iteration 530 | Cost: 92.729033
# Iteration 531 | Cost: 92.706588
# Iteration 532 | Cost: 92.684149
# Iteration 533 | Cost: 92.661715
# Iteration 534 | Cost: 92.639287
# Iteration 535 | Cost: 92.616865
# Iteration 536 | Cost: 92.594449
# Iteration 537 | Cost: 92.572038
# Iteration 538 | Cost: 92.549633
# Iteration 539 | Cost: 92.527233
# Iteration 540 | Cost: 92.504840
# Iteration 541 | Cost: 92.482452
# Iteration 542 | Cost: 92.460069
# Iteration 543 | Cost: 92.437693
# Iteration 544 | Cost: 92.415322
# Iteration 545 | Cost: 92.392956
# Iteration 546 | Cost: 92.370597
# Iteration 547 | Cost: 92.348243
# Iteration 548 | Cost: 92.325894
# Iteration 549 | Cost: 92.303552
# Iteration 550 | Cost: 92.281215
# Iteration 551 | Cost: 92.258883
# Iteration 552 | Cost: 92.236558
# Iteration 553 | Cost: 92.214238
# Iteration 554 | Cost: 92.191923
# Iteration 555 | Cost: 92.169615
# Iteration 556 | Cost: 92.147312
# Iteration 557 | Cost: 92.125014
# Iteration 558 | Cost: 92.102723
# Iteration 559 | Cost: 92.080437
# Iteration 560 | Cost: 92.058156
# Iteration 561 | Cost: 92.035882
# Iteration 562 | Cost: 92.013613
# Iteration 563 | Cost: 91.991349
# Iteration 564 | Cost: 91.969091
# Iteration 565 | Cost: 91.946839
# Iteration 566 | Cost: 91.924593
# Iteration 567 | Cost: 91.902352
# Iteration 568 | Cost: 91.880117
# Iteration 569 | Cost: 91.857887
# Iteration 570 | Cost: 91.835663
# Iteration 571 | Cost: 91.813445
# Iteration 572 | Cost: 91.791232
# Iteration 573 | Cost: 91.769025
# Iteration 574 | Cost: 91.746824
# Iteration 575 | Cost: 91.724628
# Iteration 576 | Cost: 91.702438
# Iteration 577 | Cost: 91.680254
# Iteration 578 | Cost: 91.658075
# Iteration 579 | Cost: 91.635902
# Iteration 580 | Cost: 91.613734
# Iteration 581 | Cost: 91.591572
# Iteration 582 | Cost: 91.569416
# Iteration 583 | Cost: 91.547265
# Iteration 584 | Cost: 91.525120
# Iteration 585 | Cost: 91.502980
# Iteration 586 | Cost: 91.480846
# Iteration 587 | Cost: 91.458718
# Iteration 588 | Cost: 91.436596
# Iteration 589 | Cost: 91.414479
# Iteration 590 | Cost: 91.392367
# Iteration 591 | Cost: 91.370261
# Iteration 592 | Cost: 91.348161
# Iteration 593 | Cost: 91.326067
# Iteration 594 | Cost: 91.303978
# Iteration 595 | Cost: 91.281894
# Iteration 596 | Cost: 91.259816
# Iteration 597 | Cost: 91.237744
# Iteration 598 | Cost: 91.215678
# Iteration 599 | Cost: 91.193617
# Iteration 600 | Cost: 91.171561
# Iteration 601 | Cost: 91.149511
# Iteration 602 | Cost: 91.127467
# Iteration 603 | Cost: 91.105429
# Iteration 604 | Cost: 91.083396
# Iteration 605 | Cost: 91.061368
# Iteration 606 | Cost: 91.039346
# Iteration 607 | Cost: 91.017330
# Iteration 608 | Cost: 90.995319
# Iteration 609 | Cost: 90.973314
# Iteration 610 | Cost: 90.951315
# Iteration 611 | Cost: 90.929321
# Iteration 612 | Cost: 90.907333
# Iteration 613 | Cost: 90.885350
# Iteration 614 | Cost: 90.863373
# Iteration 615 | Cost: 90.841401
# Iteration 616 | Cost: 90.819435
# Iteration 617 | Cost: 90.797475
# Iteration 618 | Cost: 90.775520
# Iteration 619 | Cost: 90.753570
# Iteration 620 | Cost: 90.731627
# Iteration 621 | Cost: 90.709688
# Iteration 622 | Cost: 90.687756
# Iteration 623 | Cost: 90.665829
# Iteration 624 | Cost: 90.643907
# Iteration 625 | Cost: 90.621991
# Iteration 626 | Cost: 90.600081
# Iteration 627 | Cost: 90.578176
# Iteration 628 | Cost: 90.556277
# Iteration 629 | Cost: 90.534383
# Iteration 630 | Cost: 90.512495
# Iteration 631 | Cost: 90.490612
# Iteration 632 | Cost: 90.468735
# Iteration 633 | Cost: 90.446864
# Iteration 634 | Cost: 90.424998
# Iteration 635 | Cost: 90.403138
# Iteration 636 | Cost: 90.381283
# Iteration 637 | Cost: 90.359433
# Iteration 638 | Cost: 90.337590
# Iteration 639 | Cost: 90.315751
# Iteration 640 | Cost: 90.293919
# Iteration 641 | Cost: 90.272092
# Iteration 642 | Cost: 90.250270
# Iteration 643 | Cost: 90.228454
# Iteration 644 | Cost: 90.206643
# Iteration 645 | Cost: 90.184838
# Iteration 646 | Cost: 90.163039
# Iteration 647 | Cost: 90.141245
# Iteration 648 | Cost: 90.119457
# Iteration 649 | Cost: 90.097674
# Iteration 650 | Cost: 90.075896
# Iteration 651 | Cost: 90.054124
# Iteration 652 | Cost: 90.032358
# Iteration 653 | Cost: 90.010597
# Iteration 654 | Cost: 89.988842
# Iteration 655 | Cost: 89.967092
# Iteration 656 | Cost: 89.945348
# Iteration 657 | Cost: 89.923609
# Iteration 658 | Cost: 89.901876
# Iteration 659 | Cost: 89.880149
# Iteration 660 | Cost: 89.858426
# Iteration 661 | Cost: 89.836710
# Iteration 662 | Cost: 89.814999
# Iteration 663 | Cost: 89.793293
# Iteration 664 | Cost: 89.771593
# Iteration 665 | Cost: 89.749898
# Iteration 666 | Cost: 89.728209
# Iteration 667 | Cost: 89.706525
# Iteration 668 | Cost: 89.684847
# Iteration 669 | Cost: 89.663175
# Iteration 670 | Cost: 89.641508
# Iteration 671 | Cost: 89.619846
# Iteration 672 | Cost: 89.598190
# Iteration 673 | Cost: 89.576539
# Iteration 674 | Cost: 89.554894
# Iteration 675 | Cost: 89.533254
# Iteration 676 | Cost: 89.511620
# Iteration 677 | Cost: 89.489992
# Iteration 678 | Cost: 89.468368
# Iteration 679 | Cost: 89.446751
# Iteration 680 | Cost: 89.425138
# Iteration 681 | Cost: 89.403532
# Iteration 682 | Cost: 89.381930
# Iteration 683 | Cost: 89.360335
# Iteration 684 | Cost: 89.338744
# Iteration 685 | Cost: 89.317160
# Iteration 686 | Cost: 89.295580
# Iteration 687 | Cost: 89.274006
# Iteration 688 | Cost: 89.252438
# Iteration 689 | Cost: 89.230875
# Iteration 690 | Cost: 89.209318
# Iteration 691 | Cost: 89.187766
# Iteration 692 | Cost: 89.166219
# Iteration 693 | Cost: 89.144678
# Iteration 694 | Cost: 89.123142
# Iteration 695 | Cost: 89.101612
# Iteration 696 | Cost: 89.080088
# Iteration 697 | Cost: 89.058568
# Iteration 698 | Cost: 89.037055
# Iteration 699 | Cost: 89.015546
# Iteration 700 | Cost: 88.994044
# Iteration 701 | Cost: 88.972546
# Iteration 702 | Cost: 88.951054
# Iteration 703 | Cost: 88.929568
# Iteration 704 | Cost: 88.908087
# Iteration 705 | Cost: 88.886611
# Iteration 706 | Cost: 88.865141
# Iteration 707 | Cost: 88.843676
# Iteration 708 | Cost: 88.822217
# Iteration 709 | Cost: 88.800763
# Iteration 710 | Cost: 88.779315
# Iteration 711 | Cost: 88.757872
# Iteration 712 | Cost: 88.736435
# Iteration 713 | Cost: 88.715003
# Iteration 714 | Cost: 88.693576
# Iteration 715 | Cost: 88.672155
# Iteration 716 | Cost: 88.650739
# Iteration 717 | Cost: 88.629329
# Iteration 718 | Cost: 88.607924
# Iteration 719 | Cost: 88.586525
# Iteration 720 | Cost: 88.565131
# Iteration 721 | Cost: 88.543742
# Iteration 722 | Cost: 88.522359
# Iteration 723 | Cost: 88.500981
# Iteration 724 | Cost: 88.479609
# Iteration 725 | Cost: 88.458242
# Iteration 726 | Cost: 88.436881
# Iteration 727 | Cost: 88.415525
# Iteration 728 | Cost: 88.394174
# Iteration 729 | Cost: 88.372829
# Iteration 730 | Cost: 88.351489
# Iteration 731 | Cost: 88.330155
# Iteration 732 | Cost: 88.308826
# Iteration 733 | Cost: 88.287502
# Iteration 734 | Cost: 88.266184
# Iteration 735 | Cost: 88.244872
# Iteration 736 | Cost: 88.223564
# Iteration 737 | Cost: 88.202262
# Iteration 738 | Cost: 88.180966
# Iteration 739 | Cost: 88.159675
# Iteration 740 | Cost: 88.138389
# Iteration 741 | Cost: 88.117109
# Iteration 742 | Cost: 88.095834
# Iteration 743 | Cost: 88.074564
# Iteration 744 | Cost: 88.053300
# Iteration 745 | Cost: 88.032042
# Iteration 746 | Cost: 88.010788
# Iteration 747 | Cost: 87.989540
# Iteration 748 | Cost: 87.968298
# Iteration 749 | Cost: 87.947061
# Iteration 750 | Cost: 87.925829
# Iteration 751 | Cost: 87.904603
# Iteration 752 | Cost: 87.883382
# Iteration 753 | Cost: 87.862166
# Iteration 754 | Cost: 87.840956
# Iteration 755 | Cost: 87.819751
# Iteration 756 | Cost: 87.798551
# Iteration 757 | Cost: 87.777357
# Iteration 758 | Cost: 87.756169
# Iteration 759 | Cost: 87.734985
# Iteration 760 | Cost: 87.713807
# Iteration 761 | Cost: 87.692635
# Iteration 762 | Cost: 87.671468
# Iteration 763 | Cost: 87.650306
# Iteration 764 | Cost: 87.629149
# Iteration 765 | Cost: 87.607998
# Iteration 766 | Cost: 87.586853
# Iteration 767 | Cost: 87.565712
# Iteration 768 | Cost: 87.544577
# Iteration 769 | Cost: 87.523447
# Iteration 770 | Cost: 87.502323
# Iteration 771 | Cost: 87.481204
# Iteration 772 | Cost: 87.460091
# Iteration 773 | Cost: 87.438982
# Iteration 774 | Cost: 87.417880
# Iteration 775 | Cost: 87.396782
# Iteration 776 | Cost: 87.375690
# Iteration 777 | Cost: 87.354603
# Iteration 778 | Cost: 87.333522
# Iteration 779 | Cost: 87.312446
# Iteration 780 | Cost: 87.291375
# Iteration 781 | Cost: 87.270309
# Iteration 782 | Cost: 87.249249
# Iteration 783 | Cost: 87.228195
# Iteration 784 | Cost: 87.207145
# Iteration 785 | Cost: 87.186101
# Iteration 786 | Cost: 87.165063
# Iteration 787 | Cost: 87.144029
# Iteration 788 | Cost: 87.123001
# Iteration 789 | Cost: 87.101978
# Iteration 790 | Cost: 87.080961
# Iteration 791 | Cost: 87.059949
# Iteration 792 | Cost: 87.038942
# Iteration 793 | Cost: 87.017941
# Iteration 794 | Cost: 86.996945
# Iteration 795 | Cost: 86.975954
# Iteration 796 | Cost: 86.954969
# Iteration 797 | Cost: 86.933989
# Iteration 798 | Cost: 86.913014
# Iteration 799 | Cost: 86.892045
# Iteration 800 | Cost: 86.871080
# Iteration 801 | Cost: 86.850122
# Iteration 802 | Cost: 86.829168
# Iteration 803 | Cost: 86.808220
# Iteration 804 | Cost: 86.787277
# Iteration 805 | Cost: 86.766340
# Iteration 806 | Cost: 86.745408
# Iteration 807 | Cost: 86.724481
# Iteration 808 | Cost: 86.703559
# Iteration 809 | Cost: 86.682643
# Iteration 810 | Cost: 86.661732
# Iteration 811 | Cost: 86.640826
# Iteration 812 | Cost: 86.619926
# Iteration 813 | Cost: 86.599031
# Iteration 814 | Cost: 86.578141
# Iteration 815 | Cost: 86.557256
# Iteration 816 | Cost: 86.536377
# Iteration 817 | Cost: 86.515503
# Iteration 818 | Cost: 86.494635
# Iteration 819 | Cost: 86.473772
# Iteration 820 | Cost: 86.452914
# Iteration 821 | Cost: 86.432061
# Iteration 822 | Cost: 86.411213
# Iteration 823 | Cost: 86.390371
# Iteration 824 | Cost: 86.369534
# Iteration 825 | Cost: 86.348703
# Iteration 826 | Cost: 86.327877
# Iteration 827 | Cost: 86.307056
# Iteration 828 | Cost: 86.286240
# Iteration 829 | Cost: 86.265430
# Iteration 830 | Cost: 86.244624
# Iteration 831 | Cost: 86.223825
# Iteration 832 | Cost: 86.203030
# Iteration 833 | Cost: 86.182241
# Iteration 834 | Cost: 86.161457
# Iteration 835 | Cost: 86.140678
# Iteration 836 | Cost: 86.119904
# Iteration 837 | Cost: 86.099136
# Iteration 838 | Cost: 86.078373
# Iteration 839 | Cost: 86.057616
# Iteration 840 | Cost: 86.036863
# Iteration 841 | Cost: 86.016116
# Iteration 842 | Cost: 85.995374
# Iteration 843 | Cost: 85.974638
# Iteration 844 | Cost: 85.953906
# Iteration 845 | Cost: 85.933180
# Iteration 846 | Cost: 85.912459
# Iteration 847 | Cost: 85.891744
# Iteration 848 | Cost: 85.871033
# Iteration 849 | Cost: 85.850328
# Iteration 850 | Cost: 85.829628
# Iteration 851 | Cost: 85.808934
# Iteration 852 | Cost: 85.788245
# Iteration 853 | Cost: 85.767560
# Iteration 854 | Cost: 85.746882
# Iteration 855 | Cost: 85.726208
# Iteration 856 | Cost: 85.705540
# Iteration 857 | Cost: 85.684877
# Iteration 858 | Cost: 85.664219
# Iteration 859 | Cost: 85.643566
# Iteration 860 | Cost: 85.622919
# Iteration 861 | Cost: 85.602277
# Iteration 862 | Cost: 85.581640
# Iteration 863 | Cost: 85.561008
# Iteration 864 | Cost: 85.540382
# Iteration 865 | Cost: 85.519761
# Iteration 866 | Cost: 85.499145
# Iteration 867 | Cost: 85.478534
# Iteration 868 | Cost: 85.457928
# Iteration 869 | Cost: 85.437328
# Iteration 870 | Cost: 85.416733
# Iteration 871 | Cost: 85.396143
# Iteration 872 | Cost: 85.375559
# Iteration 873 | Cost: 85.354979
# Iteration 874 | Cost: 85.334405
# Iteration 875 | Cost: 85.313836
# Iteration 876 | Cost: 85.293272
# Iteration 877 | Cost: 85.272714
# Iteration 878 | Cost: 85.252161
# Iteration 879 | Cost: 85.231613
# Iteration 880 | Cost: 85.211070
# Iteration 881 | Cost: 85.190532
# Iteration 882 | Cost: 85.170000
# Iteration 883 | Cost: 85.149472
# Iteration 884 | Cost: 85.128950
# Iteration 885 | Cost: 85.108434
# Iteration 886 | Cost: 85.087922
# Iteration 887 | Cost: 85.067415
# Iteration 888 | Cost: 85.046914
# Iteration 889 | Cost: 85.026418
# Iteration 890 | Cost: 85.005927
# Iteration 891 | Cost: 84.985442
# Iteration 892 | Cost: 84.964961
# Iteration 893 | Cost: 84.944486
# Iteration 894 | Cost: 84.924016
# Iteration 895 | Cost: 84.903551
# Iteration 896 | Cost: 84.883092
# Iteration 897 | Cost: 84.862637
# Iteration 898 | Cost: 84.842188
# Iteration 899 | Cost: 84.821744
# Iteration 900 | Cost: 84.801305
# Iteration 901 | Cost: 84.780871
# Iteration 902 | Cost: 84.760443
# Iteration 903 | Cost: 84.740020
# Iteration 904 | Cost: 84.719601
# Iteration 905 | Cost: 84.699189
# Iteration 906 | Cost: 84.678781
# Iteration 907 | Cost: 84.658378
# Iteration 908 | Cost: 84.637981
# Iteration 909 | Cost: 84.617588
# Iteration 910 | Cost: 84.597201
# Iteration 911 | Cost: 84.576819
# Iteration 912 | Cost: 84.556443
# Iteration 913 | Cost: 84.536071
# Iteration 914 | Cost: 84.515705
# Iteration 915 | Cost: 84.495343
# Iteration 916 | Cost: 84.474987
# Iteration 917 | Cost: 84.454637
# Iteration 918 | Cost: 84.434291
# Iteration 919 | Cost: 84.413950
# Iteration 920 | Cost: 84.393615
# Iteration 921 | Cost: 84.373285
# Iteration 922 | Cost: 84.352959
# Iteration 923 | Cost: 84.332639
# Iteration 924 | Cost: 84.312325
# Iteration 925 | Cost: 84.292015
# Iteration 926 | Cost: 84.271711
# Iteration 927 | Cost: 84.251411
# Iteration 928 | Cost: 84.231117
# Iteration 929 | Cost: 84.210828
# Iteration 930 | Cost: 84.190544
# Iteration 931 | Cost: 84.170265
# Iteration 932 | Cost: 84.149992
# Iteration 933 | Cost: 84.129723
# Iteration 934 | Cost: 84.109460
# Iteration 935 | Cost: 84.089202
# Iteration 936 | Cost: 84.068949
# Iteration 937 | Cost: 84.048701
# Iteration 938 | Cost: 84.028458
# Iteration 939 | Cost: 84.008220
# Iteration 940 | Cost: 83.987988
# Iteration 941 | Cost: 83.967761
# Iteration 942 | Cost: 83.947538
# Iteration 943 | Cost: 83.927321
# Iteration 944 | Cost: 83.907109
# Iteration 945 | Cost: 83.886902
# Iteration 946 | Cost: 83.866701
# Iteration 947 | Cost: 83.846504
# Iteration 948 | Cost: 83.826313
# Iteration 949 | Cost: 83.806126
# Iteration 950 | Cost: 83.785945
# Iteration 951 | Cost: 83.765769
# Iteration 952 | Cost: 83.745598
# Iteration 953 | Cost: 83.725432
# Iteration 954 | Cost: 83.705271
# Iteration 955 | Cost: 83.685116
# Iteration 956 | Cost: 83.664965
# Iteration 957 | Cost: 83.644820
# Iteration 958 | Cost: 83.624680
# Iteration 959 | Cost: 83.604544
# Iteration 960 | Cost: 83.584414
# Iteration 961 | Cost: 83.564289
# Iteration 962 | Cost: 83.544170
# Iteration 963 | Cost: 83.524055
# Iteration 964 | Cost: 83.503945
# Iteration 965 | Cost: 83.483841
# Iteration 966 | Cost: 83.463741
# Iteration 967 | Cost: 83.443647
# Iteration 968 | Cost: 83.423557
# Iteration 969 | Cost: 83.403473
# Iteration 970 | Cost: 83.383394
# Iteration 971 | Cost: 83.363320
# Iteration 972 | Cost: 83.343251
# Iteration 973 | Cost: 83.323188
# Iteration 974 | Cost: 83.303129
# Iteration 975 | Cost: 83.283075
# Iteration 976 | Cost: 83.263027
# Iteration 977 | Cost: 83.242983
# Iteration 978 | Cost: 83.222945
# Iteration 979 | Cost: 83.202912
# Iteration 980 | Cost: 83.182883
# Iteration 981 | Cost: 83.162860
# Iteration 982 | Cost: 83.142842
# Iteration 983 | Cost: 83.122829
# Iteration 984 | Cost: 83.102822
# Iteration 985 | Cost: 83.082819
# Iteration 986 | Cost: 83.062821
# Iteration 987 | Cost: 83.042828
# Iteration 988 | Cost: 83.022841
# Iteration 989 | Cost: 83.002858
# Iteration 990 | Cost: 82.982881
# Iteration 991 | Cost: 82.962908
# Iteration 992 | Cost: 82.942941
# Iteration 993 | Cost: 82.922979
# Iteration 994 | Cost: 82.903022
# Iteration 995 | Cost: 82.883070
# Iteration 996 | Cost: 82.863123
# Iteration 997 | Cost: 82.843181
# Iteration 998 | Cost: 82.823244
# Iteration 999 | Cost: 82.803312
# Iteration 1000 | Cost: 82.783385
# Iteration 1001 | Cost: 82.763463
# Iteration 1002 | Cost: 82.743547
# Iteration 1003 | Cost: 82.723635
# Iteration 1004 | Cost: 82.703728
# Iteration 1005 | Cost: 82.683827
# Iteration 1006 | Cost: 82.663930
# Iteration 1007 | Cost: 82.644039
# Iteration 1008 | Cost: 82.624152
# Iteration 1009 | Cost: 82.604271
# Iteration 1010 | Cost: 82.584395
# Iteration 1011 | Cost: 82.564523
# Iteration 1012 | Cost: 82.544657
# Iteration 1013 | Cost: 82.524796
# Iteration 1014 | Cost: 82.504940
# Iteration 1015 | Cost: 82.485089
# Iteration 1016 | Cost: 82.465243
# Iteration 1017 | Cost: 82.445402
# Iteration 1018 | Cost: 82.425566
# Iteration 1019 | Cost: 82.405735
# Iteration 1020 | Cost: 82.385909
# Iteration 1021 | Cost: 82.366088
# Iteration 1022 | Cost: 82.346272
# Iteration 1023 | Cost: 82.326461
# Iteration 1024 | Cost: 82.306655
# Iteration 1025 | Cost: 82.286854
# Iteration 1026 | Cost: 82.267059
# Iteration 1027 | Cost: 82.247268
# Iteration 1028 | Cost: 82.227482
# Iteration 1029 | Cost: 82.207701
# Iteration 1030 | Cost: 82.187926
# Iteration 1031 | Cost: 82.168155
# Iteration 1032 | Cost: 82.148389
# Iteration 1033 | Cost: 82.128629
# Iteration 1034 | Cost: 82.108873
# Iteration 1035 | Cost: 82.089122
# Iteration 1036 | Cost: 82.069377
# Iteration 1037 | Cost: 82.049636
# Iteration 1038 | Cost: 82.029901
# Iteration 1039 | Cost: 82.010170
# Iteration 1040 | Cost: 81.990444
# Iteration 1041 | Cost: 81.970724
# Iteration 1042 | Cost: 81.951008
# Iteration 1043 | Cost: 81.931298
# Iteration 1044 | Cost: 81.911592
# Iteration 1045 | Cost: 81.891891
# Iteration 1046 | Cost: 81.872196
# Iteration 1047 | Cost: 81.852505
# Iteration 1048 | Cost: 81.832820
# Iteration 1049 | Cost: 81.813139
# Iteration 1050 | Cost: 81.793463
# Iteration 1051 | Cost: 81.773793
# Iteration 1052 | Cost: 81.754127
# Iteration 1053 | Cost: 81.734467
# Iteration 1054 | Cost: 81.714811
# Iteration 1055 | Cost: 81.695160
# Iteration 1056 | Cost: 81.675515
# Iteration 1057 | Cost: 81.655874
# Iteration 1058 | Cost: 81.636238
# Iteration 1059 | Cost: 81.616607
# Iteration 1060 | Cost: 81.596982
# Iteration 1061 | Cost: 81.577361
# Iteration 1062 | Cost: 81.557745
# Iteration 1063 | Cost: 81.538134
# Iteration 1064 | Cost: 81.518528
# Iteration 1065 | Cost: 81.498928
# Iteration 1066 | Cost: 81.479332
# Iteration 1067 | Cost: 81.459741
# Iteration 1068 | Cost: 81.440155
# Iteration 1069 | Cost: 81.420574
# Iteration 1070 | Cost: 81.400998
# Iteration 1071 | Cost: 81.381427
# Iteration 1072 | Cost: 81.361861
# Iteration 1073 | Cost: 81.342300
# Iteration 1074 | Cost: 81.322743
# Iteration 1075 | Cost: 81.303192
# Iteration 1076 | Cost: 81.283646
# Iteration 1077 | Cost: 81.264105
# Iteration 1078 | Cost: 81.244568
# Iteration 1079 | Cost: 81.225037
# Iteration 1080 | Cost: 81.205511
# Iteration 1081 | Cost: 81.185989
# Iteration 1082 | Cost: 81.166473
# Iteration 1083 | Cost: 81.146961
# Iteration 1084 | Cost: 81.127454
# Iteration 1085 | Cost: 81.107953
# Iteration 1086 | Cost: 81.088456
# Iteration 1087 | Cost: 81.068964
# Iteration 1088 | Cost: 81.049478
# Iteration 1089 | Cost: 81.029996
# Iteration 1090 | Cost: 81.010519
# Iteration 1091 | Cost: 80.991047
# Iteration 1092 | Cost: 80.971580
# Iteration 1093 | Cost: 80.952118
# Iteration 1094 | Cost: 80.932660
# Iteration 1095 | Cost: 80.913208
# Iteration 1096 | Cost: 80.893761
# Iteration 1097 | Cost: 80.874318
# Iteration 1098 | Cost: 80.854881
# Iteration 1099 | Cost: 80.835449
# Iteration 1100 | Cost: 80.816021
# Iteration 1101 | Cost: 80.796598
# Iteration 1102 | Cost: 80.777181
# Iteration 1103 | Cost: 80.757768
# Iteration 1104 | Cost: 80.738360
# Iteration 1105 | Cost: 80.718957
# Iteration 1106 | Cost: 80.699559
# Iteration 1107 | Cost: 80.680166
# Iteration 1108 | Cost: 80.660778
# Iteration 1109 | Cost: 80.641394
# Iteration 1110 | Cost: 80.622016
# Iteration 1111 | Cost: 80.602643
# Iteration 1112 | Cost: 80.583274
# Iteration 1113 | Cost: 80.563911
# Iteration 1114 | Cost: 80.544552
# Iteration 1115 | Cost: 80.525198
# Iteration 1116 | Cost: 80.505849
# Iteration 1117 | Cost: 80.486505
# Iteration 1118 | Cost: 80.467166
# Iteration 1119 | Cost: 80.447832
# Iteration 1120 | Cost: 80.428503
# Iteration 1121 | Cost: 80.409179
# Iteration 1122 | Cost: 80.389859
# Iteration 1123 | Cost: 80.370545
# Iteration 1124 | Cost: 80.351235
# Iteration 1125 | Cost: 80.331930
# Iteration 1126 | Cost: 80.312630
# Iteration 1127 | Cost: 80.293335
# Iteration 1128 | Cost: 80.274045
# Iteration 1129 | Cost: 80.254760
# Iteration 1130 | Cost: 80.235480
# Iteration 1131 | Cost: 80.216205
# Iteration 1132 | Cost: 80.196934
# Iteration 1133 | Cost: 80.177669
# Iteration 1134 | Cost: 80.158408
# Iteration 1135 | Cost: 80.139152
# Iteration 1136 | Cost: 80.119901
# Iteration 1137 | Cost: 80.100655
# Iteration 1138 | Cost: 80.081414
# Iteration 1139 | Cost: 80.062178
# Iteration 1140 | Cost: 80.042946
# Iteration 1141 | Cost: 80.023720
# Iteration 1142 | Cost: 80.004498
# Iteration 1143 | Cost: 79.985281
# Iteration 1144 | Cost: 79.966069
# Iteration 1145 | Cost: 79.946862
# Iteration 1146 | Cost: 79.927660
# Iteration 1147 | Cost: 79.908463
# Iteration 1148 | Cost: 79.889271
# Iteration 1149 | Cost: 79.870083
# Iteration 1150 | Cost: 79.850900
# Iteration 1151 | Cost: 79.831723
# Iteration 1152 | Cost: 79.812550
# Iteration 1153 | Cost: 79.793382
# Iteration 1154 | Cost: 79.774218
# Iteration 1155 | Cost: 79.755060
# Iteration 1156 | Cost: 79.735907
# Iteration 1157 | Cost: 79.716758
# Iteration 1158 | Cost: 79.697614
# Iteration 1159 | Cost: 79.678475
# Iteration 1160 | Cost: 79.659341
# Iteration 1161 | Cost: 79.640212
# Iteration 1162 | Cost: 79.621088
# Iteration 1163 | Cost: 79.601968
# Iteration 1164 | Cost: 79.582853
# Iteration 1165 | Cost: 79.563744
# Iteration 1166 | Cost: 79.544639
# Iteration 1167 | Cost: 79.525539
# Iteration 1168 | Cost: 79.506443
# Iteration 1169 | Cost: 79.487353
# Iteration 1170 | Cost: 79.468267
# Iteration 1171 | Cost: 79.449187
# Iteration 1172 | Cost: 79.430111
# Iteration 1173 | Cost: 79.411040
# Iteration 1174 | Cost: 79.391974
# Iteration 1175 | Cost: 79.372912
# Iteration 1176 | Cost: 79.353856
# Iteration 1177 | Cost: 79.334804
# Iteration 1178 | Cost: 79.315757
# Iteration 1179 | Cost: 79.296715
# Iteration 1180 | Cost: 79.277678
# Iteration 1181 | Cost: 79.258645
# Iteration 1182 | Cost: 79.239618
# Iteration 1183 | Cost: 79.220595
# Iteration 1184 | Cost: 79.201577
# Iteration 1185 | Cost: 79.182564
# Iteration 1186 | Cost: 79.163556
# Iteration 1187 | Cost: 79.144553
# Iteration 1188 | Cost: 79.125554
# Iteration 1189 | Cost: 79.106560
# Iteration 1190 | Cost: 79.087571
# Iteration 1191 | Cost: 79.068587
# Iteration 1192 | Cost: 79.049608
# Iteration 1193 | Cost: 79.030633
# Iteration 1194 | Cost: 79.011664
# Iteration 1195 | Cost: 78.992699
# Iteration 1196 | Cost: 78.973739
# Iteration 1197 | Cost: 78.954783
# Iteration 1198 | Cost: 78.935833
# Iteration 1199 | Cost: 78.916887
# Iteration 1200 | Cost: 78.897946
# Iteration 1201 | Cost: 78.879010
# Iteration 1202 | Cost: 78.860079
# Iteration 1203 | Cost: 78.841153
# Iteration 1204 | Cost: 78.822231
# Iteration 1205 | Cost: 78.803314
# Iteration 1206 | Cost: 78.784402
# Iteration 1207 | Cost: 78.765495
# Iteration 1208 | Cost: 78.746592
# Iteration 1209 | Cost: 78.727695
# Iteration 1210 | Cost: 78.708802
# Iteration 1211 | Cost: 78.689914
# Iteration 1212 | Cost: 78.671031
# Iteration 1213 | Cost: 78.652152
# Iteration 1214 | Cost: 78.633279
# Iteration 1215 | Cost: 78.614410
# Iteration 1216 | Cost: 78.595546
# Iteration 1217 | Cost: 78.576686
# Iteration 1218 | Cost: 78.557832
# Iteration 1219 | Cost: 78.538982
# Iteration 1220 | Cost: 78.520137
# Iteration 1221 | Cost: 78.501297
# Iteration 1222 | Cost: 78.482461
# Iteration 1223 | Cost: 78.463631
# Iteration 1224 | Cost: 78.444805
# Iteration 1225 | Cost: 78.425984
# Iteration 1226 | Cost: 78.407167
# Iteration 1227 | Cost: 78.388356
# Iteration 1228 | Cost: 78.369549
# Iteration 1229 | Cost: 78.350747
# Iteration 1230 | Cost: 78.331950
# Iteration 1231 | Cost: 78.313158
# Iteration 1232 | Cost: 78.294370
# Iteration 1233 | Cost: 78.275587
# Iteration 1234 | Cost: 78.256809
# Iteration 1235 | Cost: 78.238035
# Iteration 1236 | Cost: 78.219267
# Iteration 1237 | Cost: 78.200503
# Iteration 1238 | Cost: 78.181744
# Iteration 1239 | Cost: 78.162989
# Iteration 1240 | Cost: 78.144240
# Iteration 1241 | Cost: 78.125495
# Iteration 1242 | Cost: 78.106755
# Iteration 1243 | Cost: 78.088020
# Iteration 1244 | Cost: 78.069289
# Iteration 1245 | Cost: 78.050563
# Iteration 1246 | Cost: 78.031842
# Iteration 1247 | Cost: 78.013126
# Iteration 1248 | Cost: 77.994414
# Iteration 1249 | Cost: 77.975708
# Iteration 1250 | Cost: 77.957005
# Iteration 1251 | Cost: 77.938308
# Iteration 1252 | Cost: 77.919616
# Iteration 1253 | Cost: 77.900928
# Iteration 1254 | Cost: 77.882245
# Iteration 1255 | Cost: 77.863566
# Iteration 1256 | Cost: 77.844893
# Iteration 1257 | Cost: 77.826224
# Iteration 1258 | Cost: 77.807560
# Iteration 1259 | Cost: 77.788900
# Iteration 1260 | Cost: 77.770245
# Iteration 1261 | Cost: 77.751596
# Iteration 1262 | Cost: 77.732950
# Iteration 1263 | Cost: 77.714310
# Iteration 1264 | Cost: 77.695674
# Iteration 1265 | Cost: 77.677043
# Iteration 1266 | Cost: 77.658417
# Iteration 1267 | Cost: 77.639795
# Iteration 1268 | Cost: 77.621178
# Iteration 1269 | Cost: 77.602566
# Iteration 1270 | Cost: 77.583959
# Iteration 1271 | Cost: 77.565356
# Iteration 1272 | Cost: 77.546758
# Iteration 1273 | Cost: 77.528165
# Iteration 1274 | Cost: 77.509576
# Iteration 1275 | Cost: 77.490993
# Iteration 1276 | Cost: 77.472413
# Iteration 1277 | Cost: 77.453839
# Iteration 1278 | Cost: 77.435269
# Iteration 1279 | Cost: 77.416704
# Iteration 1280 | Cost: 77.398144
# Iteration 1281 | Cost: 77.379589
# Iteration 1282 | Cost: 77.361038
# Iteration 1283 | Cost: 77.342492
# Iteration 1284 | Cost: 77.323950
# Iteration 1285 | Cost: 77.305413
# Iteration 1286 | Cost: 77.286881
# Iteration 1287 | Cost: 77.268354
# Iteration 1288 | Cost: 77.249832
# Iteration 1289 | Cost: 77.231314
# Iteration 1290 | Cost: 77.212800
# Iteration 1291 | Cost: 77.194292
# Iteration 1292 | Cost: 77.175788
# Iteration 1293 | Cost: 77.157289
# Iteration 1294 | Cost: 77.138794
# Iteration 1295 | Cost: 77.120305
# Iteration 1296 | Cost: 77.101820
# Iteration 1297 | Cost: 77.083339
# Iteration 1298 | Cost: 77.064864
# Iteration 1299 | Cost: 77.046393
# Iteration 1300 | Cost: 77.027926
# Iteration 1301 | Cost: 77.009465
# Iteration 1302 | Cost: 76.991008
# Iteration 1303 | Cost: 76.972555
# Iteration 1304 | Cost: 76.954108
# Iteration 1305 | Cost: 76.935665
# Iteration 1306 | Cost: 76.917227
# Iteration 1307 | Cost: 76.898793
# Iteration 1308 | Cost: 76.880364
# Iteration 1309 | Cost: 76.861940
# Iteration 1310 | Cost: 76.843521
# Iteration 1311 | Cost: 76.825106
# Iteration 1312 | Cost: 76.806696
# Iteration 1313 | Cost: 76.788290
# Iteration 1314 | Cost: 76.769889
# Iteration 1315 | Cost: 76.751493
# Iteration 1316 | Cost: 76.733102
# Iteration 1317 | Cost: 76.714715
# Iteration 1318 | Cost: 76.696333
# Iteration 1319 | Cost: 76.677955
# Iteration 1320 | Cost: 76.659582
# Iteration 1321 | Cost: 76.641214
# Iteration 1322 | Cost: 76.622851
# Iteration 1323 | Cost: 76.604492
# Iteration 1324 | Cost: 76.586138
# Iteration 1325 | Cost: 76.567788
# Iteration 1326 | Cost: 76.549443
# Iteration 1327 | Cost: 76.531103
# Iteration 1328 | Cost: 76.512767
# Iteration 1329 | Cost: 76.494436
# Iteration 1330 | Cost: 76.476110
# Iteration 1331 | Cost: 76.457788
# Iteration 1332 | Cost: 76.439472
# Iteration 1333 | Cost: 76.421159
# Iteration 1334 | Cost: 76.402851
# Iteration 1335 | Cost: 76.384548
# Iteration 1336 | Cost: 76.366250
# Iteration 1337 | Cost: 76.347956
# Iteration 1338 | Cost: 76.329667
# Iteration 1339 | Cost: 76.311383
# Iteration 1340 | Cost: 76.293103
# Iteration 1341 | Cost: 76.274828
# Iteration 1342 | Cost: 76.256557
# Iteration 1343 | Cost: 76.238291
# Iteration 1344 | Cost: 76.220030
# Iteration 1345 | Cost: 76.201773
# Iteration 1346 | Cost: 76.183521
# Iteration 1347 | Cost: 76.165274
# Iteration 1348 | Cost: 76.147031
# Iteration 1349 | Cost: 76.128793
# Iteration 1350 | Cost: 76.110559
# Iteration 1351 | Cost: 76.092330
# Iteration 1352 | Cost: 76.074106
# Iteration 1353 | Cost: 76.055886
# Iteration 1354 | Cost: 76.037671
# Iteration 1355 | Cost: 76.019461
# Iteration 1356 | Cost: 76.001255
# Iteration 1357 | Cost: 75.983054
# Iteration 1358 | Cost: 75.964858
# Iteration 1359 | Cost: 75.946666
# Iteration 1360 | Cost: 75.928478
# Iteration 1361 | Cost: 75.910296
# Iteration 1362 | Cost: 75.892118
# Iteration 1363 | Cost: 75.873944
# Iteration 1364 | Cost: 75.855775
# Iteration 1365 | Cost: 75.837611
# Iteration 1366 | Cost: 75.819451
# Iteration 1367 | Cost: 75.801296
# Iteration 1368 | Cost: 75.783146
# Iteration 1369 | Cost: 75.765000
# Iteration 1370 | Cost: 75.746859
# Iteration 1371 | Cost: 75.728722
# Iteration 1372 | Cost: 75.710590
# Iteration 1373 | Cost: 75.692463
# Iteration 1374 | Cost: 75.674340
# Iteration 1375 | Cost: 75.656222
# Iteration 1376 | Cost: 75.638108
# Iteration 1377 | Cost: 75.619999
# Iteration 1378 | Cost: 75.601895
# Iteration 1379 | Cost: 75.583795
# Iteration 1380 | Cost: 75.565699
# Iteration 1381 | Cost: 75.547609
# Iteration 1382 | Cost: 75.529523
# Iteration 1383 | Cost: 75.511441
# Iteration 1384 | Cost: 75.493364
# Iteration 1385 | Cost: 75.475292
# Iteration 1386 | Cost: 75.457224
# Iteration 1387 | Cost: 75.439161
# Iteration 1388 | Cost: 75.421103
# Iteration 1389 | Cost: 75.403049
# Iteration 1390 | Cost: 75.384999
# Iteration 1391 | Cost: 75.366954
# Iteration 1392 | Cost: 75.348914
# Iteration 1393 | Cost: 75.330878
# Iteration 1394 | Cost: 75.312847
# Iteration 1395 | Cost: 75.294821
# Iteration 1396 | Cost: 75.276799
# Iteration 1397 | Cost: 75.258782
# Iteration 1398 | Cost: 75.240769
# Iteration 1399 | Cost: 75.222761
# Iteration 1400 | Cost: 75.204757
# Iteration 1401 | Cost: 75.186758
# Iteration 1402 | Cost: 75.168763
# Iteration 1403 | Cost: 75.150773
# Iteration 1404 | Cost: 75.132788
# Iteration 1405 | Cost: 75.114807
# Iteration 1406 | Cost: 75.096831
# Iteration 1407 | Cost: 75.078859
# Iteration 1408 | Cost: 75.060892
# Iteration 1409 | Cost: 75.042929
# Iteration 1410 | Cost: 75.024971
# Iteration 1411 | Cost: 75.007018
# Iteration 1412 | Cost: 74.989069
# Iteration 1413 | Cost: 74.971124
# Iteration 1414 | Cost: 74.953185
# Iteration 1415 | Cost: 74.935249
# Iteration 1416 | Cost: 74.917319
# Iteration 1417 | Cost: 74.899392
# Iteration 1418 | Cost: 74.881471
# Iteration 1419 | Cost: 74.863554
# Iteration 1420 | Cost: 74.845641
# Iteration 1421 | Cost: 74.827733
# Iteration 1422 | Cost: 74.809830
# Iteration 1423 | Cost: 74.791931
# Iteration 1424 | Cost: 74.774037
# Iteration 1425 | Cost: 74.756147
# Iteration 1426 | Cost: 74.738261
# Iteration 1427 | Cost: 74.720381
# Iteration 1428 | Cost: 74.702504
# Iteration 1429 | Cost: 74.684633
# Iteration 1430 | Cost: 74.666766
# Iteration 1431 | Cost: 74.648903
# Iteration 1432 | Cost: 74.631045
# Iteration 1433 | Cost: 74.613191
# Iteration 1434 | Cost: 74.595342
# Iteration 1435 | Cost: 74.577498
# Iteration 1436 | Cost: 74.559658
# Iteration 1437 | Cost: 74.541823
# Iteration 1438 | Cost: 74.523992
# Iteration 1439 | Cost: 74.506165
# Iteration 1440 | Cost: 74.488343
# Iteration 1441 | Cost: 74.470526
# Iteration 1442 | Cost: 74.452713
# Iteration 1443 | Cost: 74.434905
# Iteration 1444 | Cost: 74.417101
# Iteration 1445 | Cost: 74.399302
# Iteration 1446 | Cost: 74.381507
# Iteration 1447 | Cost: 74.363717
# Iteration 1448 | Cost: 74.345931
# Iteration 1449 | Cost: 74.328150
# Iteration 1450 | Cost: 74.310373
# Iteration 1451 | Cost: 74.292601
# Iteration 1452 | Cost: 74.274833
# Iteration 1453 | Cost: 74.257070
# Iteration 1454 | Cost: 74.239311
# Iteration 1455 | Cost: 74.221557
# Iteration 1456 | Cost: 74.203808
# Iteration 1457 | Cost: 74.186062
# Iteration 1458 | Cost: 74.168322
# Iteration 1459 | Cost: 74.150586
# Iteration 1460 | Cost: 74.132854
# Iteration 1461 | Cost: 74.115127
# Iteration 1462 | Cost: 74.097404
# Iteration 1463 | Cost: 74.079686
# Iteration 1464 | Cost: 74.061972
# Iteration 1465 | Cost: 74.044263
# Iteration 1466 | Cost: 74.026558
# Iteration 1467 | Cost: 74.008858
# Iteration 1468 | Cost: 73.991163
# Iteration 1469 | Cost: 73.973471
# Iteration 1470 | Cost: 73.955785
# Iteration 1471 | Cost: 73.938102
# Iteration 1472 | Cost: 73.920425
# Iteration 1473 | Cost: 73.902751
# Iteration 1474 | Cost: 73.885083
# Iteration 1475 | Cost: 73.867418
# Iteration 1476 | Cost: 73.849758
# Iteration 1477 | Cost: 73.832103
# Iteration 1478 | Cost: 73.814452
# Iteration 1479 | Cost: 73.796806
# Iteration 1480 | Cost: 73.779164
# ...
# Iteration 9516 | Cost: 13.306361
# Iteration 9517 | Cost: 13.304065
# Iteration 9518 | Cost: 13.301770
# Iteration 9519 | Cost: 13.299476
# Iteration 9520 | Cost: 13.297182
# Iteration 9521 | Cost: 13.294888
# Iteration 9522 | Cost: 13.292595
# Iteration 9523 | Cost: 13.290303
# Iteration 9524 | Cost: 13.288011
# Iteration 9525 | Cost: 13.285720
# Iteration 9526 | Cost: 13.283430
# Iteration 9527 | Cost: 13.281140
# Iteration 9528 | Cost: 13.278850
# Iteration 9529 | Cost: 13.276561
# Iteration 9530 | Cost: 13.274273
# Iteration 9531 | Cost: 13.271986
# Iteration 9532 | Cost: 13.269699
# Iteration 9533 | Cost: 13.267412
# Iteration 9534 | Cost: 13.265126
# Iteration 9535 | Cost: 13.262841
# Iteration 9536 | Cost: 13.260556
# Iteration 9537 | Cost: 13.258272
# Iteration 9538 | Cost: 13.255988
# Iteration 9539 | Cost: 13.253705
# Iteration 9540 | Cost: 13.251423
# Iteration 9541 | Cost: 13.249141
# Iteration 9542 | Cost: 13.246860
# Iteration 9543 | Cost: 13.244579
# Iteration 9544 | Cost: 13.242299
# Iteration 9545 | Cost: 13.240020
# Iteration 9546 | Cost: 13.237741
# Iteration 9547 | Cost: 13.235462
# Iteration 9548 | Cost: 13.233184
# Iteration 9549 | Cost: 13.230907
# Iteration 9550 | Cost: 13.228631
# Iteration 9551 | Cost: 13.226355
# Iteration 9552 | Cost: 13.224079
# Iteration 9553 | Cost: 13.221804
# Iteration 9554 | Cost: 13.219530
# Iteration 9555 | Cost: 13.217256
# Iteration 9556 | Cost: 13.214983
# Iteration 9557 | Cost: 13.212710
# Iteration 9558 | Cost: 13.210438
# Iteration 9559 | Cost: 13.208167
# Iteration 9560 | Cost: 13.205896
# Iteration 9561 | Cost: 13.203626
# Iteration 9562 | Cost: 13.201356
# Iteration 9563 | Cost: 13.199087
# Iteration 9564 | Cost: 13.196818
# Iteration 9565 | Cost: 13.194550
# Iteration 9566 | Cost: 13.192283
# Iteration 9567 | Cost: 13.190016
# Iteration 9568 | Cost: 13.187750
# Iteration 9569 | Cost: 13.185484
# Iteration 9570 | Cost: 13.183219
# Iteration 9571 | Cost: 13.180955
# Iteration 9572 | Cost: 13.178691
# Iteration 9573 | Cost: 13.176427
# Iteration 9574 | Cost: 13.174164
# Iteration 9575 | Cost: 13.171902
# Iteration 9576 | Cost: 13.169640
# Iteration 9577 | Cost: 13.167379
# Iteration 9578 | Cost: 13.165119
# Iteration 9579 | Cost: 13.162859
# Iteration 9580 | Cost: 13.160600
# Iteration 9581 | Cost: 13.158341
# Iteration 9582 | Cost: 13.156083
# Iteration 9583 | Cost: 13.153825
# Iteration 9584 | Cost: 13.151568
# Iteration 9585 | Cost: 13.149311
# Iteration 9586 | Cost: 13.147055
# Iteration 9587 | Cost: 13.144800
# Iteration 9588 | Cost: 13.142545
# Iteration 9589 | Cost: 13.140291
# Iteration 9590 | Cost: 13.138037
# Iteration 9591 | Cost: 13.135784
# Iteration 9592 | Cost: 13.133532
# Iteration 9593 | Cost: 13.131280
# Iteration 9594 | Cost: 13.129028
# Iteration 9595 | Cost: 13.126778
# Iteration 9596 | Cost: 13.124527
# Iteration 9597 | Cost: 13.122278
# Iteration 9598 | Cost: 13.120029
# Iteration 9599 | Cost: 13.117780
# Iteration 9600 | Cost: 13.115532
# Iteration 9601 | Cost: 13.113285
# Iteration 9602 | Cost: 13.111038
# Iteration 9603 | Cost: 13.108792
# Iteration 9604 | Cost: 13.106546
# Iteration 9605 | Cost: 13.104301
# Iteration 9606 | Cost: 13.102057
# Iteration 9607 | Cost: 13.099813
# Iteration 9608 | Cost: 13.097569
# Iteration 9609 | Cost: 13.095327
# Iteration 9610 | Cost: 13.093084
# Iteration 9611 | Cost: 13.090843
# Iteration 9612 | Cost: 13.088602
# Iteration 9613 | Cost: 13.086361
# Iteration 9614 | Cost: 13.084121
# Iteration 9615 | Cost: 13.081882
# Iteration 9616 | Cost: 13.079643
# Iteration 9617 | Cost: 13.077405
# Iteration 9618 | Cost: 13.075167
# Iteration 9619 | Cost: 13.072930
# Iteration 9620 | Cost: 13.070693
# Iteration 9621 | Cost: 13.068457
# Iteration 9622 | Cost: 13.066222
# Iteration 9623 | Cost: 13.063987
# Iteration 9624 | Cost: 13.061753
# Iteration 9625 | Cost: 13.059519
# Iteration 9626 | Cost: 13.057286
# Iteration 9627 | Cost: 13.055053
# Iteration 9628 | Cost: 13.052821
# Iteration 9629 | Cost: 13.050590
# Iteration 9630 | Cost: 13.048359
# Iteration 9631 | Cost: 13.046128
# Iteration 9632 | Cost: 13.043899
# Iteration 9633 | Cost: 13.041670
# Iteration 9634 | Cost: 13.039441
# Iteration 9635 | Cost: 13.037213
# Iteration 9636 | Cost: 13.034985
# Iteration 9637 | Cost: 13.032758
# Iteration 9638 | Cost: 13.030532
# Iteration 9639 | Cost: 13.028306
# Iteration 9640 | Cost: 13.026081
# Iteration 9641 | Cost: 13.023856
# Iteration 9642 | Cost: 13.021632
# Iteration 9643 | Cost: 13.019409
# Iteration 9644 | Cost: 13.017186
# Iteration 9645 | Cost: 13.014963
# Iteration 9646 | Cost: 13.012741
# Iteration 9647 | Cost: 13.010520
# Iteration 9648 | Cost: 13.008299
# Iteration 9649 | Cost: 13.006079
# Iteration 9650 | Cost: 13.003860
# Iteration 9651 | Cost: 13.001641
# Iteration 9652 | Cost: 12.999422
# Iteration 9653 | Cost: 12.997204
# Iteration 9654 | Cost: 12.994987
# Iteration 9655 | Cost: 12.992770
# Iteration 9656 | Cost: 12.990554
# Iteration 9657 | Cost: 12.988338
# Iteration 9658 | Cost: 12.986123
# Iteration 9659 | Cost: 12.983909
# Iteration 9660 | Cost: 12.981695
# Iteration 9661 | Cost: 12.979481
# Iteration 9662 | Cost: 12.977268
# Iteration 9663 | Cost: 12.975056
# Iteration 9664 | Cost: 12.972844
# Iteration 9665 | Cost: 12.970633
# Iteration 9666 | Cost: 12.968423
# Iteration 9667 | Cost: 12.966213
# Iteration 9668 | Cost: 12.964003
# Iteration 9669 | Cost: 12.961794
# Iteration 9670 | Cost: 12.959586
# Iteration 9671 | Cost: 12.957378
# Iteration 9672 | Cost: 12.955171
# Iteration 9673 | Cost: 12.952964
# Iteration 9674 | Cost: 12.950758
# Iteration 9675 | Cost: 12.948552
# Iteration 9676 | Cost: 12.946347
# Iteration 9677 | Cost: 12.944143
# Iteration 9678 | Cost: 12.941939
# Iteration 9679 | Cost: 12.939736
# Iteration 9680 | Cost: 12.937533
# Iteration 9681 | Cost: 12.935331
# Iteration 9682 | Cost: 12.933129
# Iteration 9683 | Cost: 12.930928
# Iteration 9684 | Cost: 12.928728
# Iteration 9685 | Cost: 12.926528
# Iteration 9686 | Cost: 12.924328
# Iteration 9687 | Cost: 12.922129
# Iteration 9688 | Cost: 12.919931
# Iteration 9689 | Cost: 12.917733
# Iteration 9690 | Cost: 12.915536
# Iteration 9691 | Cost: 12.913339
# Iteration 9692 | Cost: 12.911143
# Iteration 9693 | Cost: 12.908948
# Iteration 9694 | Cost: 12.906753
# Iteration 9695 | Cost: 12.904559
# Iteration 9696 | Cost: 12.902365
# Iteration 9697 | Cost: 12.900171
# Iteration 9698 | Cost: 12.897979
# Iteration 9699 | Cost: 12.895787
# Iteration 9700 | Cost: 12.893595
# Iteration 9701 | Cost: 12.891404
# Iteration 9702 | Cost: 12.889213
# Iteration 9703 | Cost: 12.887023
# Iteration 9704 | Cost: 12.884834
# Iteration 9705 | Cost: 12.882645
# Iteration 9706 | Cost: 12.880457
# Iteration 9707 | Cost: 12.878269
# Iteration 9708 | Cost: 12.876082
# Iteration 9709 | Cost: 12.873895
# Iteration 9710 | Cost: 12.871709
# Iteration 9711 | Cost: 12.869524
# Iteration 9712 | Cost: 12.867339
# Iteration 9713 | Cost: 12.865154
# Iteration 9714 | Cost: 12.862971
# Iteration 9715 | Cost: 12.860787
# Iteration 9716 | Cost: 12.858605
# Iteration 9717 | Cost: 12.856422
# Iteration 9718 | Cost: 12.854241
# Iteration 9719 | Cost: 12.852060
# Iteration 9720 | Cost: 12.849879
# Iteration 9721 | Cost: 12.847699
# Iteration 9722 | Cost: 12.845520
# Iteration 9723 | Cost: 12.843341
# Iteration 9724 | Cost: 12.841163
# Iteration 9725 | Cost: 12.838985
# Iteration 9726 | Cost: 12.836808
# Iteration 9727 | Cost: 12.834631
# Iteration 9728 | Cost: 12.832455
# Iteration 9729 | Cost: 12.830279
# Iteration 9730 | Cost: 12.828104
# Iteration 9731 | Cost: 12.825930
# Iteration 9732 | Cost: 12.823756
# Iteration 9733 | Cost: 12.821583
# Iteration 9734 | Cost: 12.819410
# Iteration 9735 | Cost: 12.817238
# Iteration 9736 | Cost: 12.815066
# Iteration 9737 | Cost: 12.812895
# Iteration 9738 | Cost: 12.810724
# Iteration 9739 | Cost: 12.808554
# Iteration 9740 | Cost: 12.806385
# Iteration 9741 | Cost: 12.804216
# Iteration 9742 | Cost: 12.802047
# Iteration 9743 | Cost: 12.799880
# Iteration 9744 | Cost: 12.797712
# Iteration 9745 | Cost: 12.795546
# Iteration 9746 | Cost: 12.793379
# Iteration 9747 | Cost: 12.791214
# Iteration 9748 | Cost: 12.789049
# Iteration 9749 | Cost: 12.786884
# Iteration 9750 | Cost: 12.784720
# Iteration 9751 | Cost: 12.782557
# Iteration 9752 | Cost: 12.780394
# Iteration 9753 | Cost: 12.778231
# Iteration 9754 | Cost: 12.776070
# Iteration 9755 | Cost: 12.773908
# Iteration 9756 | Cost: 12.771748
# Iteration 9757 | Cost: 12.769588
# Iteration 9758 | Cost: 12.767428
# Iteration 9759 | Cost: 12.765269
# Iteration 9760 | Cost: 12.763110
# Iteration 9761 | Cost: 12.760952
# Iteration 9762 | Cost: 12.758795
# Iteration 9763 | Cost: 12.756638
# Iteration 9764 | Cost: 12.754482
# Iteration 9765 | Cost: 12.752326
# Iteration 9766 | Cost: 12.750171
# Iteration 9767 | Cost: 12.748016
# Iteration 9768 | Cost: 12.745862
# Iteration 9769 | Cost: 12.743709
# Iteration 9770 | Cost: 12.741555
# Iteration 9771 | Cost: 12.739403
# Iteration 9772 | Cost: 12.737251
# Iteration 9773 | Cost: 12.735100
# Iteration 9774 | Cost: 12.732949
# Iteration 9775 | Cost: 12.730798
# Iteration 9776 | Cost: 12.728649
# Iteration 9777 | Cost: 12.726500
# Iteration 9778 | Cost: 12.724351
# Iteration 9779 | Cost: 12.722203
# Iteration 9780 | Cost: 12.720055
# Iteration 9781 | Cost: 12.717908
# Iteration 9782 | Cost: 12.715762
# Iteration 9783 | Cost: 12.713616
# Iteration 9784 | Cost: 12.711470
# Iteration 9785 | Cost: 12.709325
# Iteration 9786 | Cost: 12.707181
# Iteration 9787 | Cost: 12.705037
# Iteration 9788 | Cost: 12.702894
# Iteration 9789 | Cost: 12.700751
# Iteration 9790 | Cost: 12.698609
# Iteration 9791 | Cost: 12.696468
# Iteration 9792 | Cost: 12.694327
# Iteration 9793 | Cost: 12.692186
# Iteration 9794 | Cost: 12.690046
# Iteration 9795 | Cost: 12.687907
# Iteration 9796 | Cost: 12.685768
# Iteration 9797 | Cost: 12.683630
# Iteration 9798 | Cost: 12.681492
# Iteration 9799 | Cost: 12.679355
# Iteration 9800 | Cost: 12.677218
# Iteration 9801 | Cost: 12.675082
# Iteration 9802 | Cost: 12.672946
# Iteration 9803 | Cost: 12.670811
# Iteration 9804 | Cost: 12.668676
# Iteration 9805 | Cost: 12.666542
# Iteration 9806 | Cost: 12.664409
# Iteration 9807 | Cost: 12.662276
# Iteration 9808 | Cost: 12.660144
# Iteration 9809 | Cost: 12.658012
# Iteration 9810 | Cost: 12.655881
# Iteration 9811 | Cost: 12.653750
# Iteration 9812 | Cost: 12.651620
# Iteration 9813 | Cost: 12.649490
# Iteration 9814 | Cost: 12.647361
# Iteration 9815 | Cost: 12.645232
# Iteration 9816 | Cost: 12.643104
# Iteration 9817 | Cost: 12.640977
# Iteration 9818 | Cost: 12.638850
# Iteration 9819 | Cost: 12.636723
# Iteration 9820 | Cost: 12.634597
# Iteration 9821 | Cost: 12.632472
# Iteration 9822 | Cost: 12.630347
# Iteration 9823 | Cost: 12.628223
# Iteration 9824 | Cost: 12.626099
# Iteration 9825 | Cost: 12.623976
# Iteration 9826 | Cost: 12.621853
# Iteration 9827 | Cost: 12.619731
# Iteration 9828 | Cost: 12.617610
# Iteration 9829 | Cost: 12.615489
# Iteration 9830 | Cost: 12.613368
# Iteration 9831 | Cost: 12.611248
# Iteration 9832 | Cost: 12.609129
# Iteration 9833 | Cost: 12.607010
# Iteration 9834 | Cost: 12.604891
# Iteration 9835 | Cost: 12.602774
# Iteration 9836 | Cost: 12.600656
# Iteration 9837 | Cost: 12.598540
# Iteration 9838 | Cost: 12.596423
# Iteration 9839 | Cost: 12.594308
# Iteration 9840 | Cost: 12.592193
# Iteration 9841 | Cost: 12.590078
# Iteration 9842 | Cost: 12.587964
# Iteration 9843 | Cost: 12.585850
# Iteration 9844 | Cost: 12.583737
# Iteration 9845 | Cost: 12.581625
# Iteration 9846 | Cost: 12.579513
# Iteration 9847 | Cost: 12.577402
# Iteration 9848 | Cost: 12.575291
# Iteration 9849 | Cost: 12.573181
# Iteration 9850 | Cost: 12.571071
# Iteration 9851 | Cost: 12.568961
# Iteration 9852 | Cost: 12.566853
# Iteration 9853 | Cost: 12.564745
# Iteration 9854 | Cost: 12.562637
# Iteration 9855 | Cost: 12.560530
# Iteration 9856 | Cost: 12.558423
# Iteration 9857 | Cost: 12.556317
# Iteration 9858 | Cost: 12.554212
# Iteration 9859 | Cost: 12.552107
# Iteration 9860 | Cost: 12.550002
# Iteration 9861 | Cost: 12.547899
# Iteration 9862 | Cost: 12.545795
# Iteration 9863 | Cost: 12.543692
# Iteration 9864 | Cost: 12.541590
# Iteration 9865 | Cost: 12.539488
# Iteration 9866 | Cost: 12.537387
# Iteration 9867 | Cost: 12.535286
# Iteration 9868 | Cost: 12.533186
# Iteration 9869 | Cost: 12.531087
# Iteration 9870 | Cost: 12.528988
# Iteration 9871 | Cost: 12.526889
# Iteration 9872 | Cost: 12.524791
# Iteration 9873 | Cost: 12.522693
# Iteration 9874 | Cost: 12.520596
# Iteration 9875 | Cost: 12.518500
# Iteration 9876 | Cost: 12.516404
# Iteration 9877 | Cost: 12.514309
# Iteration 9878 | Cost: 12.512214
# Iteration 9879 | Cost: 12.510120
# Iteration 9880 | Cost: 12.508026
# Iteration 9881 | Cost: 12.505933
# Iteration 9882 | Cost: 12.503840
# Iteration 9883 | Cost: 12.501748
# Iteration 9884 | Cost: 12.499656
# Iteration 9885 | Cost: 12.497565
# Iteration 9886 | Cost: 12.495474
# Iteration 9887 | Cost: 12.493384
# Iteration 9888 | Cost: 12.491295
# Iteration 9889 | Cost: 12.489206
# Iteration 9890 | Cost: 12.487117
# Iteration 9891 | Cost: 12.485029
# Iteration 9892 | Cost: 12.482942
# Iteration 9893 | Cost: 12.480855
# Iteration 9894 | Cost: 12.478769
# Iteration 9895 | Cost: 12.476683
# Iteration 9896 | Cost: 12.474598
# Iteration 9897 | Cost: 12.472513
# Iteration 9898 | Cost: 12.470429
# Iteration 9899 | Cost: 12.468345
# Iteration 9900 | Cost: 12.466262
# Iteration 9901 | Cost: 12.464179
# Iteration 9902 | Cost: 12.462097
# Iteration 9903 | Cost: 12.460015
# Iteration 9904 | Cost: 12.457934
# Iteration 9905 | Cost: 12.455854
# Iteration 9906 | Cost: 12.453774
# Iteration 9907 | Cost: 12.451694
# Iteration 9908 | Cost: 12.449615
# Iteration 9909 | Cost: 12.447537
# Iteration 9910 | Cost: 12.445459
# Iteration 9911 | Cost: 12.443382
# Iteration 9912 | Cost: 12.441305
# Iteration 9913 | Cost: 12.439229
# Iteration 9914 | Cost: 12.437153
# Iteration 9915 | Cost: 12.435077
# Iteration 9916 | Cost: 12.433003
# Iteration 9917 | Cost: 12.430929
# Iteration 9918 | Cost: 12.428855
# Iteration 9919 | Cost: 12.426782
# Iteration 9920 | Cost: 12.424709
# Iteration 9921 | Cost: 12.422637
# Iteration 9922 | Cost: 12.420565
# Iteration 9923 | Cost: 12.418494
# Iteration 9924 | Cost: 12.416424
# Iteration 9925 | Cost: 12.414354
# Iteration 9926 | Cost: 12.412284
# Iteration 9927 | Cost: 12.410215
# Iteration 9928 | Cost: 12.408147
# Iteration 9929 | Cost: 12.406079
# Iteration 9930 | Cost: 12.404012
# Iteration 9931 | Cost: 12.401945
# Iteration 9932 | Cost: 12.399878
# Iteration 9933 | Cost: 12.397813
# Iteration 9934 | Cost: 12.395747
# Iteration 9935 | Cost: 12.393683
# Iteration 9936 | Cost: 12.391618
# Iteration 9937 | Cost: 12.389555
# Iteration 9938 | Cost: 12.387491
# Iteration 9939 | Cost: 12.385429
# Iteration 9940 | Cost: 12.383367
# Iteration 9941 | Cost: 12.381305
# Iteration 9942 | Cost: 12.379244
# Iteration 9943 | Cost: 12.377183
# Iteration 9944 | Cost: 12.375123
# Iteration 9945 | Cost: 12.373064
# Iteration 9946 | Cost: 12.371005
# Iteration 9947 | Cost: 12.368946
# Iteration 9948 | Cost: 12.366888
# Iteration 9949 | Cost: 12.364831
# Iteration 9950 | Cost: 12.362774
# Iteration 9951 | Cost: 12.360718
# Iteration 9952 | Cost: 12.358662
# Iteration 9953 | Cost: 12.356606
# Iteration 9954 | Cost: 12.354552
# Iteration 9955 | Cost: 12.352497
# Iteration 9956 | Cost: 12.350443
# Iteration 9957 | Cost: 12.348390
# Iteration 9958 | Cost: 12.346337
# Iteration 9959 | Cost: 12.344285
# Iteration 9960 | Cost: 12.342234
# Iteration 9961 | Cost: 12.340182
# Iteration 9962 | Cost: 12.338132
# Iteration 9963 | Cost: 12.336082
# Iteration 9964 | Cost: 12.334032
# Iteration 9965 | Cost: 12.331983
# Iteration 9966 | Cost: 12.329934
# Iteration 9967 | Cost: 12.327886
# Iteration 9968 | Cost: 12.325839
# Iteration 9969 | Cost: 12.323792
# Iteration 9970 | Cost: 12.321745
# Iteration 9971 | Cost: 12.319699
# Iteration 9972 | Cost: 12.317654
# Iteration 9973 | Cost: 12.315609
# Iteration 9974 | Cost: 12.313564
# Iteration 9975 | Cost: 12.311520
# Iteration 9976 | Cost: 12.309477
# Iteration 9977 | Cost: 12.307434
# Iteration 9978 | Cost: 12.305392
# Iteration 9979 | Cost: 12.303350
# Iteration 9980 | Cost: 12.301309
# Iteration 9981 | Cost: 12.299268
# Iteration 9982 | Cost: 12.297228
# Iteration 9983 | Cost: 12.295188
# Iteration 9984 | Cost: 12.293149
# Iteration 9985 | Cost: 12.291110
# Iteration 9986 | Cost: 12.289072
# Iteration 9987 | Cost: 12.287034
# Iteration 9988 | Cost: 12.284997
# Iteration 9989 | Cost: 12.282960
# Iteration 9990 | Cost: 12.280924
# Iteration 9991 | Cost: 12.278888
# Iteration 9992 | Cost: 12.276853
# Iteration 9993 | Cost: 12.274819
# Iteration 9994 | Cost: 12.272785
# Iteration 9995 | Cost: 12.270751
# Iteration 9996 | Cost: 12.268718
# Iteration 9997 | Cost: 12.266685
# Iteration 9998 | Cost: 12.264653
# Iteration 9999 | Cost: 12.262622
# [21.30671996  1.13078708]

# %%
def get_one_hot(targets, nb_classes):
    res = np.eye(nb_classes)[np.array(targets).reshape(-1)]
    return res.reshape(list(targets.shape)+[nb_classes])

def quadKernel(X):
    quad = np.hstack((np.ones((X.shape[0],1)),X))
    for i in range(X.shape[1]):
        quad = np.hstack((quad,np.array([X[:,i]**2]).T))
    for i in range(X.shape[1]):
        for j in range(i+1,X.shape[1]):
            quad = np.hstack((quad, np.array([np.multiply(X[:,i],X[:,j])]).T     ))
    return quad

# %%
def gradientDescentLogisticMultiClass(x, y, W, alpha=0.01, numIterations=10000, beta = 0, verbose = False):
    m = x.shape[0]
    v = np.zeros(W.shape)
    J_hist = []
    W_hist = []
    for i in range(0, numIterations):
        
        hypothesis = softmax(x,W)
        loss = hypothesis-y
        cost = np.sum(loss ** 2) / (2 * m)
        J_hist.append(cost)  
        W_hist.append(W)
        if(verbose): print("Iteration %d | Cost: %f" % (i, cost))
        gradient = np.dot(x.transpose(), loss) / m
        v = beta*v + alpha*gradient
        W = W - v

    return (W, J_hist, W_hist)

# %%
def multiClassLogisticRegression(X_test, X_train, y_train, numClasses, numIterations = 2000, alpha = 0.001, beta = 0.9):
    old_y_train = y_train
    y_train = get_one_hot(y_train, numClasses)
    
#    X_train = np.hstack((np.array(np.ones((X_train.shape[0],1))),X_train))
#    X_test = np.hstack((np.array(np.ones((X_test.shape[0],1))),X_test))
    X_train = quadKernel(X_train)
    X_test = quadKernel(X_test)
    numFeatures = X_train.shape[1]
    W = np.random.rand(numFeatures, numClasses)/1000
    (W,J_hist, W_hist) = gradientDescentLogisticMultiClass(X_train, y_train, W, alpha = alpha, numIterations=numIterations, beta = beta, verbose = True)
    
    plt.plot(J_hist)
    
    y_pred = softmax(X_test,W)
    y_pred = np.argmax(y_pred, axis=1)
    
    return y_pred

# %%
def softmax(x,w):
    y_pred = np.exp(np.dot(x, w))
    rowsum = np.sum(y_pred, axis=1)
    y_pred = y_pred/rowsum[:, None]
    return y_pred

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareRailwayData(scale = 1)
y_pred = multiClassLogisticRegression(X_test, X_train, y_train, 2, 20000,0.000001, 0.999)
print("Accuracy, Logistic Regression, Railway Data (Test)", accuracy(y_pred, y_test))
#0.761
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-11e742751860> in <module>()
#       1 (X_train, y_train, X_val, y_val, X_test, y_test) = prepareRailwayData(scale = 1)
# ----> 2 y_pred = multiClassLogisticRegression(X_test, X_train, y_train, 2, 20000,0.000001, 0.999)
#       3 print("Accuracy, Logistic Regression, Railway Data (Test)", accuracy(y_pred, y_test))
#       4 #0.761
#
# <ipython-input-8-1af02d66dab1> in multiClassLogisticRegression(X_test, X_train, y_train, numClasses, numIterations, alpha, beta)
#       1 def multiClassLogisticRegression(X_test, X_train, y_train, numClasses, numIterations = 2000, alpha = 0.001, beta = 0.9):
#       2     old_y_train = y_train
# ----> 3     y_train = get_one_hot(y_train, numClasses)
#       4
#       5 #    X_train = np.hstack((np.array(np.ones((X_train.shape[0],1))),X_train))
#
# NameError: name 'get_one_hot' is not defined

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareRailwayData(scale = 1)
y_pred = multiClassLogisticRegression(X_train, X_train, y_train, 2, 20000,0.000001, 0.999)
print("Accuracy, Logistic Regression, Railway Data (Train)", accuracy(y_pred, y_train))
#0.799
# Out:
# Accuracy, Logistic Regression, Railway Data (Train) 0.8148487626031164

# %%
def multiClassLogisticRegression(X_test, X_train, y_train, numClasses, numIterations = 2000, alpha = 0.001, beta = 0.9):
    old_y_train = y_train
    y_train = get_one_hot(y_train, numClasses)
    
#    X_train = np.hstack((np.array(np.ones((X_train.shape[0],1))),X_train))
#    X_test = np.hstack((np.array(np.ones((X_test.shape[0],1))),X_test))

    X_train = quadKernel(X_train)
    X_test = quadKernel(X_test)
    numFeatures = X_train.shape[1]
    W = np.random.rand(numFeatures, numClasses)/1000
    (W,J_hist, W_hist) = gradientDescentLogisticMultiClass(X_train, y_train, W, alpha = alpha, numIterations=numIterations, beta = beta, verbose = False)
    
    plt.plot(J_hist)
    
    y_pred = softmax(X_test,W)
    y_pred = np.argmax(y_pred, axis=1)
    
    return y_pred

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareMedicalData()
y_pred = multiClassLogisticRegression(X_test, X_train, y_train, 3, 10000, 0.00001, 0.999)
print("Accuracy, Logistic Regression, Medical Data (Test)", accuracy(y_pred, y_test))
# Out:
# Accuracy, Logistic Regression, Medical Data (Test) 0.8996666666666666

# %% [markdown]
# # OneVsAll
# - Have to train 3 classifiers
# - Conflict --> Rejection Class

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareMedicalData()
numClasses = 3
X_train = quadKernel(X_train)
X_test = quadKernel(X_test)
numFeatures = X_train.shape[1]
y_train = get_one_hot(y_train, numClasses)

y_pred = []
for index in range(numClasses):    
    y_train_index = np.array([y_train[:,index]]).T
    y_train_index = np.hstack(  (1 - y_train_index, y_train_index )  )
    #NotIndex, Index

    W = np.random.rand(numFeatures, 2)/1000
    (W, J_hist, W_hist) = gradientDescentLogisticMultiClass(X_train, y_train_index, W, alpha = 0.00001, numIterations=1000, beta = 0.99, verbose = False)
    plt.plot(J_hist)
    #W represents individual classifiers
    
    y_pred_index = softmax(X_test,W)
    y_pred_index = np.argmax(y_pred_index, axis=1)
    y_pred.append(y_pred_index)

y_pred = np.array(y_pred).T


legitIndices = np.where(np.sum(y_pred, axis = 1) ==1)[0]
rejectedIndices = np.where(np.sum(y_pred, axis = 1) != 1)[0]

print("OneVsAll Logistic Regression, Only good points, Medical Data (Test)", accuracy(y_pred[legitIndices].argmax(axis = 1), y_test[legitIndices]))
print("OneVsAll Logistic Regression, All points, Medical Data (Test)", accuracy(y_pred.argmax(axis = 1), y_test))
# Out:
# OneVsAll Logistic Regression, Only good points, Medical Data (Test) 0.8773873185637892
# OneVsAll Logistic Regression, All points, Medical Data (Test) 0.8223333333333334

# %% [markdown]
# # Comments:
#     - None, really
#     - For some reason, One vs All method is worse than softmax even when accounting only for those points that are classified without collision
#     - When accounting for collisions (which occur 382/3000 times), accuracy gets much worse

# %%
rejectedIndices.shape
# Out:
# (382,)

# %%
#This is worse than normal, even when only including legit indices

# %%
accuracy(y_pred.argmax(axis = 1), y_test)
# Out:
# 0.8223333333333334

# %%
def perceptron(X_test, X_train, y_train):
    ## assumes class labels as 0 and 1
    numFeatures = X_train.shape[1]
    X_train = np.hstack((np.array(np.ones((X_train.shape[0],1))),X_train))
    X_test = np.hstack((np.array(np.ones((X_test.shape[0],1))),X_test))

    W = np.zeros(numFeatures+1)
    acc_test = []
    acc_train = []
    for idx in range(X_train.shape[0]):
        y = np.dot(X_train[idx], W)
        if(y > 0):
            y = 1
        else:
            y = 0
        W = W + 0.0001*(y_train[idx]-y)*X_train[idx].T
        acc_test.append(accuracy(y_test, np.dot(X_test, W) > 0))
        acc_train.append(accuracy(y_train, np.dot(X_train, W)> 0))
    y_pred = np.zeros(X_test.shape[0])
    plt.plot(acc_test, label='test')
    plt.plot(acc_train, label='train')
    plt.legend()
    for idx in range(X_test.shape[0]):
        y = np.dot(X_test[idx], W)
        if(y > 0):
            y_pred[idx] = 1
        else:
            y_pred[idx] = 0
            
    return y_pred

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareRailwayData(scale = 1)
y_pred = perceptron(X_test, X_train, y_train)
print(accuracy(y_pred, y_test))
# Out:
# 0.6605504587155964

# %% [markdown]
# ##### Train accuracy more volatile than test
# ##### Multiple y for same x, outliers -> one reason
# ##### Many points concentrated near the hyper plane. Hence one misclassification

# %% [markdown]
# ###  SVM

# %%
#Default SVM
import cvxopt
def linear_kernel(x1, x2):
    return np.dot(x1, x2)

def polynomial_kernel(x, y, p=3):
    return (1 + np.dot(x, y)) ** p

def gaussian_kernel(x, y, sigma=1):
    return np.exp(-linalg.norm(x-y)**2 / (2 * (sigma ** 2)))

def sigmoidal_kernel(x,y, a = 1, theta = 0):
    return np.tanh(a*np.dot(x,y) + theta)


class SVM(object):

    def __init__(self, kernel=linear_kernel, C=None):
        self.kernel = kernel
        self.C = C
        if self.C is not None: self.C = float(self.C)

    def fit(self, X, y):
        n_samples, n_features = X.shape
        #y = np.array([y]).T

        # Gram matrix
        K = np.zeros((n_samples, n_samples))
        for i in range(n_samples):
            for j in range(n_samples):
                K[i,j] = self.kernel(X[i], X[j])

        P = cvxopt.matrix(np.multiply(np.matmul(np.array([y]).T, np.array([y])),K)) 
        q = cvxopt.matrix(-1 * np.ones(n_samples) )
        A = cvxopt.matrix(y, (1,n_samples),'d')
        b = cvxopt.matrix(0.0)
        
        if self.C is None:
            G = cvxopt.matrix(np.diag(np.ones(n_samples) * -1))
            h = cvxopt.matrix(np.zeros(n_samples))
        else:
            G = cvxopt.matrix(np.vstack((np.diag(np.ones(n_samples) * -1), np.identity(n_samples))))
            h = cvxopt.matrix(np.hstack((np.zeros(n_samples), np.ones(n_samples) * self.C)))

        # solve QP problem
        #cvxopt_solvers.options['show_progress'] = False
        solution = cvxopt.solvers.qp(P, q, G, h, A, b)
        
        # Lagrange multipliers
        a = np.ravel(solution['x'])

        # Support vectors have non zero lagrange multipliers
        sv = a > 1e-5
        ind = np.arange(len(a))[sv]
        self.a = a[sv]
        self.sv = X[sv]
        self.sv_y = y[sv]
        print("%d support vectors out of %d points" % (len(self.a), n_samples))

        
        self.b = np.mean(y[sv]) - np.sum((np.dot(K[sv,:][:,sv], np.multiply(a[sv],y[sv])))/np.sum(sv))   
        print(self.b)

     
        if self.kernel == linear_kernel:
            self.w = np.dot(np.multiply(a, y), X) 
        else:
            self.w = None
                        
        return a
        
    def project(self, X):
        if self.w is not None:
            return np.dot(X, self.w) + self.b
        else:
            y_predict = np.zeros(len(X))
            s = np.zeros(X.shape[0])
            for a,sv_y,sv in zip(self.a, self.sv_y, self.sv):
                s += a*sv_y * self.kernel(X, sv)
            y_predict = s
            return y_predict + self.b

    def predict(self, X):
        return np.sign(self.project(X))

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareMedicalData()
X_train = X_train[:1000,:]
y_train = y_train[:1000]
X_test = X_test[:400,:]
y_test = y_test[:400]

clf = SVM(kernel = polynomial_kernel, C = 10)
y_train = (y_train==1)*2 - 1
y_test = (y_test==1)*2 - 1

a = clf.fit(X_train, y_train)
#print(a[a>1e-5])
y_pred = clf.predict(X_test)
print("Accuracy", accuracy(y_pred, y_test))
print("Precision", precision(y_pred, y_test, 1))
print("Recall", recall(y_pred, y_test, 1))

#Gaussian: .89, .87, .82
#Polynomial(3): .91, .87, .86
#Polynomial(2): .915, .84, .902
#Linear: .81, .74, .71
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -2.0435e+03 -8.6568e+04  2e+05  9e-01  5e-11
#  1: -1.8184e+03 -3.6735e+04  5e+04  2e-01  3e-11
#  2: -1.6945e+03 -2.1565e+04  3e+04  8e-02  3e-11
#  3: -1.5851e+03 -1.4141e+04  2e+04  4e-02  3e-11
#  4: -1.5803e+03 -8.9002e+03  1e+04  2e-02  4e-11
#  5: -1.5976e+03 -6.2198e+03  6e+03  1e-02  3e-11
#  6: -1.6347e+03 -5.1131e+03  4e+03  6e-03  3e-11
#  7: -1.7183e+03 -4.1305e+03  3e+03  4e-03  3e-11
#  8: -1.8299e+03 -3.2268e+03  2e+03  2e-03  4e-11
#  9: -1.8868e+03 -2.8189e+03  1e+03  1e-03  4e-11
# 10: -1.9230e+03 -2.5719e+03  8e+02  5e-04  5e-11
# 11: -1.9550e+03 -2.3763e+03  5e+02  3e-04  4e-11
# 12: -1.9537e+03 -2.3267e+03  4e+02  2e-04  5e-11
# 13: -1.9477e+03 -2.3005e+03  4e+02  1e-04  4e-11
# 14: -1.9833e+03 -2.1844e+03  2e+02  7e-05  4e-11
# 15: -2.0069e+03 -2.1148e+03  1e+02  3e-05  4e-11
# 16: -2.0036e+03 -2.1105e+03  1e+02  2e-05  4e-11
# 17: -2.0200e+03 -2.0776e+03  6e+01  9e-06  5e-11
# 18: -2.0299e+03 -2.0559e+03  3e+01  1e-06  5e-11
# 19: -2.0370e+03 -2.0464e+03  1e+01  3e-07  5e-11
# 20: -2.0379e+03 -2.0452e+03  7e+00  2e-07  4e-11
# 21: -2.0403e+03 -2.0420e+03  2e+00  5e-09  6e-11
# 22: -2.0408e+03 -2.0414e+03  6e-01  2e-09  5e-11
# 23: -2.0411e+03 -2.0412e+03  8e-02  2e-16  5e-11
# 24: -2.0411e+03 -2.0411e+03  2e-03  9e-14  6e-11
# Optimal solution found.
# 232 support vectors out of 1000 points
# 3.317856008885697
# Accuracy 0.9075
# Precision 0.8642857142857143
# Recall 0.8705035971223022

# %% [markdown]
# # One vs All SVM

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareMedicalData()
#X_train = X_train[:1000,:]
#y_train = y_train[:1000]
#X_test = X_test[:400,:]
#y_test = y_test[:400]

numClasses = 3
numFeatures = X_train.shape[1]
y_pred = []


print("Data Ready")
for index in range(numClasses):    

    y_train_index = (y_train==index)*2 - 1
    y_test_index = (y_test == index)*2 - 1

    clf = SVM(kernel = polynomial_kernel, C = 1)
    clf.fit(X_train, y_train_index)
    y_pred_index = clf.predict(X_test)
    y_pred.append(y_pred_index)
            
y_pred = np.array(y_pred).T
# Out:
# Data Ready
#      pcost       dcost       gap    pres   dres
#  0: -7.9972e+02 -7.8666e+03  5e+04  4e+00  1e-12
#  1: -5.0185e+02 -5.3588e+03  9e+03  4e-01  8e-13
#  2: -4.4617e+02 -2.4298e+03  3e+03  1e-01  6e-13
#  3: -4.4068e+02 -1.6344e+03  2e+03  7e-02  6e-13
#  4: -4.4277e+02 -1.2565e+03  1e+03  4e-02  6e-13
#  5: -4.4350e+02 -1.1002e+03  9e+02  3e-02  6e-13
#  6: -4.5179e+02 -8.2665e+02  5e+02  2e-02  6e-13
#  7: -4.5030e+02 -7.8224e+02  5e+02  1e-02  6e-13
#  8: -4.5394e+02 -6.8056e+02  3e+02  8e-03  6e-13
#  9: -4.5510e+02 -6.1064e+02  2e+02  5e-03  6e-13
# 10: -4.5486e+02 -5.6912e+02  2e+02  3e-03  7e-13
# 11: -4.5274e+02 -5.6118e+02  2e+02  3e-03  6e-13
# 12: -4.5149e+02 -5.4005e+02  1e+02  2e-03  7e-13
# 13: -4.5053e+02 -5.2879e+02  1e+02  1e-03  6e-13
# 14: -4.5823e+02 -4.8858e+02  4e+01  5e-04  7e-13
# 15: -4.6157e+02 -4.7537e+02  2e+01  2e-04  8e-13
# 16: -4.6312e+02 -4.6809e+02  5e+00  4e-06  8e-13
# 17: -4.6432e+02 -4.6661e+02  2e+00  1e-06  8e-13
# 18: -4.6497e+02 -4.6586e+02  9e-01  2e-07  8e-13
# 19: -4.6522e+02 -4.6557e+02  4e-01  6e-09  9e-13
# 20: -4.6538e+02 -4.6541e+02  3e-02  2e-10  9e-13
# 21: -4.6539e+02 -4.6540e+02  2e-03  1e-11  9e-13
# 22: -4.6540e+02 -4.6540e+02  2e-05  2e-13  9e-13
# Optimal solution found.
# 476 support vectors out of 2500 points
#      pcost       dcost       gap    pres   dres
#  0: -1.1188e+03 -7.5359e+03  5e+04  4e+00  1e-12
#  1: -7.2885e+02 -5.1540e+03  7e+03  3e-01  1e-12
#  2: -6.9245e+02 -3.5135e+03  4e+03  2e-01  9e-13
#  3: -6.8393e+02 -3.0764e+03  4e+03  1e-01  9e-13
#  4: -6.7109e+02 -2.9628e+03  3e+03  1e-01  9e-13
#  5: -6.5200e+02 -2.8648e+03  3e+03  1e-01  8e-13
#  6: -6.1660e+02 -2.4635e+03  3e+03  7e-02  8e-13
#  7: -5.9666e+02 -2.3106e+03  3e+03  6e-02  9e-13
#  8: -5.7866e+02 -1.9933e+03  2e+03  4e-02  9e-13
#  9: -5.6345e+02 -1.7389e+03  2e+03  3e-02  9e-13
# 10: -5.4314e+02 -1.5254e+03  1e+03  2e-02  1e-12
# 11: -5.1738e+02 -1.2568e+03  1e+03  1e-02  1e-12
# 12: -5.0601e+02 -1.1155e+03  9e+02  9e-03  1e-12
# 13: -5.0164e+02 -8.7978e+02  5e+02  5e-03  1e-12
# 14: -5.0159e+02 -7.0556e+02  3e+02  2e-03  1e-12
# 15: -5.0827e+02 -6.3764e+02  2e+02  1e-03  1e-12
# 16: -5.1716e+02 -5.9038e+02  9e+01  5e-04  1e-12
# 17: -5.2260e+02 -5.6503e+02  5e+01  2e-04  1e-12
# 18: -5.2701e+02 -5.5037e+02  2e+01  5e-05  1e-12
# 19: -5.2990e+02 -5.4397e+02  1e+01  1e-05  1e-12
# 20: -5.3302e+02 -5.3958e+02  7e+00  5e-06  1e-12
# 21: -5.3413e+02 -5.3790e+02  4e+00  1e-06  1e-12
# 22: -5.3510e+02 -5.3677e+02  2e+00  4e-07  1e-12
# 23: -5.3571e+02 -5.3609e+02  4e-01  4e-15  2e-12
# 24: -5.3587e+02 -5.3592e+02  4e-02  6e-14  2e-12
# 25: -5.3589e+02 -5.3590e+02  6e-04  3e-14  2e-12
# 26: -5.3590e+02 -5.3590e+02  6e-06  2e-14  2e-12
# Optimal solution found.
# 554 support vectors out of 2500 points
#      pcost       dcost       gap    pres   dres
#  0: -1.0913e+03 -8.3954e+03  6e+04  4e+00  2e-12
#  1: -7.0768e+02 -5.9875e+03  1e+04  4e-01  1e-12
#  2: -6.7917e+02 -3.7058e+03  5e+03  2e-01  1e-12
#  3: -6.7597e+02 -2.4468e+03  3e+03  1e-01  9e-13
#  4: -6.6021e+02 -2.3275e+03  3e+03  9e-02  9e-13
#  5: -6.4516e+02 -1.9936e+03  2e+03  7e-02  7e-13
#  6: -6.3416e+02 -1.9487e+03  2e+03  6e-02  8e-13
#  7: -6.0616e+02 -1.7438e+03  2e+03  5e-02  7e-13
#  8: -5.8513e+02 -1.6077e+03  2e+03  4e-02  7e-13
#  9: -5.4446e+02 -1.4650e+03  1e+03  3e-02  6e-13
# 10: -5.2648e+02 -1.3494e+03  1e+03  2e-02  6e-13
# 11: -4.9329e+02 -1.1314e+03  1e+03  1e-02  7e-13
# 12: -4.7946e+02 -1.0293e+03  8e+02  1e-02  7e-13
# 13: -4.6842e+02 -8.1720e+02  5e+02  5e-03  8e-13
# 14: -4.6495e+02 -7.0804e+02  3e+02  3e-03  8e-13
# 15: -4.7140e+02 -5.9814e+02  2e+02  1e-03  8e-13
# 16: -4.7912e+02 -5.5045e+02  9e+01  6e-04  9e-13
# 17: -4.8505e+02 -5.2450e+02  5e+01  3e-04  1e-12
# 18: -4.8857e+02 -5.1007e+02  2e+01  8e-05  1e-12
# 19: -4.9017e+02 -5.0432e+02  1e+01  3e-05  1e-12
# 20: -4.9228e+02 -5.0103e+02  9e+00  1e-05  1e-12
# 21: -4.9379e+02 -4.9885e+02  5e+00  7e-06  1e-12
# 22: -4.9509e+02 -4.9701e+02  2e+00  1e-06  1e-12
# 23: -4.9560e+02 -4.9639e+02  8e-01  5e-07  1e-12
# 24: -4.9582e+02 -4.9613e+02  3e-01  2e-07  1e-12
# 25: -4.9592e+02 -4.9601e+02  9e-02  4e-14  1e-12
# 26: -4.9596e+02 -4.9597e+02  4e-03  1e-13  1e-12
# 27: -4.9596e+02 -4.9596e+02  2e-04  8e-14  1e-12
# Optimal solution found.
# 521 support vectors out of 2500 points

# %%
legitIndices = (np.sum((y_pred==1), axis = 1)==1)
rejectedIndices = (np.sum((y_pred==1), axis = 1)!=1)
print("No. of legit indices = ", legitIndices.shape[0])

print("Accuracy, SVM oneVall, polynomial Kernel, good points only = ", accuracy(y_pred[legitIndices].argmax(axis = 1), y_test[legitIndices]))
#0.94717
print("Accuracy, SVM oneVall, polynomial Kernel, All points = ", accuracy(y_pred.argmax(axis = 1), y_test))
#0..8516
# Out:
# No. of legit indices =  3000
# Accuracy, SVM oneVall, polynomial Kernel, good points only =  0.9471759447379114
# Accuracy, SVM oneVall, polynomial Kernel, All points =  0.8516666666666667

# %%
# Out:
# array([0, 0, 0, ..., 0, 2, 1])

# %% [markdown]
# # One-vs-One SVM

# %%
#One-vs-One
# Out:
# Data Ready
# Class  0  vs  1
#      pcost       dcost       gap    pres   dres
#  0: -3.9572e+02 -5.1273e+03  4e+04  4e+00  1e-12
#  1: -2.4731e+02 -3.3781e+03  6e+03  4e-01  8e-13
#  2: -2.2364e+02 -1.6282e+03  2e+03  1e-01  6e-13
#  3: -2.1906e+02 -9.1812e+02  1e+03  6e-02  5e-13
#  4: -2.0871e+02 -7.5077e+02  9e+02  4e-02  5e-13
#  5: -2.0198e+02 -7.3757e+02  9e+02  4e-02  5e-13
#  6: -1.8665e+02 -6.5573e+02  8e+02  3e-02  4e-13
#  7: -1.7819e+02 -5.6460e+02  6e+02  2e-02  4e-13
#  8: -1.6970e+02 -5.1299e+02  6e+02  2e-02  5e-13
#  9: -1.6347e+02 -4.5094e+02  5e+02  1e-02  4e-13
# 10: -1.5853e+02 -3.4179e+02  3e+02  8e-03  5e-13
# 11: -1.5587e+02 -2.6944e+02  2e+02  4e-03  6e-13
# 12: -1.5490e+02 -2.1278e+02  9e+01  2e-03  7e-13
# 13: -1.5393e+02 -1.9122e+02  5e+01  8e-04  7e-13
# 14: -1.5504e+02 -1.7965e+02  3e+01  4e-04  8e-13
# 15: -1.5229e+02 -1.7712e+02  3e+01  2e-04  8e-13
# 16: -1.5327e+02 -1.7389e+02  2e+01  1e-04  7e-13
# 17: -1.5312e+02 -1.7322e+02  2e+01  9e-05  8e-13
# 18: -1.5578e+02 -1.6800e+02  1e+01  4e-05  8e-13
# 19: -1.5712e+02 -1.6534e+02  8e+00  2e-05  8e-13
# 20: -1.5888e+02 -1.6259e+02  4e+00  2e-06  9e-13
# 21: -1.5969e+02 -1.6158e+02  2e+00  9e-07  8e-13
# 22: -1.5992e+02 -1.6123e+02  1e+00  2e-07  9e-13
# 23: -1.6031e+02 -1.6077e+02  5e-01  3e-09  9e-13
# 24: -1.6046e+02 -1.6061e+02  2e-01  4e-10  9e-13
# 25: -1.6054e+02 -1.6054e+02  4e-03  1e-11  9e-13
# 26: -1.6054e+02 -1.6054e+02  2e-04  4e-13  9e-13
# 27: -1.6054e+02 -1.6054e+02  3e-06  7e-15  1e-12
# Optimal solution found.
# 174 support vectors out of 1677 points
# Class  0  vs  2
#      pcost       dcost       gap    pres   dres
#  0: -4.0817e+02 -5.0933e+03  4e+04  4e+00  6e-13
#  1: -2.4933e+02 -3.3843e+03  6e+03  4e-01  7e-13
#  2: -2.2184e+02 -1.8350e+03  3e+03  2e-01  5e-13
#  3: -2.0889e+02 -1.1193e+03  1e+03  9e-02  4e-13
#  4: -2.0129e+02 -9.4878e+02  1e+03  7e-02  4e-13
#  5: -1.9057e+02 -9.2151e+02  1e+03  6e-02  4e-13
#  6: -1.8428e+02 -8.8679e+02  1e+03  6e-02  4e-13
#  7: -1.7261e+02 -7.9410e+02  1e+03  5e-02  3e-13
#  8: -1.6376e+02 -7.4088e+02  1e+03  4e-02  3e-13
#  9: -1.5502e+02 -6.7770e+02  9e+02  3e-02  3e-13
# 10: -1.4439e+02 -5.5758e+02  7e+02  2e-02  3e-13
# 11: -1.3762e+02 -5.0022e+02  6e+02  2e-02  3e-13
# 12: -1.2673e+02 -3.6711e+02  4e+02  1e-02  3e-13
# 13: -1.1877e+02 -2.8274e+02  3e+02  6e-03  3e-13
# 14: -1.1512e+02 -1.8302e+02  1e+02  2e-03  4e-13
# 15: -1.1822e+02 -1.4242e+02  3e+01  4e-04  4e-13
# 16: -1.1979e+02 -1.3360e+02  2e+01  2e-04  4e-13
# 17: -1.2107e+02 -1.2983e+02  1e+01  8e-05  4e-13
# 18: -1.2127e+02 -1.2723e+02  6e+00  9e-15  5e-13
# 19: -1.2259e+02 -1.2558e+02  3e+00  2e-14  5e-13
# 20: -1.2309e+02 -1.2495e+02  2e+00  5e-15  4e-13
# 21: -1.2349e+02 -1.2444e+02  9e-01  5e-15  5e-13
# 22: -1.2386e+02 -1.2403e+02  2e-01  9e-15  5e-13
# 23: -1.2394e+02 -1.2395e+02  2e-03  5e-15  5e-13
# 24: -1.2394e+02 -1.2394e+02  4e-05  4e-15  5e-13
# Optimal solution found.
# 137 support vectors out of 1647 points
# Class  1  vs  2
#      pcost       dcost       gap    pres   dres
#  0: -7.2678e+02 -3.9913e+03  2e+04  3e+00  1e-12
#  1: -5.1428e+02 -2.6538e+03  4e+03  5e-01  1e-12
#  2: -4.8207e+02 -1.6190e+03  2e+03  2e-01  7e-13
#  3: -4.6871e+02 -1.3027e+03  1e+03  1e-01  7e-13
#  4: -4.4694e+02 -1.2231e+03  1e+03  1e-01  6e-13
#  5: -4.2009e+02 -1.0322e+03  1e+03  8e-02  6e-13
#  6: -3.9909e+02 -8.1495e+02  8e+02  5e-02  6e-13
#  7: -3.8054e+02 -7.0899e+02  7e+02  4e-02  6e-13
#  8: -3.6553e+02 -6.2927e+02  6e+02  3e-02  6e-13
#  9: -3.4895e+02 -5.3804e+02  4e+02  2e-02  6e-13
# 10: -3.3530e+02 -4.8147e+02  4e+02  2e-02  6e-13
# 11: -3.2035e+02 -4.3898e+02  3e+02  1e-02  6e-13
# 12: -3.0063e+02 -4.2028e+02  3e+02  9e-03  6e-13
# 13: -2.8251e+02 -3.9382e+02  2e+02  6e-03  7e-13
# 14: -2.7389e+02 -3.5524e+02  1e+02  3e-03  7e-13
# 15: -2.7045e+02 -3.1387e+02  7e+01  1e-03  8e-13
# 16: -2.7502e+02 -2.8436e+02  1e+01  2e-04  9e-13
# 17: -2.7595e+02 -2.7999e+02  5e+00  7e-05  9e-13
# 18: -2.7676e+02 -2.7760e+02  9e-01  2e-06  1e-12
# 19: -2.7713e+02 -2.7716e+02  4e-02  6e-08  1e-12
# 20: -2.7715e+02 -2.7715e+02  6e-04  1e-09  1e-12
# 21: -2.7715e+02 -2.7715e+02  7e-06  1e-11  1e-12
# Optimal solution found.
# 304 support vectors out of 1676 points

# %%
#One-vs-One

(X_train, y_train, X_val, y_val, X_test, y_test) = prepareMedicalData()
#X_train = X_train[:1000,:]
#y_train = y_train[:1000]
#X_test = X_test[:400,:]
#y_test = y_test[:400]


numClasses = 3
numFeatures = X_train.shape[1]
y_pred = []

print("Data Ready")

y_pred_oVo = np.zeros((numClasses, numClasses, X_test.shape[0]))
for i in range(numClasses):
    for j in range(i+1, numClasses):
        print("Class ", i, " vs ", j)
        #i-->1, j-->-1
        relevantIndices = np.logical_or((y_train == i),(y_train == j))
        clf = SVM(kernel = polynomial_kernel, C = 1)
        clf.fit(X_train[relevantIndices], (y_train[relevantIndices] == i)*2 - 1)

        y_pred_oVo[i,j,:] = clf.predict(X_test)
        y_pred_oVo[j,i,:] = - clf.predict(X_test)
        #y_pred[i][j] ==1 --> i beat j

# %%
#legitIndices = (np.max(np.sum(y_pred_oVo, axis = 0), axis = 0) == numClasses - 1)
y_pred = np.argmax(np.sum(y_pred_oVo, axis = 1), axis = 0)
print("Accuracy", accuracy(y_pred, y_test))
# Out:
# Accuracy 0.8966666666666666

# %% [markdown]
# # One vs All Plot

# %%
# %matplotlib notebook
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareMedicalData()
X_train = X_train[:600,:]
y_train = y_train[:600]
X_test = X_train[:600,:]
y_test = y_test[:600]


from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

for y in range(np.max(y_train)+1):
    X = X_train[np.where(y_train==y)[0]]
    ax.scatter(X[:,0], X[:,1], X[:,2], label = str(y))

#ax.scatter(clf.sv[:,0], clf.sv[:,1], clf.sv[:,2], s = 100, label = "Support Vectors")


plt.xlabel('Test1')
plt.ylabel('Test2')
#plt.zlabel('Test3')

plt.title('Polynomial Kernel, SVM seperating Class 1')


X1, X2, X3 = np.meshgrid(np.linspace(-5,5,50), np.linspace(-2,5,50), np.linspace(-1,4,50))
X = np.array([[x1, x2, x3] for x1, x2, x3 in zip(np.ravel(X1), np.ravel(X2), np.ravel(X3))])
Z = clf.project(X).reshape(X1.shape)
contour = [np.abs(Z)<=.2]
X = X1[contour]
Y = X2[contour]
Z = X3[contour]

surf = ax.scatter(X, Y, Z, alpha = 0.3, linewidth=1, label = 'Decision Boundary')

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:31: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:32: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareRailwayData(scale = 1)
clf = SVM(C = .1)
y_train = 2*y_train - 1
y_test = 2*y_test - 1
a = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Accuracy", accuracy(y_pred, y_test))
print("Recall", recall(y_pred, y_test, 1))
print("Precision", precision(y_pred, y_test, 1))
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -3.5780e+02 -2.6384e+02  1e+04  3e+01  2e-14
#  1: -5.3842e+01 -2.5005e+02  5e+02  9e-01  2e-14
#  2: -4.2807e+01 -1.0806e+02  7e+01  3e-02  4e-15
#  3: -4.5622e+01 -5.7789e+01  1e+01  5e-03  4e-15
#  4: -4.5996e+01 -4.7788e+01  2e+00  1e-14  4e-15
#  5: -4.6253e+01 -4.6280e+01  3e-02  7e-15  3e-15
#  6: -4.6256e+01 -4.6256e+01  3e-04  9e-16  3e-15
#  7: -4.6256e+01 -4.6256e+01  3e-06  4e-15  3e-15
# Optimal solution found.
# 1091 support vectors out of 1091 points
# Accuracy 0.7247706422018348
# Recall 0.7952755905511811
# Precision 0.7481481481481481

# %%
def FLDA(X_train, y_train):
    X1 = X_train[np.where(y_train == 0)]
    X2 = X_train[np.where(y_train == 1)]
    m1 = np.array([X1.mean(axis=0)])
    m2 = np.array([X2.mean(axis=0)])
    d = X_train.shape[1]
    Sw = np.zeros([d, d])     
    Sw += np.dot((X1-m1).T, X1-m1)

    Sw += np.dot((X2-m2).T, X2 - m2)
    w = np.dot(m2-m1, np.linalg.pinv(Sw)).T
    return w

def multiClassFLDA(X_train, y_train):
    n = X_train.shape[0]
    d = X_train.shape[1]
    A = np.unique(y_train)
    k = len(A)
    class_means = np.zeros([k,d])
    N = np.zeros(k)
    for i in range(k):
        X = X_train[np.where(y_train == A[i])]
        class_means[i] = np.array([X.mean(axis=0)])
        N[i] = X.shape[0]
    overall_mean = np.array([X_train.mean(axis=0)])
    S_B = np.zeros([d,d])
    for i in range(k):
        S_B += N[i]*np.dot((class_means[i]-overall_mean).T, (class_means[i]-overall_mean))

    S_T = np.zeros([d,d])
    S_T += np.dot((X_train - overall_mean).T, X_train - overall_mean)

    S_W = np.subtract(S_T,S_B)
    mat = np.dot(np.linalg.pinv(S_W), S_B)
    
    eigvals, eigvecs = np.linalg.eig(mat)
    eiglist = [(eigvals[i], eigvecs[:, i]) for i in range(len(eigvals))]
    eiglist = sorted(eiglist, key = lambda x : x[0], reverse = True)
    w = np.array([eiglist[i][1] for i in range(k-1)])
    return w

# %%
def multiClassLogisticRegression(X_test, X_train, y_train, numClasses, numIterations = 2000, alpha = 0.001, beta = 0.9):
    old_y_train = y_train
    y_train = get_one_hot(y_train, numClasses)
    
    X_train = np.hstack((np.array(np.ones((X_train.shape[0],1))),X_train))
    X_test = np.hstack((np.array(np.ones((X_test.shape[0],1))),X_test))
#     X_train = quadKernel(X_train)
    print(X_train.shape)
#     X_test = quadKernel(X_test)
    numFeatures = X_train.shape[1]
    W = np.random.rand(numFeatures, numClasses)/1000
    (W,J_hist, W_hist) = gradientDescentLogisticMultiClass(X_train, y_train, W, alpha = alpha, numIterations=numIterations, beta = beta, verbose = True)
    
    plt.plot(J_hist)
    
    y_pred = softmax(X_test,W)
    y_pred = np.argmax(y_pred, axis=1)
    
    return y_pred

# %%
def quadKernel(X):
    quad = np.hstack((np.ones((X.shape[0],1)),X))
    for i in range(X.shape[1]):
        quad = np.hstack((quad,np.array([X[:,i]**2]).T))
    for i in range(X.shape[1]):
        for j in range(i+1,X.shape[1]):
            quad = np.hstack((quad, np.array([np.multiply(X[:,i],X[:,j])]).T     ))
    return quad

# %%
# %%time
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareFMNISTData()
print("Data Ready")
W_FLDA = np.real(multiClassFLDA(X_train, y_train))
X_train = np.dot(X_train, W_FLDA.T)
X_test = np.dot(X_test, W_FLDA.T)
# Out:
# Data Ready
# CPU times: user 27.5 s, sys: 5.68 s, total: 33.2 s
# Wall time: 13.8 s

# %%
#(X_train, y_train, X_val, y_val, X_test, y_test) = prepareMedicalData();
#(X_train, y_train, X_val, y_val, X_test, y_test) = prepareFMNISTData(PCA_threshold=1, PCA_p = 24)

fig=plt.figure(figsize=(15, 15))
columns = 3
rows = 3

colors = ['violet', 'red', 'blue', 'green', 'indigo', 'yellow', 'orange', 'black', 'purple', 'maroon']
for i in range(1, columns*rows +1):
    X_i = [X_train[np.where(y_train==c)][:,i-1] for c in np.unique(y_train)]
    ax = fig.add_subplot(rows, columns, i)
    ax.hist(X_i, color = colors, edgecolor = 'black', bins = int(100), histtype = 'stepfilled', density = True)
    ax.set_title("Feature " + str(i)) 

fig.tight_layout()
plt.show()

# %% [markdown]
# # SoftMax on FMNIST FLDA

# %%
y_pred = multiClassLogisticRegression(X_test, X_train, y_train, 10, 3000, alpha = 0.00000001, beta = 0.99)
# Out:
# (59998, 55)
# Iteration 0 | Cost: 0.644297
# Iteration 1 | Cost: 0.640128
# Iteration 2 | Cost: 0.622782
# Iteration 3 | Cost: 0.577903
# Iteration 4 | Cost: 0.517270
# Iteration 5 | Cost: 0.497743
# Iteration 6 | Cost: 0.480717
# Iteration 7 | Cost: 0.468931
# Iteration 8 | Cost: 0.457943
# Iteration 9 | Cost: 0.432516
# Iteration 10 | Cost: 0.395541
# Iteration 11 | Cost: 0.383899
# Iteration 12 | Cost: 0.379566
# Iteration 13 | Cost: 0.377131
# Iteration 14 | Cost: 0.374378
# Iteration 15 | Cost: 0.370186
# Iteration 16 | Cost: 0.364212
# Iteration 17 | Cost: 0.356723
# Iteration 18 | Cost: 0.348269
# Iteration 19 | Cost: 0.339338
# Iteration 20 | Cost: 0.330265
# Iteration 21 | Cost: 0.321241
# Iteration 22 | Cost: 0.312388
# Iteration 23 | Cost: 0.303782
# Iteration 24 | Cost: 0.295451
# Iteration 25 | Cost: 0.287404
# Iteration 26 | Cost: 0.279650
# Iteration 27 | Cost: 0.272161
# Iteration 28 | Cost: 0.264947
# Iteration 29 | Cost: 0.258058
# Iteration 30 | Cost: 0.251589
# Iteration 31 | Cost: 0.245671
# Iteration 32 | Cost: 0.240412
# Iteration 33 | Cost: 0.235852
# Iteration 34 | Cost: 0.231992
# Iteration 35 | Cost: 0.228772
# Iteration 36 | Cost: 0.226077
# Iteration 37 | Cost: 0.223808
# Iteration 38 | Cost: 0.221881
# Iteration 39 | Cost: 0.220214
# Iteration 40 | Cost: 0.218725
# Iteration 41 | Cost: 0.217334
# Iteration 42 | Cost: 0.216009
# Iteration 43 | Cost: 0.214733
# Iteration 44 | Cost: 0.213477
# Iteration 45 | Cost: 0.212231
# Iteration 46 | Cost: 0.210985
# Iteration 47 | Cost: 0.209726
# Iteration 48 | Cost: 0.208462
# Iteration 49 | Cost: 0.207178
# Iteration 50 | Cost: 0.205873
# Iteration 51 | Cost: 0.204547
# Iteration 52 | Cost: 0.203205
# Iteration 53 | Cost: 0.201852
# Iteration 54 | Cost: 0.200504
# Iteration 55 | Cost: 0.199164
# Iteration 56 | Cost: 0.197824
# Iteration 57 | Cost: 0.196479
# Iteration 58 | Cost: 0.195133
# Iteration 59 | Cost: 0.193789
# Iteration 60 | Cost: 0.192453
# Iteration 61 | Cost: 0.191128
# Iteration 62 | Cost: 0.189819
# Iteration 63 | Cost: 0.188538
# Iteration 64 | Cost: 0.187283
# Iteration 65 | Cost: 0.186058
# Iteration 66 | Cost: 0.184869
# Iteration 67 | Cost: 0.183724
# Iteration 68 | Cost: 0.182626
# Iteration 69 | Cost: 0.181573
# Iteration 70 | Cost: 0.180562
# Iteration 71 | Cost: 0.179595
# Iteration 72 | Cost: 0.178676
# Iteration 73 | Cost: 0.177805
# Iteration 74 | Cost: 0.176982
# Iteration 75 | Cost: 0.176213
# Iteration 76 | Cost: 0.175501
# Iteration 77 | Cost: 0.174842
# Iteration 78 | Cost: 0.174232
# Iteration 79 | Cost: 0.173665
# Iteration 80 | Cost: 0.173138
# Iteration 81 | Cost: 0.172648
# Iteration 82 | Cost: 0.172201
# Iteration 83 | Cost: 0.171797
# Iteration 84 | Cost: 0.171432
# Iteration 85 | Cost: 0.171101
# Iteration 86 | Cost: 0.170795
# Iteration 87 | Cost: 0.170517
# Iteration 88 | Cost: 0.170268
# Iteration 89 | Cost: 0.170053
# Iteration 90 | Cost: 0.169883
# Iteration 91 | Cost: 0.169758
# Iteration 92 | Cost: 0.169649
# Iteration 93 | Cost: 0.169539
# Iteration 94 | Cost: 0.169456
# Iteration 95 | Cost: 0.169418
# Iteration 96 | Cost: 0.169411
# Iteration 97 | Cost: 0.169418
# Iteration 98 | Cost: 0.169428
# Iteration 99 | Cost: 0.169450
# Iteration 100 | Cost: 0.169497
# Iteration 101 | Cost: 0.169557
# Iteration 102 | Cost: 0.169626
# Iteration 103 | Cost: 0.169705
# Iteration 104 | Cost: 0.169790
# Iteration 105 | Cost: 0.169903
# Iteration 106 | Cost: 0.170037
# Iteration 107 | Cost: 0.170167
# Iteration 108 | Cost: 0.170284
# Iteration 109 | Cost: 0.170380
# Iteration 110 | Cost: 0.170446
# Iteration 111 | Cost: 0.170474
# Iteration 112 | Cost: 0.170463
# Iteration 113 | Cost: 0.170416
# Iteration 114 | Cost: 0.170336
# Iteration 115 | Cost: 0.170222
# Iteration 116 | Cost: 0.170073
# Iteration 117 | Cost: 0.169887
# Iteration 118 | Cost: 0.169663
# Iteration 119 | Cost: 0.169397
# Iteration 120 | Cost: 0.169090
# Iteration 121 | Cost: 0.168743
# Iteration 122 | Cost: 0.168360
# Iteration 123 | Cost: 0.167944
# Iteration 124 | Cost: 0.167503
# Iteration 125 | Cost: 0.167041
# Iteration 126 | Cost: 0.166562
# Iteration 127 | Cost: 0.166070
# Iteration 128 | Cost: 0.165572
# Iteration 129 | Cost: 0.165080
# Iteration 130 | Cost: 0.164605
# Iteration 131 | Cost: 0.164153
# Iteration 132 | Cost: 0.163726
# Iteration 133 | Cost: 0.163319
# Iteration 134 | Cost: 0.162928
# Iteration 135 | Cost: 0.162548
# Iteration 136 | Cost: 0.162175
# Iteration 137 | Cost: 0.161811
# Iteration 138 | Cost: 0.161466
# Iteration 139 | Cost: 0.161145
# Iteration 140 | Cost: 0.160850
# Iteration 141 | Cost: 0.160578
# Iteration 142 | Cost: 0.160326
# Iteration 143 | Cost: 0.160091
# Iteration 144 | Cost: 0.159870
# Iteration 145 | Cost: 0.159669
# Iteration 146 | Cost: 0.159496
# Iteration 147 | Cost: 0.159354
# Iteration 148 | Cost: 0.159237
# Iteration 149 | Cost: 0.159141
# Iteration 150 | Cost: 0.159066
# Iteration 151 | Cost: 0.159003
# Iteration 152 | Cost: 0.158950
# Iteration 153 | Cost: 0.158913
# Iteration 154 | Cost: 0.158896
# Iteration 155 | Cost: 0.158900
# Iteration 156 | Cost: 0.158927
# Iteration 157 | Cost: 0.158973
# Iteration 158 | Cost: 0.159036
# Iteration 159 | Cost: 0.159114
# Iteration 160 | Cost: 0.159201
# Iteration 161 | Cost: 0.159295
# Iteration 162 | Cost: 0.159392
# Iteration 163 | Cost: 0.159489
# Iteration 164 | Cost: 0.159584
# Iteration 165 | Cost: 0.159674
# Iteration 166 | Cost: 0.159757
# Iteration 167 | Cost: 0.159830
# Iteration 168 | Cost: 0.159891
# Iteration 169 | Cost: 0.159941
# Iteration 170 | Cost: 0.159979
# Iteration 171 | Cost: 0.160005
# Iteration 172 | Cost: 0.160021
# Iteration 173 | Cost: 0.160028
# Iteration 174 | Cost: 0.160028
# Iteration 175 | Cost: 0.160022
# Iteration 176 | Cost: 0.160012
# Iteration 177 | Cost: 0.159997
# Iteration 178 | Cost: 0.159980
# Iteration 179 | Cost: 0.159959
# Iteration 180 | Cost: 0.159937
# Iteration 181 | Cost: 0.159912
# Iteration 182 | Cost: 0.159883
# Iteration 183 | Cost: 0.159856
# Iteration 184 | Cost: 0.159834
# Iteration 185 | Cost: 0.159822
# Iteration 186 | Cost: 0.159821
# Iteration 187 | Cost: 0.159827
# Iteration 188 | Cost: 0.159836
# Iteration 189 | Cost: 0.159845
# Iteration 190 | Cost: 0.159850
# Iteration 191 | Cost: 0.159848
# Iteration 192 | Cost: 0.159837
# Iteration 193 | Cost: 0.159817
# Iteration 194 | Cost: 0.159783
# Iteration 195 | Cost: 0.159735
# Iteration 196 | Cost: 0.159670
# Iteration 197 | Cost: 0.159590
# Iteration 198 | Cost: 0.159492
# Iteration 199 | Cost: 0.159379
# Iteration 200 | Cost: 0.159249
# Iteration 201 | Cost: 0.159104
# Iteration 202 | Cost: 0.158944
# Iteration 203 | Cost: 0.158770
# Iteration 204 | Cost: 0.158584
# Iteration 205 | Cost: 0.158390
# Iteration 206 | Cost: 0.158188
# Iteration 207 | Cost: 0.157981
# Iteration 208 | Cost: 0.157771
# Iteration 209 | Cost: 0.157559
# Iteration 210 | Cost: 0.157351
# Iteration 211 | Cost: 0.157148
# Iteration 212 | Cost: 0.156952
# Iteration 213 | Cost: 0.156764
# Iteration 214 | Cost: 0.156586
# Iteration 215 | Cost: 0.156417
# Iteration 216 | Cost: 0.156260
# Iteration 217 | Cost: 0.156114
# Iteration 218 | Cost: 0.155978
# Iteration 219 | Cost: 0.155853
# Iteration 220 | Cost: 0.155738
# Iteration 221 | Cost: 0.155633
# Iteration 222 | Cost: 0.155535
# Iteration 223 | Cost: 0.155445
# Iteration 224 | Cost: 0.155360
# Iteration 225 | Cost: 0.155280
# Iteration 226 | Cost: 0.155203
# Iteration 227 | Cost: 0.155127
# Iteration 228 | Cost: 0.155049
# Iteration 229 | Cost: 0.154969
# Iteration 230 | Cost: 0.154885
# Iteration 231 | Cost: 0.154794
# Iteration 232 | Cost: 0.154696
# Iteration 233 | Cost: 0.154591
# Iteration 234 | Cost: 0.154479
# Iteration 235 | Cost: 0.154358
# Iteration 236 | Cost: 0.154231
# Iteration 237 | Cost: 0.154098
# Iteration 238 | Cost: 0.153960
# Iteration 239 | Cost: 0.153818
# Iteration 240 | Cost: 0.153674
# Iteration 241 | Cost: 0.153528
# Iteration 242 | Cost: 0.153382
# Iteration 243 | Cost: 0.153236
# Iteration 244 | Cost: 0.153093
# Iteration 245 | Cost: 0.152951
# Iteration 246 | Cost: 0.152811
# Iteration 247 | Cost: 0.152674
# Iteration 248 | Cost: 0.152540
# Iteration 249 | Cost: 0.152408
# Iteration 250 | Cost: 0.152280
# Iteration 251 | Cost: 0.152154
# Iteration 252 | Cost: 0.152032
# Iteration 253 | Cost: 0.151912
# Iteration 254 | Cost: 0.151795
# Iteration 255 | Cost: 0.151680
# Iteration 256 | Cost: 0.151565
# Iteration 257 | Cost: 0.151451
# Iteration 258 | Cost: 0.151335
# Iteration 259 | Cost: 0.151217
# Iteration 260 | Cost: 0.151096
# Iteration 261 | Cost: 0.150969
# Iteration 262 | Cost: 0.150837
# Iteration 263 | Cost: 0.150698
# Iteration 264 | Cost: 0.150552
# Iteration 265 | Cost: 0.150398
# Iteration 266 | Cost: 0.150236
# Iteration 267 | Cost: 0.150066
# Iteration 268 | Cost: 0.149889
# Iteration 269 | Cost: 0.149705
# Iteration 270 | Cost: 0.149515
# Iteration 271 | Cost: 0.149321
# Iteration 272 | Cost: 0.149125
# Iteration 273 | Cost: 0.148928
# Iteration 274 | Cost: 0.148732
# Iteration 275 | Cost: 0.148539
# Iteration 276 | Cost: 0.148350
# Iteration 277 | Cost: 0.148167
# Iteration 278 | Cost: 0.147990
# Iteration 279 | Cost: 0.147821
# Iteration 280 | Cost: 0.147661
# Iteration 281 | Cost: 0.147510
# Iteration 282 | Cost: 0.147368
# Iteration 283 | Cost: 0.147235
# Iteration 284 | Cost: 0.147111
# Iteration 285 | Cost: 0.146995
# Iteration 286 | Cost: 0.146885
# Iteration 287 | Cost: 0.146781
# Iteration 288 | Cost: 0.146680
# Iteration 289 | Cost: 0.146581
# Iteration 290 | Cost: 0.146482
# Iteration 291 | Cost: 0.146382
# Iteration 292 | Cost: 0.146278
# Iteration 293 | Cost: 0.146169
# Iteration 294 | Cost: 0.146054
# Iteration 295 | Cost: 0.145931
# Iteration 296 | Cost: 0.145800
# Iteration 297 | Cost: 0.145660
# Iteration 298 | Cost: 0.145512
# Iteration 299 | Cost: 0.145355
# Iteration 300 | Cost: 0.145190
# Iteration 301 | Cost: 0.145018
# Iteration 302 | Cost: 0.144842
# Iteration 303 | Cost: 0.144661
# Iteration 304 | Cost: 0.144478
# Iteration 305 | Cost: 0.144296
# Iteration 306 | Cost: 0.144114
# Iteration 307 | Cost: 0.143937
# Iteration 308 | Cost: 0.143765
# Iteration 309 | Cost: 0.143600
# Iteration 310 | Cost: 0.143445
# Iteration 311 | Cost: 0.143299
# Iteration 312 | Cost: 0.143164
# Iteration 313 | Cost: 0.143041
# Iteration 314 | Cost: 0.142928
# Iteration 315 | Cost: 0.142826
# Iteration 316 | Cost: 0.142733
# Iteration 317 | Cost: 0.142648
# Iteration 318 | Cost: 0.142570
# Iteration 319 | Cost: 0.142495
# Iteration 320 | Cost: 0.142423
# Iteration 321 | Cost: 0.142350
# Iteration 322 | Cost: 0.142275
# Iteration 323 | Cost: 0.142197
# Iteration 324 | Cost: 0.142113
# Iteration 325 | Cost: 0.142024
# Iteration 326 | Cost: 0.141928
# Iteration 327 | Cost: 0.141827
# Iteration 328 | Cost: 0.141720
# Iteration 329 | Cost: 0.141609
# Iteration 330 | Cost: 0.141497
# Iteration 331 | Cost: 0.141385
# Iteration 332 | Cost: 0.141276
# Iteration 333 | Cost: 0.141172
# Iteration 334 | Cost: 0.141075
# Iteration 335 | Cost: 0.140986
# Iteration 336 | Cost: 0.140909
# Iteration 337 | Cost: 0.140843
# Iteration 338 | Cost: 0.140788
# Iteration 339 | Cost: 0.140746
# Iteration 340 | Cost: 0.140715
# Iteration 341 | Cost: 0.140694
# Iteration 342 | Cost: 0.140681
# Iteration 343 | Cost: 0.140675
# Iteration 344 | Cost: 0.140672
# Iteration 345 | Cost: 0.140672
# Iteration 346 | Cost: 0.140671
# Iteration 347 | Cost: 0.140667
# Iteration 348 | Cost: 0.140659
# Iteration 349 | Cost: 0.140644
# Iteration 350 | Cost: 0.140622
# Iteration 351 | Cost: 0.140592
# Iteration 352 | Cost: 0.140553
# Iteration 353 | Cost: 0.140506
# Iteration 354 | Cost: 0.140451
# Iteration 355 | Cost: 0.140391
# Iteration 356 | Cost: 0.140327
# Iteration 357 | Cost: 0.140260
# Iteration 358 | Cost: 0.140192
# Iteration 359 | Cost: 0.140126
# Iteration 360 | Cost: 0.140064
# Iteration 361 | Cost: 0.140008
# Iteration 362 | Cost: 0.139960
# Iteration 363 | Cost: 0.139920
# Iteration 364 | Cost: 0.139890
# Iteration 365 | Cost: 0.139869
# Iteration 366 | Cost: 0.139858
# Iteration 367 | Cost: 0.139856
# Iteration 368 | Cost: 0.139863
# Iteration 369 | Cost: 0.139879
# Iteration 370 | Cost: 0.139901
# Iteration 371 | Cost: 0.139928
# Iteration 372 | Cost: 0.139959
# Iteration 373 | Cost: 0.139992
# Iteration 374 | Cost: 0.140023
# Iteration 375 | Cost: 0.140051
# Iteration 376 | Cost: 0.140075
# Iteration 377 | Cost: 0.140093
# Iteration 378 | Cost: 0.140102
# Iteration 379 | Cost: 0.140103
# Iteration 380 | Cost: 0.140096
# Iteration 381 | Cost: 0.140085
# Iteration 382 | Cost: 0.140074
# Iteration 383 | Cost: 0.140068
# Iteration 384 | Cost: 0.140075
# Iteration 385 | Cost: 0.140099
# Iteration 386 | Cost: 0.140141
# Iteration 387 | Cost: 0.140201
# Iteration 388 | Cost: 0.140286
# Iteration 389 | Cost: 0.140399
# Iteration 390 | Cost: 0.140543
# Iteration 391 | Cost: 0.140721
# Iteration 392 | Cost: 0.140935
# Iteration 393 | Cost: 0.141185
# Iteration 394 | Cost: 0.141468
# Iteration 395 | Cost: 0.141779
# Iteration 396 | Cost: 0.142107
# Iteration 397 | Cost: 0.142441
# Iteration 398 | Cost: 0.142771
# Iteration 399 | Cost: 0.143088
# Iteration 400 | Cost: 0.143381
# Iteration 401 | Cost: 0.143639
# Iteration 402 | Cost: 0.143848
# Iteration 403 | Cost: 0.143998
# Iteration 404 | Cost: 0.144078
# Iteration 405 | Cost: 0.144082
# Iteration 406 | Cost: 0.144010
# Iteration 407 | Cost: 0.143862
# Iteration 408 | Cost: 0.143648
# Iteration 409 | Cost: 0.143378
# Iteration 410 | Cost: 0.143066
# Iteration 411 | Cost: 0.142728
# Iteration 412 | Cost: 0.142376
# Iteration 413 | Cost: 0.142024
# Iteration 414 | Cost: 0.141681
# Iteration 415 | Cost: 0.141356
# Iteration 416 | Cost: 0.141057
# Iteration 417 | Cost: 0.140789
# Iteration 418 | Cost: 0.140557
# Iteration 419 | Cost: 0.140364
# Iteration 420 | Cost: 0.140209
# Iteration 421 | Cost: 0.140084
# Iteration 422 | Cost: 0.139986
# Iteration 423 | Cost: 0.139909
# Iteration 424 | Cost: 0.139851
# Iteration 425 | Cost: 0.139810
# Iteration 426 | Cost: 0.139781
# Iteration 427 | Cost: 0.139759
# Iteration 428 | Cost: 0.139741
# Iteration 429 | Cost: 0.139722
# Iteration 430 | Cost: 0.139700
# Iteration 431 | Cost: 0.139673
# Iteration 432 | Cost: 0.139640
# Iteration 433 | Cost: 0.139598
# Iteration 434 | Cost: 0.139549
# Iteration 435 | Cost: 0.139490
# Iteration 436 | Cost: 0.139421
# Iteration 437 | Cost: 0.139343
# Iteration 438 | Cost: 0.139254
# Iteration 439 | Cost: 0.139156
# Iteration 440 | Cost: 0.139049
# Iteration 441 | Cost: 0.138932
# Iteration 442 | Cost: 0.138805
# Iteration 443 | Cost: 0.138670
# Iteration 444 | Cost: 0.138526
# Iteration 445 | Cost: 0.138373
# Iteration 446 | Cost: 0.138213
# Iteration 447 | Cost: 0.138044
# Iteration 448 | Cost: 0.137868
# Iteration 449 | Cost: 0.137686
# Iteration 450 | Cost: 0.137497
# Iteration 451 | Cost: 0.137302
# Iteration 452 | Cost: 0.137103
# Iteration 453 | Cost: 0.136901
# Iteration 454 | Cost: 0.136697
# Iteration 455 | Cost: 0.136493
# Iteration 456 | Cost: 0.136290
# Iteration 457 | Cost: 0.136090
# Iteration 458 | Cost: 0.135894
# Iteration 459 | Cost: 0.135705
# Iteration 460 | Cost: 0.135525
# Iteration 461 | Cost: 0.135355
# Iteration 462 | Cost: 0.135199
# Iteration 463 | Cost: 0.135057
# Iteration 464 | Cost: 0.134930
# Iteration 465 | Cost: 0.134819
# Iteration 466 | Cost: 0.134724
# Iteration 467 | Cost: 0.134645
# Iteration 468 | Cost: 0.134583
# Iteration 469 | Cost: 0.134537
# Iteration 470 | Cost: 0.134508
# Iteration 471 | Cost: 0.134494
# Iteration 472 | Cost: 0.134492
# Iteration 473 | Cost: 0.134503
# Iteration 474 | Cost: 0.134523
# Iteration 475 | Cost: 0.134550
# Iteration 476 | Cost: 0.134583
# Iteration 477 | Cost: 0.134619
# Iteration 478 | Cost: 0.134656
# Iteration 479 | Cost: 0.134691
# Iteration 480 | Cost: 0.134722
# Iteration 481 | Cost: 0.134746
# Iteration 482 | Cost: 0.134761
# Iteration 483 | Cost: 0.134762
# Iteration 484 | Cost: 0.134749
# Iteration 485 | Cost: 0.134719
# Iteration 486 | Cost: 0.134670
# Iteration 487 | Cost: 0.134603
# Iteration 488 | Cost: 0.134518
# Iteration 489 | Cost: 0.134414
# Iteration 490 | Cost: 0.134295
# Iteration 491 | Cost: 0.134162
# Iteration 492 | Cost: 0.134017
# Iteration 493 | Cost: 0.133865
# Iteration 494 | Cost: 0.133708
# Iteration 495 | Cost: 0.133550
# Iteration 496 | Cost: 0.133392
# Iteration 497 | Cost: 0.133239
# Iteration 498 | Cost: 0.133092
# Iteration 499 | Cost: 0.132953
# Iteration 500 | Cost: 0.132824
# Iteration 501 | Cost: 0.132706
# Iteration 502 | Cost: 0.132599
# Iteration 503 | Cost: 0.132503
# Iteration 504 | Cost: 0.132417
# Iteration 505 | Cost: 0.132343
# Iteration 506 | Cost: 0.132280
# Iteration 507 | Cost: 0.132226
# Iteration 508 | Cost: 0.132184
# Iteration 509 | Cost: 0.132152
# Iteration 510 | Cost: 0.132130
# Iteration 511 | Cost: 0.132118
# Iteration 512 | Cost: 0.132116
# Iteration 513 | Cost: 0.132122
# Iteration 514 | Cost: 0.132135
# Iteration 515 | Cost: 0.132155
# Iteration 516 | Cost: 0.132180
# Iteration 517 | Cost: 0.132210
# Iteration 518 | Cost: 0.132243
# Iteration 519 | Cost: 0.132279
# Iteration 520 | Cost: 0.132317
# Iteration 521 | Cost: 0.132356
# Iteration 522 | Cost: 0.132395
# Iteration 523 | Cost: 0.132432
# Iteration 524 | Cost: 0.132468
# Iteration 525 | Cost: 0.132500
# Iteration 526 | Cost: 0.132529
# Iteration 527 | Cost: 0.132552
# Iteration 528 | Cost: 0.132570
# Iteration 529 | Cost: 0.132581
# Iteration 530 | Cost: 0.132585
# Iteration 531 | Cost: 0.132581
# Iteration 532 | Cost: 0.132568
# Iteration 533 | Cost: 0.132546
# Iteration 534 | Cost: 0.132515
# Iteration 535 | Cost: 0.132475
# Iteration 536 | Cost: 0.132427
# Iteration 537 | Cost: 0.132369
# Iteration 538 | Cost: 0.132304
# Iteration 539 | Cost: 0.132231
# Iteration 540 | Cost: 0.132151
# Iteration 541 | Cost: 0.132065
# Iteration 542 | Cost: 0.131975
# Iteration 543 | Cost: 0.131880
# Iteration 544 | Cost: 0.131782
# Iteration 545 | Cost: 0.131682
# Iteration 546 | Cost: 0.131580
# Iteration 547 | Cost: 0.131479
# Iteration 548 | Cost: 0.131379
# Iteration 549 | Cost: 0.131280
# Iteration 550 | Cost: 0.131184
# Iteration 551 | Cost: 0.131091
# Iteration 552 | Cost: 0.131002
# Iteration 553 | Cost: 0.130918
# Iteration 554 | Cost: 0.130838
# Iteration 555 | Cost: 0.130764
# Iteration 556 | Cost: 0.130696
# Iteration 557 | Cost: 0.130634
# Iteration 558 | Cost: 0.130578
# Iteration 559 | Cost: 0.130529
# Iteration 560 | Cost: 0.130486
# Iteration 561 | Cost: 0.130451
# Iteration 562 | Cost: 0.130422
# Iteration 563 | Cost: 0.130399
# Iteration 564 | Cost: 0.130384
# Iteration 565 | Cost: 0.130376
# Iteration 566 | Cost: 0.130374
# Iteration 567 | Cost: 0.130378
# Iteration 568 | Cost: 0.130389
# Iteration 569 | Cost: 0.130405
# Iteration 570 | Cost: 0.130425
# Iteration 571 | Cost: 0.130448
# Iteration 572 | Cost: 0.130473
# Iteration 573 | Cost: 0.130499
# Iteration 574 | Cost: 0.130525
# Iteration 575 | Cost: 0.130549
# Iteration 576 | Cost: 0.130569
# Iteration 577 | Cost: 0.130585
# Iteration 578 | Cost: 0.130595
# Iteration 579 | Cost: 0.130597
# Iteration 580 | Cost: 0.130592
# Iteration 581 | Cost: 0.130577
# Iteration 582 | Cost: 0.130554
# Iteration 583 | Cost: 0.130520
# Iteration 584 | Cost: 0.130477
# Iteration 585 | Cost: 0.130424
# Iteration 586 | Cost: 0.130363
# Iteration 587 | Cost: 0.130294
# Iteration 588 | Cost: 0.130219
# Iteration 589 | Cost: 0.130138
# Iteration 590 | Cost: 0.130054
# Iteration 591 | Cost: 0.129969
# Iteration 592 | Cost: 0.129883
# Iteration 593 | Cost: 0.129800
# Iteration 594 | Cost: 0.129720
# Iteration 595 | Cost: 0.129646
# Iteration 596 | Cost: 0.129579
# Iteration 597 | Cost: 0.129521
# Iteration 598 | Cost: 0.129472
# Iteration 599 | Cost: 0.129434
# Iteration 600 | Cost: 0.129408
# Iteration 601 | Cost: 0.129393
# Iteration 602 | Cost: 0.129389
# Iteration 603 | Cost: 0.129398
# Iteration 604 | Cost: 0.129417
# Iteration 605 | Cost: 0.129448
# Iteration 606 | Cost: 0.129487
# Iteration 607 | Cost: 0.129536
# Iteration 608 | Cost: 0.129590
# Iteration 609 | Cost: 0.129651
# Iteration 610 | Cost: 0.129714
# Iteration 611 | Cost: 0.129779
# Iteration 612 | Cost: 0.129844
# Iteration 613 | Cost: 0.129906
# Iteration 614 | Cost: 0.129963
# Iteration 615 | Cost: 0.130015
# Iteration 616 | Cost: 0.130058
# Iteration 617 | Cost: 0.130093
# Iteration 618 | Cost: 0.130117
# Iteration 619 | Cost: 0.130130
# Iteration 620 | Cost: 0.130132
# Iteration 621 | Cost: 0.130122
# Iteration 622 | Cost: 0.130102
# Iteration 623 | Cost: 0.130071
# Iteration 624 | Cost: 0.130033
# Iteration 625 | Cost: 0.129989
# Iteration 626 | Cost: 0.129940
# Iteration 627 | Cost: 0.129891
# Iteration 628 | Cost: 0.129843
# Iteration 629 | Cost: 0.129800
# Iteration 630 | Cost: 0.129766
# Iteration 631 | Cost: 0.129744
# Iteration 632 | Cost: 0.129736
# Iteration 633 | Cost: 0.129746
# Iteration 634 | Cost: 0.129773
# Iteration 635 | Cost: 0.129817
# Iteration 636 | Cost: 0.129874
# Iteration 637 | Cost: 0.129941
# Iteration 638 | Cost: 0.130008
# Iteration 639 | Cost: 0.130069
# Iteration 640 | Cost: 0.130112
# Iteration 641 | Cost: 0.130131
# Iteration 642 | Cost: 0.130120
# Iteration 643 | Cost: 0.130076
# Iteration 644 | Cost: 0.130002
# Iteration 645 | Cost: 0.129901
# Iteration 646 | Cost: 0.129782
# Iteration 647 | Cost: 0.129653
# Iteration 648 | Cost: 0.129522
# Iteration 649 | Cost: 0.129395
# Iteration 650 | Cost: 0.129278
# Iteration 651 | Cost: 0.129173
# Iteration 652 | Cost: 0.129081
# Iteration 653 | Cost: 0.129004
# Iteration 654 | Cost: 0.128939
# Iteration 655 | Cost: 0.128886
# Iteration 656 | Cost: 0.128844
# Iteration 657 | Cost: 0.128809
# Iteration 658 | Cost: 0.128781
# Iteration 659 | Cost: 0.128759
# Iteration 660 | Cost: 0.128740
# Iteration 661 | Cost: 0.128724
# Iteration 662 | Cost: 0.128709
# Iteration 663 | Cost: 0.128694
# Iteration 664 | Cost: 0.128679
# Iteration 665 | Cost: 0.128663
# Iteration 666 | Cost: 0.128646
# Iteration 667 | Cost: 0.128627
# Iteration 668 | Cost: 0.128606
# Iteration 669 | Cost: 0.128584
# Iteration 670 | Cost: 0.128560
# Iteration 671 | Cost: 0.128535
# Iteration 672 | Cost: 0.128508
# Iteration 673 | Cost: 0.128479
# Iteration 674 | Cost: 0.128450
# Iteration 675 | Cost: 0.128420
# Iteration 676 | Cost: 0.128389
# Iteration 677 | Cost: 0.128359
# Iteration 678 | Cost: 0.128328
# Iteration 679 | Cost: 0.128298
# Iteration 680 | Cost: 0.128269
# Iteration 681 | Cost: 0.128241
# Iteration 682 | Cost: 0.128215
# Iteration 683 | Cost: 0.128190
# Iteration 684 | Cost: 0.128167
# Iteration 685 | Cost: 0.128146
# Iteration 686 | Cost: 0.128128
# Iteration 687 | Cost: 0.128111
# Iteration 688 | Cost: 0.128098
# Iteration 689 | Cost: 0.128086
# Iteration 690 | Cost: 0.128078
# Iteration 691 | Cost: 0.128071
# Iteration 692 | Cost: 0.128067
# Iteration 693 | Cost: 0.128065
# Iteration 694 | Cost: 0.128064
# Iteration 695 | Cost: 0.128065
# Iteration 696 | Cost: 0.128068
# Iteration 697 | Cost: 0.128071
# Iteration 698 | Cost: 0.128076
# Iteration 699 | Cost: 0.128080
# Iteration 700 | Cost: 0.128085
# Iteration 701 | Cost: 0.128089
# Iteration 702 | Cost: 0.128093
# Iteration 703 | Cost: 0.128097
# Iteration 704 | Cost: 0.128099
# Iteration 705 | Cost: 0.128099
# Iteration 706 | Cost: 0.128098
# Iteration 707 | Cost: 0.128096
# Iteration 708 | Cost: 0.128091
# Iteration 709 | Cost: 0.128085
# Iteration 710 | Cost: 0.128077
# Iteration 711 | Cost: 0.128067
# Iteration 712 | Cost: 0.128054
# Iteration 713 | Cost: 0.128040
# Iteration 714 | Cost: 0.128025
# Iteration 715 | Cost: 0.128008
# Iteration 716 | Cost: 0.127990
# Iteration 717 | Cost: 0.127971
# Iteration 718 | Cost: 0.127951
# Iteration 719 | Cost: 0.127931
# Iteration 720 | Cost: 0.127911
# Iteration 721 | Cost: 0.127891
# Iteration 722 | Cost: 0.127872
# Iteration 723 | Cost: 0.127853
# Iteration 724 | Cost: 0.127836
# Iteration 725 | Cost: 0.127820
# Iteration 726 | Cost: 0.127806
# Iteration 727 | Cost: 0.127793
# Iteration 728 | Cost: 0.127783
# Iteration 729 | Cost: 0.127774
# Iteration 730 | Cost: 0.127767
# Iteration 731 | Cost: 0.127763
# Iteration 732 | Cost: 0.127760
# Iteration 733 | Cost: 0.127760
# Iteration 734 | Cost: 0.127761
# Iteration 735 | Cost: 0.127764
# Iteration 736 | Cost: 0.127768
# Iteration 737 | Cost: 0.127773
# Iteration 738 | Cost: 0.127780
# Iteration 739 | Cost: 0.127787
# Iteration 740 | Cost: 0.127794
# Iteration 741 | Cost: 0.127802
# Iteration 742 | Cost: 0.127809
# Iteration 743 | Cost: 0.127816
# Iteration 744 | Cost: 0.127823
# Iteration 745 | Cost: 0.127828
# Iteration 746 | Cost: 0.127832
# Iteration 747 | Cost: 0.127834
# Iteration 748 | Cost: 0.127835
# Iteration 749 | Cost: 0.127834
# Iteration 750 | Cost: 0.127831
# Iteration 751 | Cost: 0.127827
# Iteration 752 | Cost: 0.127820
# Iteration 753 | Cost: 0.127812
# Iteration 754 | Cost: 0.127803
# Iteration 755 | Cost: 0.127792
# Iteration 756 | Cost: 0.127781
# Iteration 757 | Cost: 0.127769
# Iteration 758 | Cost: 0.127756
# Iteration 759 | Cost: 0.127744
# Iteration 760 | Cost: 0.127733
# Iteration 761 | Cost: 0.127723
# Iteration 762 | Cost: 0.127714
# Iteration 763 | Cost: 0.127708
# Iteration 764 | Cost: 0.127704
# Iteration 765 | Cost: 0.127702
# Iteration 766 | Cost: 0.127703
# Iteration 767 | Cost: 0.127706
# Iteration 768 | Cost: 0.127712
# Iteration 769 | Cost: 0.127720
# Iteration 770 | Cost: 0.127729
# Iteration 771 | Cost: 0.127738
# Iteration 772 | Cost: 0.127748
# Iteration 773 | Cost: 0.127756
# Iteration 774 | Cost: 0.127762
# Iteration 775 | Cost: 0.127766
# Iteration 776 | Cost: 0.127765
# Iteration 777 | Cost: 0.127761
# Iteration 778 | Cost: 0.127753
# Iteration 779 | Cost: 0.127742
# Iteration 780 | Cost: 0.127726
# Iteration 781 | Cost: 0.127709
# Iteration 782 | Cost: 0.127689
# Iteration 783 | Cost: 0.127668
# Iteration 784 | Cost: 0.127647
# Iteration 785 | Cost: 0.127627
# Iteration 786 | Cost: 0.127608
# Iteration 787 | Cost: 0.127591
# Iteration 788 | Cost: 0.127576
# Iteration 789 | Cost: 0.127564
# Iteration 790 | Cost: 0.127553
# Iteration 791 | Cost: 0.127545
# Iteration 792 | Cost: 0.127538
# Iteration 793 | Cost: 0.127532
# Iteration 794 | Cost: 0.127528
# Iteration 795 | Cost: 0.127524
# Iteration 796 | Cost: 0.127520
# Iteration 797 | Cost: 0.127515
# Iteration 798 | Cost: 0.127509
# Iteration 799 | Cost: 0.127503
# Iteration 800 | Cost: 0.127494
# Iteration 801 | Cost: 0.127484
# Iteration 802 | Cost: 0.127472
# Iteration 803 | Cost: 0.127458
# Iteration 804 | Cost: 0.127442
# Iteration 805 | Cost: 0.127424
# Iteration 806 | Cost: 0.127404
# Iteration 807 | Cost: 0.127382
# Iteration 808 | Cost: 0.127359
# Iteration 809 | Cost: 0.127334
# Iteration 810 | Cost: 0.127308
# Iteration 811 | Cost: 0.127282
# Iteration 812 | Cost: 0.127255
# Iteration 813 | Cost: 0.127228
# Iteration 814 | Cost: 0.127202
# Iteration 815 | Cost: 0.127176
# Iteration 816 | Cost: 0.127150
# Iteration 817 | Cost: 0.127126
# Iteration 818 | Cost: 0.127103
# Iteration 819 | Cost: 0.127082
# Iteration 820 | Cost: 0.127062
# Iteration 821 | Cost: 0.127044
# Iteration 822 | Cost: 0.127027
# Iteration 823 | Cost: 0.127012
# Iteration 824 | Cost: 0.126999
# Iteration 825 | Cost: 0.126987
# Iteration 826 | Cost: 0.126976
# Iteration 827 | Cost: 0.126966
# Iteration 828 | Cost: 0.126957
# Iteration 829 | Cost: 0.126949
# Iteration 830 | Cost: 0.126941
# Iteration 831 | Cost: 0.126934
# Iteration 832 | Cost: 0.126926
# Iteration 833 | Cost: 0.126918
# Iteration 834 | Cost: 0.126910
# Iteration 835 | Cost: 0.126900
# Iteration 836 | Cost: 0.126891
# Iteration 837 | Cost: 0.126880
# Iteration 838 | Cost: 0.126868
# Iteration 839 | Cost: 0.126856
# Iteration 840 | Cost: 0.126842
# Iteration 841 | Cost: 0.126828
# Iteration 842 | Cost: 0.126813
# Iteration 843 | Cost: 0.126797
# Iteration 844 | Cost: 0.126781
# Iteration 845 | Cost: 0.126765
# Iteration 846 | Cost: 0.126749
# Iteration 847 | Cost: 0.126732
# Iteration 848 | Cost: 0.126716
# Iteration 849 | Cost: 0.126700
# Iteration 850 | Cost: 0.126685
# Iteration 851 | Cost: 0.126670
# Iteration 852 | Cost: 0.126656
# Iteration 853 | Cost: 0.126643
# Iteration 854 | Cost: 0.126630
# Iteration 855 | Cost: 0.126619
# Iteration 856 | Cost: 0.126608
# Iteration 857 | Cost: 0.126599
# Iteration 858 | Cost: 0.126590
# Iteration 859 | Cost: 0.126582
# Iteration 860 | Cost: 0.126574
# Iteration 861 | Cost: 0.126567
# Iteration 862 | Cost: 0.126561
# Iteration 863 | Cost: 0.126555
# Iteration 864 | Cost: 0.126550
# Iteration 865 | Cost: 0.126545
# Iteration 866 | Cost: 0.126539
# Iteration 867 | Cost: 0.126534
# Iteration 868 | Cost: 0.126529
# Iteration 869 | Cost: 0.126524
# Iteration 870 | Cost: 0.126518
# Iteration 871 | Cost: 0.126512
# Iteration 872 | Cost: 0.126505
# Iteration 873 | Cost: 0.126498
# Iteration 874 | Cost: 0.126490
# Iteration 875 | Cost: 0.126482
# Iteration 876 | Cost: 0.126474
# Iteration 877 | Cost: 0.126464
# Iteration 878 | Cost: 0.126454
# Iteration 879 | Cost: 0.126444
# Iteration 880 | Cost: 0.126433
# Iteration 881 | Cost: 0.126422
# Iteration 882 | Cost: 0.126411
# Iteration 883 | Cost: 0.126399
# Iteration 884 | Cost: 0.126387
# Iteration 885 | Cost: 0.126376
# Iteration 886 | Cost: 0.126364
# Iteration 887 | Cost: 0.126352
# Iteration 888 | Cost: 0.126341
# Iteration 889 | Cost: 0.126330
# Iteration 890 | Cost: 0.126319
# Iteration 891 | Cost: 0.126310
# Iteration 892 | Cost: 0.126300
# Iteration 893 | Cost: 0.126292
# Iteration 894 | Cost: 0.126284
# Iteration 895 | Cost: 0.126277
# Iteration 896 | Cost: 0.126271
# Iteration 897 | Cost: 0.126265
# Iteration 898 | Cost: 0.126260
# Iteration 899 | Cost: 0.126256
# Iteration 900 | Cost: 0.126252
# Iteration 901 | Cost: 0.126249
# Iteration 902 | Cost: 0.126246
# Iteration 903 | Cost: 0.126243
# Iteration 904 | Cost: 0.126240
# Iteration 905 | Cost: 0.126237
# Iteration 906 | Cost: 0.126233
# Iteration 907 | Cost: 0.126230
# Iteration 908 | Cost: 0.126226
# Iteration 909 | Cost: 0.126222
# Iteration 910 | Cost: 0.126217
# Iteration 911 | Cost: 0.126211
# Iteration 912 | Cost: 0.126206
# Iteration 913 | Cost: 0.126200
# Iteration 914 | Cost: 0.126194
# Iteration 915 | Cost: 0.126187
# Iteration 916 | Cost: 0.126181
# Iteration 917 | Cost: 0.126175
# Iteration 918 | Cost: 0.126169
# Iteration 919 | Cost: 0.126163
# Iteration 920 | Cost: 0.126158
# Iteration 921 | Cost: 0.126154
# Iteration 922 | Cost: 0.126150
# Iteration 923 | Cost: 0.126147
# Iteration 924 | Cost: 0.126144
# Iteration 925 | Cost: 0.126142
# Iteration 926 | Cost: 0.126140
# Iteration 927 | Cost: 0.126139
# Iteration 928 | Cost: 0.126138
# Iteration 929 | Cost: 0.126138
# Iteration 930 | Cost: 0.126137
# Iteration 931 | Cost: 0.126136
# Iteration 932 | Cost: 0.126135
# Iteration 933 | Cost: 0.126133
# Iteration 934 | Cost: 0.126131
# Iteration 935 | Cost: 0.126128
# Iteration 936 | Cost: 0.126124
# Iteration 937 | Cost: 0.126120
# Iteration 938 | Cost: 0.126114
# Iteration 939 | Cost: 0.126107
# Iteration 940 | Cost: 0.126099
# Iteration 941 | Cost: 0.126091
# Iteration 942 | Cost: 0.126081
# Iteration 943 | Cost: 0.126070
# Iteration 944 | Cost: 0.126058
# Iteration 945 | Cost: 0.126046
# Iteration 946 | Cost: 0.126033
# Iteration 947 | Cost: 0.126020
# Iteration 948 | Cost: 0.126006
# Iteration 949 | Cost: 0.125992
# Iteration 950 | Cost: 0.125978
# Iteration 951 | Cost: 0.125964
# Iteration 952 | Cost: 0.125950
# Iteration 953 | Cost: 0.125936
# Iteration 954 | Cost: 0.125923
# Iteration 955 | Cost: 0.125911
# Iteration 956 | Cost: 0.125898
# Iteration 957 | Cost: 0.125887
# Iteration 958 | Cost: 0.125876
# Iteration 959 | Cost: 0.125865
# Iteration 960 | Cost: 0.125855
# Iteration 961 | Cost: 0.125846
# Iteration 962 | Cost: 0.125837
# Iteration 963 | Cost: 0.125828
# Iteration 964 | Cost: 0.125820
# Iteration 965 | Cost: 0.125811
# Iteration 966 | Cost: 0.125803
# Iteration 967 | Cost: 0.125795
# Iteration 968 | Cost: 0.125787
# Iteration 969 | Cost: 0.125778
# Iteration 970 | Cost: 0.125770
# Iteration 971 | Cost: 0.125761
# Iteration 972 | Cost: 0.125752
# Iteration 973 | Cost: 0.125742
# Iteration 974 | Cost: 0.125733
# Iteration 975 | Cost: 0.125723
# Iteration 976 | Cost: 0.125714
# Iteration 977 | Cost: 0.125704
# Iteration 978 | Cost: 0.125694
# Iteration 979 | Cost: 0.125685
# Iteration 980 | Cost: 0.125675
# Iteration 981 | Cost: 0.125666
# Iteration 982 | Cost: 0.125658
# Iteration 983 | Cost: 0.125649
# Iteration 984 | Cost: 0.125641
# Iteration 985 | Cost: 0.125633
# Iteration 986 | Cost: 0.125626
# Iteration 987 | Cost: 0.125620
# Iteration 988 | Cost: 0.125613
# Iteration 989 | Cost: 0.125608
# Iteration 990 | Cost: 0.125603
# Iteration 991 | Cost: 0.125598
# Iteration 992 | Cost: 0.125593
# Iteration 993 | Cost: 0.125589
# Iteration 994 | Cost: 0.125585
# Iteration 995 | Cost: 0.125582
# Iteration 996 | Cost: 0.125578
# Iteration 997 | Cost: 0.125575
# Iteration 998 | Cost: 0.125571
# Iteration 999 | Cost: 0.125568
# Iteration 1000 | Cost: 0.125564
# Iteration 1001 | Cost: 0.125561
# Iteration 1002 | Cost: 0.125557
# Iteration 1003 | Cost: 0.125553
# Iteration 1004 | Cost: 0.125549
# Iteration 1005 | Cost: 0.125544
# Iteration 1006 | Cost: 0.125540
# Iteration 1007 | Cost: 0.125535
# Iteration 1008 | Cost: 0.125530
# Iteration 1009 | Cost: 0.125524
# Iteration 1010 | Cost: 0.125518
# Iteration 1011 | Cost: 0.125512
# Iteration 1012 | Cost: 0.125506
# Iteration 1013 | Cost: 0.125500
# Iteration 1014 | Cost: 0.125493
# Iteration 1015 | Cost: 0.125487
# Iteration 1016 | Cost: 0.125480
# Iteration 1017 | Cost: 0.125474
# Iteration 1018 | Cost: 0.125467
# Iteration 1019 | Cost: 0.125460
# Iteration 1020 | Cost: 0.125454
# Iteration 1021 | Cost: 0.125448
# Iteration 1022 | Cost: 0.125442
# Iteration 1023 | Cost: 0.125436
# Iteration 1024 | Cost: 0.125430
# Iteration 1025 | Cost: 0.125424
# Iteration 1026 | Cost: 0.125419
# Iteration 1027 | Cost: 0.125414
# Iteration 1028 | Cost: 0.125409
# Iteration 1029 | Cost: 0.125404
# Iteration 1030 | Cost: 0.125400
# Iteration 1031 | Cost: 0.125395
# Iteration 1032 | Cost: 0.125391
# Iteration 1033 | Cost: 0.125386
# Iteration 1034 | Cost: 0.125382
# Iteration 1035 | Cost: 0.125378
# Iteration 1036 | Cost: 0.125374
# Iteration 1037 | Cost: 0.125370
# Iteration 1038 | Cost: 0.125366
# Iteration 1039 | Cost: 0.125361
# Iteration 1040 | Cost: 0.125357
# Iteration 1041 | Cost: 0.125353
# Iteration 1042 | Cost: 0.125349
# Iteration 1043 | Cost: 0.125345
# Iteration 1044 | Cost: 0.125341
# Iteration 1045 | Cost: 0.125337
# Iteration 1046 | Cost: 0.125333
# Iteration 1047 | Cost: 0.125330
# Iteration 1048 | Cost: 0.125326
# Iteration 1049 | Cost: 0.125323
# Iteration 1050 | Cost: 0.125320
# Iteration 1051 | Cost: 0.125317
# Iteration 1052 | Cost: 0.125314
# Iteration 1053 | Cost: 0.125312
# Iteration 1054 | Cost: 0.125310
# Iteration 1055 | Cost: 0.125308
# Iteration 1056 | Cost: 0.125306
# Iteration 1057 | Cost: 0.125305
# Iteration 1058 | Cost: 0.125303
# Iteration 1059 | Cost: 0.125302
# Iteration 1060 | Cost: 0.125301
# Iteration 1061 | Cost: 0.125300
# Iteration 1062 | Cost: 0.125299
# Iteration 1063 | Cost: 0.125298
# Iteration 1064 | Cost: 0.125297
# Iteration 1065 | Cost: 0.125295
# Iteration 1066 | Cost: 0.125293
# Iteration 1067 | Cost: 0.125291
# Iteration 1068 | Cost: 0.125289
# Iteration 1069 | Cost: 0.125287
# Iteration 1070 | Cost: 0.125284
# Iteration 1071 | Cost: 0.125280
# Iteration 1072 | Cost: 0.125277
# Iteration 1073 | Cost: 0.125273
# Iteration 1074 | Cost: 0.125268
# Iteration 1075 | Cost: 0.125263
# Iteration 1076 | Cost: 0.125258
# Iteration 1077 | Cost: 0.125252
# Iteration 1078 | Cost: 0.125247
# Iteration 1079 | Cost: 0.125240
# Iteration 1080 | Cost: 0.125234
# Iteration 1081 | Cost: 0.125228
# Iteration 1082 | Cost: 0.125221
# Iteration 1083 | Cost: 0.125214
# Iteration 1084 | Cost: 0.125207
# Iteration 1085 | Cost: 0.125200
# Iteration 1086 | Cost: 0.125194
# Iteration 1087 | Cost: 0.125187
# Iteration 1088 | Cost: 0.125180
# Iteration 1089 | Cost: 0.125173
# Iteration 1090 | Cost: 0.125167
# Iteration 1091 | Cost: 0.125160
# Iteration 1092 | Cost: 0.125154
# Iteration 1093 | Cost: 0.125148
# Iteration 1094 | Cost: 0.125142
# Iteration 1095 | Cost: 0.125136
# Iteration 1096 | Cost: 0.125130
# Iteration 1097 | Cost: 0.125124
# Iteration 1098 | Cost: 0.125118
# Iteration 1099 | Cost: 0.125113
# Iteration 1100 | Cost: 0.125107
# Iteration 1101 | Cost: 0.125101
# Iteration 1102 | Cost: 0.125096
# Iteration 1103 | Cost: 0.125090
# Iteration 1104 | Cost: 0.125085
# Iteration 1105 | Cost: 0.125080
# Iteration 1106 | Cost: 0.125074
# Iteration 1107 | Cost: 0.125069
# Iteration 1108 | Cost: 0.125064
# Iteration 1109 | Cost: 0.125058
# Iteration 1110 | Cost: 0.125053
# Iteration 1111 | Cost: 0.125048
# Iteration 1112 | Cost: 0.125043
# Iteration 1113 | Cost: 0.125039
# Iteration 1114 | Cost: 0.125034
# Iteration 1115 | Cost: 0.125029
# Iteration 1116 | Cost: 0.125025
# Iteration 1117 | Cost: 0.125021
# Iteration 1118 | Cost: 0.125017
# Iteration 1119 | Cost: 0.125013
# Iteration 1120 | Cost: 0.125009
# Iteration 1121 | Cost: 0.125005
# Iteration 1122 | Cost: 0.125001
# Iteration 1123 | Cost: 0.124997
# Iteration 1124 | Cost: 0.124994
# Iteration 1125 | Cost: 0.124990
# Iteration 1126 | Cost: 0.124986
# Iteration 1127 | Cost: 0.124982
# Iteration 1128 | Cost: 0.124978
# Iteration 1129 | Cost: 0.124974
# Iteration 1130 | Cost: 0.124970
# Iteration 1131 | Cost: 0.124966
# Iteration 1132 | Cost: 0.124962
# Iteration 1133 | Cost: 0.124957
# Iteration 1134 | Cost: 0.124952
# Iteration 1135 | Cost: 0.124947
# Iteration 1136 | Cost: 0.124942
# Iteration 1137 | Cost: 0.124937
# Iteration 1138 | Cost: 0.124931
# Iteration 1139 | Cost: 0.124926
# Iteration 1140 | Cost: 0.124920
# Iteration 1141 | Cost: 0.124914
# Iteration 1142 | Cost: 0.124909
# Iteration 1143 | Cost: 0.124903
# Iteration 1144 | Cost: 0.124897
# Iteration 1145 | Cost: 0.124890
# Iteration 1146 | Cost: 0.124884
# Iteration 1147 | Cost: 0.124878
# Iteration 1148 | Cost: 0.124872
# Iteration 1149 | Cost: 0.124866
# Iteration 1150 | Cost: 0.124860
# Iteration 1151 | Cost: 0.124855
# Iteration 1152 | Cost: 0.124849
# Iteration 1153 | Cost: 0.124843
# Iteration 1154 | Cost: 0.124838
# Iteration 1155 | Cost: 0.124832
# Iteration 1156 | Cost: 0.124827
# Iteration 1157 | Cost: 0.124822
# Iteration 1158 | Cost: 0.124817
# Iteration 1159 | Cost: 0.124812
# Iteration 1160 | Cost: 0.124808
# Iteration 1161 | Cost: 0.124803
# Iteration 1162 | Cost: 0.124799
# Iteration 1163 | Cost: 0.124794
# Iteration 1164 | Cost: 0.124790
# Iteration 1165 | Cost: 0.124786
# Iteration 1166 | Cost: 0.124782
# Iteration 1167 | Cost: 0.124778
# Iteration 1168 | Cost: 0.124774
# Iteration 1169 | Cost: 0.124771
# Iteration 1170 | Cost: 0.124767
# Iteration 1171 | Cost: 0.124763
# Iteration 1172 | Cost: 0.124760
# Iteration 1173 | Cost: 0.124757
# Iteration 1174 | Cost: 0.124753
# Iteration 1175 | Cost: 0.124750
# Iteration 1176 | Cost: 0.124747
# Iteration 1177 | Cost: 0.124744
# Iteration 1178 | Cost: 0.124741
# Iteration 1179 | Cost: 0.124739
# Iteration 1180 | Cost: 0.124736
# Iteration 1181 | Cost: 0.124733
# Iteration 1182 | Cost: 0.124731
# Iteration 1183 | Cost: 0.124728
# Iteration 1184 | Cost: 0.124726
# Iteration 1185 | Cost: 0.124724
# Iteration 1186 | Cost: 0.124722
# Iteration 1187 | Cost: 0.124719
# Iteration 1188 | Cost: 0.124717
# Iteration 1189 | Cost: 0.124715
# Iteration 1190 | Cost: 0.124713
# Iteration 1191 | Cost: 0.124711
# Iteration 1192 | Cost: 0.124709
# Iteration 1193 | Cost: 0.124706
# Iteration 1194 | Cost: 0.124704
# Iteration 1195 | Cost: 0.124702
# Iteration 1196 | Cost: 0.124699
# Iteration 1197 | Cost: 0.124697
# Iteration 1198 | Cost: 0.124694
# Iteration 1199 | Cost: 0.124691
# Iteration 1200 | Cost: 0.124688
# Iteration 1201 | Cost: 0.124685
# Iteration 1202 | Cost: 0.124682
# Iteration 1203 | Cost: 0.124679
# Iteration 1204 | Cost: 0.124676
# Iteration 1205 | Cost: 0.124672
# Iteration 1206 | Cost: 0.124669
# Iteration 1207 | Cost: 0.124665
# Iteration 1208 | Cost: 0.124661
# Iteration 1209 | Cost: 0.124658
# Iteration 1210 | Cost: 0.124654
# Iteration 1211 | Cost: 0.124650
# Iteration 1212 | Cost: 0.124646
# Iteration 1213 | Cost: 0.124642
# Iteration 1214 | Cost: 0.124638
# Iteration 1215 | Cost: 0.124634
# Iteration 1216 | Cost: 0.124631
# Iteration 1217 | Cost: 0.124627
# Iteration 1218 | Cost: 0.124623
# Iteration 1219 | Cost: 0.124619
# Iteration 1220 | Cost: 0.124615
# Iteration 1221 | Cost: 0.124612
# Iteration 1222 | Cost: 0.124608
# Iteration 1223 | Cost: 0.124604
# Iteration 1224 | Cost: 0.124601
# Iteration 1225 | Cost: 0.124597
# Iteration 1226 | Cost: 0.124594
# Iteration 1227 | Cost: 0.124590
# Iteration 1228 | Cost: 0.124587
# Iteration 1229 | Cost: 0.124583
# Iteration 1230 | Cost: 0.124580
# Iteration 1231 | Cost: 0.124577
# Iteration 1232 | Cost: 0.124573
# Iteration 1233 | Cost: 0.124570
# Iteration 1234 | Cost: 0.124566
# Iteration 1235 | Cost: 0.124563
# Iteration 1236 | Cost: 0.124560
# Iteration 1237 | Cost: 0.124556
# Iteration 1238 | Cost: 0.124553
# Iteration 1239 | Cost: 0.124550
# Iteration 1240 | Cost: 0.124546
# Iteration 1241 | Cost: 0.124543
# Iteration 1242 | Cost: 0.124540
# Iteration 1243 | Cost: 0.124537
# Iteration 1244 | Cost: 0.124533
# Iteration 1245 | Cost: 0.124530
# Iteration 1246 | Cost: 0.124527
# Iteration 1247 | Cost: 0.124524
# Iteration 1248 | Cost: 0.124520
# Iteration 1249 | Cost: 0.124517
# Iteration 1250 | Cost: 0.124514
# Iteration 1251 | Cost: 0.124511
# Iteration 1252 | Cost: 0.124507
# Iteration 1253 | Cost: 0.124504
# Iteration 1254 | Cost: 0.124501
# Iteration 1255 | Cost: 0.124497
# Iteration 1256 | Cost: 0.124494
# Iteration 1257 | Cost: 0.124490
# Iteration 1258 | Cost: 0.124487
# Iteration 1259 | Cost: 0.124483
# Iteration 1260 | Cost: 0.124479
# Iteration 1261 | Cost: 0.124476
# Iteration 1262 | Cost: 0.124472
# Iteration 1263 | Cost: 0.124468
# Iteration 1264 | Cost: 0.124464
# Iteration 1265 | Cost: 0.124460
# Iteration 1266 | Cost: 0.124456
# Iteration 1267 | Cost: 0.124451
# Iteration 1268 | Cost: 0.124447
# Iteration 1269 | Cost: 0.124443
# Iteration 1270 | Cost: 0.124438
# Iteration 1271 | Cost: 0.124434
# Iteration 1272 | Cost: 0.124429
# Iteration 1273 | Cost: 0.124425
# Iteration 1274 | Cost: 0.124420
# Iteration 1275 | Cost: 0.124416
# Iteration 1276 | Cost: 0.124411
# Iteration 1277 | Cost: 0.124407
# Iteration 1278 | Cost: 0.124402
# Iteration 1279 | Cost: 0.124397
# Iteration 1280 | Cost: 0.124393
# Iteration 1281 | Cost: 0.124388
# Iteration 1282 | Cost: 0.124384
# Iteration 1283 | Cost: 0.124380
# Iteration 1284 | Cost: 0.124375
# Iteration 1285 | Cost: 0.124371
# Iteration 1286 | Cost: 0.124367
# Iteration 1287 | Cost: 0.124362
# Iteration 1288 | Cost: 0.124358
# Iteration 1289 | Cost: 0.124354
# Iteration 1290 | Cost: 0.124350
# Iteration 1291 | Cost: 0.124346
# Iteration 1292 | Cost: 0.124342
# Iteration 1293 | Cost: 0.124338
# Iteration 1294 | Cost: 0.124334
# Iteration 1295 | Cost: 0.124330
# Iteration 1296 | Cost: 0.124327
# Iteration 1297 | Cost: 0.124323
# Iteration 1298 | Cost: 0.124319
# Iteration 1299 | Cost: 0.124316
# Iteration 1300 | Cost: 0.124312
# Iteration 1301 | Cost: 0.124308
# Iteration 1302 | Cost: 0.124305
# Iteration 1303 | Cost: 0.124302
# Iteration 1304 | Cost: 0.124298
# Iteration 1305 | Cost: 0.124295
# Iteration 1306 | Cost: 0.124292
# Iteration 1307 | Cost: 0.124289
# Iteration 1308 | Cost: 0.124285
# Iteration 1309 | Cost: 0.124282
# Iteration 1310 | Cost: 0.124279
# Iteration 1311 | Cost: 0.124276
# Iteration 1312 | Cost: 0.124273
# Iteration 1313 | Cost: 0.124270
# Iteration 1314 | Cost: 0.124267
# Iteration 1315 | Cost: 0.124265
# Iteration 1316 | Cost: 0.124262
# Iteration 1317 | Cost: 0.124259
# Iteration 1318 | Cost: 0.124256
# Iteration 1319 | Cost: 0.124253
# Iteration 1320 | Cost: 0.124250
# Iteration 1321 | Cost: 0.124247
# Iteration 1322 | Cost: 0.124245
# Iteration 1323 | Cost: 0.124242
# Iteration 1324 | Cost: 0.124239
# Iteration 1325 | Cost: 0.124236
# Iteration 1326 | Cost: 0.124233
# Iteration 1327 | Cost: 0.124230
# Iteration 1328 | Cost: 0.124227
# Iteration 1329 | Cost: 0.124224
# Iteration 1330 | Cost: 0.124220
# Iteration 1331 | Cost: 0.124217
# Iteration 1332 | Cost: 0.124214
# Iteration 1333 | Cost: 0.124211
# Iteration 1334 | Cost: 0.124207
# Iteration 1335 | Cost: 0.124204
# Iteration 1336 | Cost: 0.124200
# Iteration 1337 | Cost: 0.124197
# Iteration 1338 | Cost: 0.124193
# Iteration 1339 | Cost: 0.124190
# Iteration 1340 | Cost: 0.124186
# Iteration 1341 | Cost: 0.124183
# Iteration 1342 | Cost: 0.124179
# Iteration 1343 | Cost: 0.124176
# Iteration 1344 | Cost: 0.124172
# Iteration 1345 | Cost: 0.124168
# Iteration 1346 | Cost: 0.124165
# Iteration 1347 | Cost: 0.124161
# Iteration 1348 | Cost: 0.124158
# Iteration 1349 | Cost: 0.124154
# Iteration 1350 | Cost: 0.124151
# Iteration 1351 | Cost: 0.124147
# Iteration 1352 | Cost: 0.124144
# Iteration 1353 | Cost: 0.124140
# Iteration 1354 | Cost: 0.124137
# Iteration 1355 | Cost: 0.124133
# Iteration 1356 | Cost: 0.124130
# Iteration 1357 | Cost: 0.124127
# Iteration 1358 | Cost: 0.124124
# Iteration 1359 | Cost: 0.124120
# Iteration 1360 | Cost: 0.124117
# Iteration 1361 | Cost: 0.124114
# Iteration 1362 | Cost: 0.124111
# Iteration 1363 | Cost: 0.124108
# Iteration 1364 | Cost: 0.124105
# Iteration 1365 | Cost: 0.124102
# Iteration 1366 | Cost: 0.124099
# Iteration 1367 | Cost: 0.124096
# Iteration 1368 | Cost: 0.124093
# Iteration 1369 | Cost: 0.124090
# Iteration 1370 | Cost: 0.124087
# Iteration 1371 | Cost: 0.124084
# Iteration 1372 | Cost: 0.124081
# Iteration 1373 | Cost: 0.124078
# Iteration 1374 | Cost: 0.124076
# Iteration 1375 | Cost: 0.124073
# Iteration 1376 | Cost: 0.124070
# Iteration 1377 | Cost: 0.124067
# Iteration 1378 | Cost: 0.124064
# Iteration 1379 | Cost: 0.124062
# Iteration 1380 | Cost: 0.124059
# Iteration 1381 | Cost: 0.124056
# Iteration 1382 | Cost: 0.124053
# Iteration 1383 | Cost: 0.124050
# Iteration 1384 | Cost: 0.124048
# Iteration 1385 | Cost: 0.124045
# Iteration 1386 | Cost: 0.124042
# Iteration 1387 | Cost: 0.124039
# Iteration 1388 | Cost: 0.124036
# Iteration 1389 | Cost: 0.124033
# Iteration 1390 | Cost: 0.124030
# Iteration 1391 | Cost: 0.124027
# Iteration 1392 | Cost: 0.124024
# Iteration 1393 | Cost: 0.124020
# Iteration 1394 | Cost: 0.124017
# Iteration 1395 | Cost: 0.124014
# Iteration 1396 | Cost: 0.124010
# Iteration 1397 | Cost: 0.124007
# Iteration 1398 | Cost: 0.124004
# Iteration 1399 | Cost: 0.124000
# Iteration 1400 | Cost: 0.123997
# Iteration 1401 | Cost: 0.123993
# Iteration 1402 | Cost: 0.123989
# Iteration 1403 | Cost: 0.123986
# Iteration 1404 | Cost: 0.123982
# Iteration 1405 | Cost: 0.123979
# Iteration 1406 | Cost: 0.123975
# Iteration 1407 | Cost: 0.123971
# Iteration 1408 | Cost: 0.123968
# Iteration 1409 | Cost: 0.123964
# Iteration 1410 | Cost: 0.123960
# Iteration 1411 | Cost: 0.123957
# Iteration 1412 | Cost: 0.123953
# Iteration 1413 | Cost: 0.123950
# Iteration 1414 | Cost: 0.123946
# Iteration 1415 | Cost: 0.123942
# Iteration 1416 | Cost: 0.123939
# Iteration 1417 | Cost: 0.123936
# Iteration 1418 | Cost: 0.123932
# Iteration 1419 | Cost: 0.123929
# Iteration 1420 | Cost: 0.123925
# Iteration 1421 | Cost: 0.123922
# Iteration 1422 | Cost: 0.123919
# Iteration 1423 | Cost: 0.123916
# Iteration 1424 | Cost: 0.123912
# Iteration 1425 | Cost: 0.123909
# Iteration 1426 | Cost: 0.123906
# Iteration 1427 | Cost: 0.123903
# Iteration 1428 | Cost: 0.123900
# Iteration 1429 | Cost: 0.123897
# Iteration 1430 | Cost: 0.123894
# Iteration 1431 | Cost: 0.123891
# Iteration 1432 | Cost: 0.123888
# Iteration 1433 | Cost: 0.123885
# Iteration 1434 | Cost: 0.123882
# Iteration 1435 | Cost: 0.123880
# Iteration 1436 | Cost: 0.123877
# Iteration 1437 | Cost: 0.123874
# Iteration 1438 | Cost: 0.123871
# Iteration 1439 | Cost: 0.123868
# Iteration 1440 | Cost: 0.123866
# Iteration 1441 | Cost: 0.123863
# Iteration 1442 | Cost: 0.123860
# Iteration 1443 | Cost: 0.123858
# Iteration 1444 | Cost: 0.123855
# Iteration 1445 | Cost: 0.123852
# Iteration 1446 | Cost: 0.123850
# Iteration 1447 | Cost: 0.123847
# Iteration 1448 | Cost: 0.123844
# Iteration 1449 | Cost: 0.123842
# Iteration 1450 | Cost: 0.123839
# Iteration 1451 | Cost: 0.123836
# Iteration 1452 | Cost: 0.123833
# Iteration 1453 | Cost: 0.123831
# Iteration 1454 | Cost: 0.123828
# Iteration 1455 | Cost: 0.123825
# Iteration 1456 | Cost: 0.123822
# Iteration 1457 | Cost: 0.123820
# Iteration 1458 | Cost: 0.123817
# Iteration 1459 | Cost: 0.123814
# Iteration 1460 | Cost: 0.123811
# Iteration 1461 | Cost: 0.123808
# Iteration 1462 | Cost: 0.123805
# Iteration 1463 | Cost: 0.123803
# Iteration 1464 | Cost: 0.123800
# Iteration 1465 | Cost: 0.123797
# Iteration 1466 | Cost: 0.123794
# Iteration 1467 | Cost: 0.123791
# Iteration 1468 | Cost: 0.123788
# Iteration 1469 | Cost: 0.123785
# Iteration 1470 | Cost: 0.123782
# Iteration 1471 | Cost: 0.123780
# Iteration 1472 | Cost: 0.123777
# Iteration 1473 | Cost: 0.123774
# Iteration 1474 | Cost: 0.123771
# Iteration 1475 | Cost: 0.123768
# Iteration 1476 | Cost: 0.123766
# Iteration 1477 | Cost: 0.123763
# Iteration 1478 | Cost: 0.123760
# Iteration 1479 | Cost: 0.123757
# Iteration 1480 | Cost: 0.123755
# Iteration 1481 | Cost: 0.123752
# Iteration 1482 | Cost: 0.123750
# Iteration 1483 | Cost: 0.123747
# Iteration 1484 | Cost: 0.123744
# Iteration 1485 | Cost: 0.123742
# Iteration 1486 | Cost: 0.123739
# Iteration 1487 | Cost: 0.123737
# Iteration 1488 | Cost: 0.123735
# Iteration 1489 | Cost: 0.123732
# Iteration 1490 | Cost: 0.123730
# Iteration 1491 | Cost: 0.123727
# Iteration 1492 | Cost: 0.123725
# Iteration 1493 | Cost: 0.123723
# Iteration 1494 | Cost: 0.123720
# Iteration 1495 | Cost: 0.123718
# Iteration 1496 | Cost: 0.123716
# Iteration 1497 | Cost: 0.123714
# Iteration 1498 | Cost: 0.123711
# Iteration 1499 | Cost: 0.123709
# Iteration 1500 | Cost: 0.123707
# Iteration 1501 | Cost: 0.123705
# Iteration 1502 | Cost: 0.123703
# Iteration 1503 | Cost: 0.123700
# Iteration 1504 | Cost: 0.123698
# Iteration 1505 | Cost: 0.123696
# Iteration 1506 | Cost: 0.123694
# Iteration 1507 | Cost: 0.123692
# Iteration 1508 | Cost: 0.123689
# Iteration 1509 | Cost: 0.123687
# Iteration 1510 | Cost: 0.123685
# Iteration 1511 | Cost: 0.123683
# Iteration 1512 | Cost: 0.123681
# Iteration 1513 | Cost: 0.123678
# Iteration 1514 | Cost: 0.123676
# Iteration 1515 | Cost: 0.123674
# Iteration 1516 | Cost: 0.123671
# Iteration 1517 | Cost: 0.123669
# Iteration 1518 | Cost: 0.123667
# Iteration 1519 | Cost: 0.123664
# Iteration 1520 | Cost: 0.123662
# Iteration 1521 | Cost: 0.123660
# Iteration 1522 | Cost: 0.123657
# Iteration 1523 | Cost: 0.123655
# Iteration 1524 | Cost: 0.123652
# Iteration 1525 | Cost: 0.123650
# Iteration 1526 | Cost: 0.123647
# Iteration 1527 | Cost: 0.123645
# Iteration 1528 | Cost: 0.123642
# Iteration 1529 | Cost: 0.123640
# Iteration 1530 | Cost: 0.123637
# Iteration 1531 | Cost: 0.123634
# Iteration 1532 | Cost: 0.123632
# Iteration 1533 | Cost: 0.123629
# ...
# Iteration 2500 | Cost: 0.122078
# Iteration 2501 | Cost: 0.122077
# Iteration 2502 | Cost: 0.122076
# Iteration 2503 | Cost: 0.122075
# Iteration 2504 | Cost: 0.122074
# Iteration 2505 | Cost: 0.122073
# Iteration 2506 | Cost: 0.122072
# Iteration 2507 | Cost: 0.122071
# Iteration 2508 | Cost: 0.122071
# Iteration 2509 | Cost: 0.122070
# Iteration 2510 | Cost: 0.122069
# Iteration 2511 | Cost: 0.122068
# Iteration 2512 | Cost: 0.122067
# Iteration 2513 | Cost: 0.122066
# Iteration 2514 | Cost: 0.122065
# Iteration 2515 | Cost: 0.122064
# Iteration 2516 | Cost: 0.122063
# Iteration 2517 | Cost: 0.122062
# Iteration 2518 | Cost: 0.122062
# Iteration 2519 | Cost: 0.122061
# Iteration 2520 | Cost: 0.122060
# Iteration 2521 | Cost: 0.122059
# Iteration 2522 | Cost: 0.122058
# Iteration 2523 | Cost: 0.122057
# Iteration 2524 | Cost: 0.122056
# Iteration 2525 | Cost: 0.122055
# Iteration 2526 | Cost: 0.122055
# Iteration 2527 | Cost: 0.122054
# Iteration 2528 | Cost: 0.122053
# Iteration 2529 | Cost: 0.122052
# Iteration 2530 | Cost: 0.122051
# Iteration 2531 | Cost: 0.122050
# Iteration 2532 | Cost: 0.122049
# Iteration 2533 | Cost: 0.122048
# Iteration 2534 | Cost: 0.122048
# Iteration 2535 | Cost: 0.122047
# Iteration 2536 | Cost: 0.122046
# Iteration 2537 | Cost: 0.122045
# Iteration 2538 | Cost: 0.122044
# Iteration 2539 | Cost: 0.122043
# Iteration 2540 | Cost: 0.122042
# Iteration 2541 | Cost: 0.122041
# Iteration 2542 | Cost: 0.122041
# Iteration 2543 | Cost: 0.122040
# Iteration 2544 | Cost: 0.122039
# Iteration 2545 | Cost: 0.122038
# Iteration 2546 | Cost: 0.122037
# Iteration 2547 | Cost: 0.122036
# Iteration 2548 | Cost: 0.122035
# Iteration 2549 | Cost: 0.122034
# Iteration 2550 | Cost: 0.122034
# Iteration 2551 | Cost: 0.122033
# Iteration 2552 | Cost: 0.122032
# Iteration 2553 | Cost: 0.122031
# Iteration 2554 | Cost: 0.122030
# Iteration 2555 | Cost: 0.122029
# Iteration 2556 | Cost: 0.122028
# Iteration 2557 | Cost: 0.122028
# Iteration 2558 | Cost: 0.122027
# Iteration 2559 | Cost: 0.122026
# Iteration 2560 | Cost: 0.122025
# Iteration 2561 | Cost: 0.122024
# Iteration 2562 | Cost: 0.122023
# Iteration 2563 | Cost: 0.122022
# Iteration 2564 | Cost: 0.122021
# Iteration 2565 | Cost: 0.122021
# Iteration 2566 | Cost: 0.122020
# Iteration 2567 | Cost: 0.122019
# Iteration 2568 | Cost: 0.122018
# Iteration 2569 | Cost: 0.122017
# Iteration 2570 | Cost: 0.122016
# Iteration 2571 | Cost: 0.122015
# Iteration 2572 | Cost: 0.122015
# Iteration 2573 | Cost: 0.122014
# Iteration 2574 | Cost: 0.122013
# Iteration 2575 | Cost: 0.122012
# Iteration 2576 | Cost: 0.122011
# Iteration 2577 | Cost: 0.122010
# Iteration 2578 | Cost: 0.122010
# Iteration 2579 | Cost: 0.122009
# Iteration 2580 | Cost: 0.122008
# Iteration 2581 | Cost: 0.122007
# Iteration 2582 | Cost: 0.122006
# Iteration 2583 | Cost: 0.122005
# Iteration 2584 | Cost: 0.122004
# Iteration 2585 | Cost: 0.122004
# Iteration 2586 | Cost: 0.122003
# Iteration 2587 | Cost: 0.122002
# Iteration 2588 | Cost: 0.122001
# Iteration 2589 | Cost: 0.122000
# Iteration 2590 | Cost: 0.121999
# Iteration 2591 | Cost: 0.121999
# Iteration 2592 | Cost: 0.121998
# Iteration 2593 | Cost: 0.121997
# Iteration 2594 | Cost: 0.121996
# Iteration 2595 | Cost: 0.121995
# Iteration 2596 | Cost: 0.121994
# Iteration 2597 | Cost: 0.121993
# Iteration 2598 | Cost: 0.121993
# Iteration 2599 | Cost: 0.121992
# Iteration 2600 | Cost: 0.121991
# Iteration 2601 | Cost: 0.121990
# Iteration 2602 | Cost: 0.121989
# Iteration 2603 | Cost: 0.121988
# Iteration 2604 | Cost: 0.121988
# Iteration 2605 | Cost: 0.121987
# Iteration 2606 | Cost: 0.121986
# Iteration 2607 | Cost: 0.121985
# Iteration 2608 | Cost: 0.121984
# Iteration 2609 | Cost: 0.121983
# Iteration 2610 | Cost: 0.121983
# Iteration 2611 | Cost: 0.121982
# Iteration 2612 | Cost: 0.121981
# Iteration 2613 | Cost: 0.121980
# Iteration 2614 | Cost: 0.121979
# Iteration 2615 | Cost: 0.121978
# Iteration 2616 | Cost: 0.121978
# Iteration 2617 | Cost: 0.121977
# Iteration 2618 | Cost: 0.121976
# Iteration 2619 | Cost: 0.121975
# Iteration 2620 | Cost: 0.121974
# Iteration 2621 | Cost: 0.121973
# Iteration 2622 | Cost: 0.121973
# Iteration 2623 | Cost: 0.121972
# Iteration 2624 | Cost: 0.121971
# Iteration 2625 | Cost: 0.121970
# Iteration 2626 | Cost: 0.121969
# Iteration 2627 | Cost: 0.121969
# Iteration 2628 | Cost: 0.121968
# Iteration 2629 | Cost: 0.121967
# Iteration 2630 | Cost: 0.121966
# Iteration 2631 | Cost: 0.121965
# Iteration 2632 | Cost: 0.121964
# Iteration 2633 | Cost: 0.121964
# Iteration 2634 | Cost: 0.121963
# Iteration 2635 | Cost: 0.121962
# Iteration 2636 | Cost: 0.121961
# Iteration 2637 | Cost: 0.121960
# Iteration 2638 | Cost: 0.121959
# Iteration 2639 | Cost: 0.121959
# Iteration 2640 | Cost: 0.121958
# Iteration 2641 | Cost: 0.121957
# Iteration 2642 | Cost: 0.121956
# Iteration 2643 | Cost: 0.121955
# Iteration 2644 | Cost: 0.121955
# Iteration 2645 | Cost: 0.121954
# Iteration 2646 | Cost: 0.121953
# Iteration 2647 | Cost: 0.121952
# Iteration 2648 | Cost: 0.121951
# Iteration 2649 | Cost: 0.121951
# Iteration 2650 | Cost: 0.121950
# Iteration 2651 | Cost: 0.121949
# Iteration 2652 | Cost: 0.121948
# Iteration 2653 | Cost: 0.121947
# Iteration 2654 | Cost: 0.121946
# Iteration 2655 | Cost: 0.121946
# Iteration 2656 | Cost: 0.121945
# Iteration 2657 | Cost: 0.121944
# Iteration 2658 | Cost: 0.121943
# Iteration 2659 | Cost: 0.121942
# Iteration 2660 | Cost: 0.121942
# Iteration 2661 | Cost: 0.121941
# Iteration 2662 | Cost: 0.121940
# Iteration 2663 | Cost: 0.121939
# Iteration 2664 | Cost: 0.121938
# Iteration 2665 | Cost: 0.121938
# Iteration 2666 | Cost: 0.121937
# Iteration 2667 | Cost: 0.121936
# Iteration 2668 | Cost: 0.121935
# Iteration 2669 | Cost: 0.121934
# Iteration 2670 | Cost: 0.121934
# Iteration 2671 | Cost: 0.121933
# Iteration 2672 | Cost: 0.121932
# Iteration 2673 | Cost: 0.121931
# Iteration 2674 | Cost: 0.121930
# Iteration 2675 | Cost: 0.121930
# Iteration 2676 | Cost: 0.121929
# Iteration 2677 | Cost: 0.121928
# Iteration 2678 | Cost: 0.121927
# Iteration 2679 | Cost: 0.121926
# Iteration 2680 | Cost: 0.121926
# Iteration 2681 | Cost: 0.121925
# Iteration 2682 | Cost: 0.121924
# Iteration 2683 | Cost: 0.121923
# Iteration 2684 | Cost: 0.121922
# Iteration 2685 | Cost: 0.121922
# Iteration 2686 | Cost: 0.121921
# Iteration 2687 | Cost: 0.121920
# Iteration 2688 | Cost: 0.121919
# Iteration 2689 | Cost: 0.121918
# Iteration 2690 | Cost: 0.121918
# Iteration 2691 | Cost: 0.121917
# Iteration 2692 | Cost: 0.121916
# Iteration 2693 | Cost: 0.121915
# Iteration 2694 | Cost: 0.121914
# Iteration 2695 | Cost: 0.121914
# Iteration 2696 | Cost: 0.121913
# Iteration 2697 | Cost: 0.121912
# Iteration 2698 | Cost: 0.121911
# Iteration 2699 | Cost: 0.121910
# Iteration 2700 | Cost: 0.121910
# Iteration 2701 | Cost: 0.121909
# Iteration 2702 | Cost: 0.121908
# Iteration 2703 | Cost: 0.121907
# Iteration 2704 | Cost: 0.121906
# Iteration 2705 | Cost: 0.121906
# Iteration 2706 | Cost: 0.121905
# Iteration 2707 | Cost: 0.121904
# Iteration 2708 | Cost: 0.121903
# Iteration 2709 | Cost: 0.121903
# Iteration 2710 | Cost: 0.121902
# Iteration 2711 | Cost: 0.121901
# Iteration 2712 | Cost: 0.121900
# Iteration 2713 | Cost: 0.121899
# Iteration 2714 | Cost: 0.121899
# Iteration 2715 | Cost: 0.121898
# Iteration 2716 | Cost: 0.121897
# Iteration 2717 | Cost: 0.121896
# Iteration 2718 | Cost: 0.121895
# Iteration 2719 | Cost: 0.121895
# Iteration 2720 | Cost: 0.121894
# Iteration 2721 | Cost: 0.121893
# Iteration 2722 | Cost: 0.121892
# Iteration 2723 | Cost: 0.121892
# Iteration 2724 | Cost: 0.121891
# Iteration 2725 | Cost: 0.121890
# Iteration 2726 | Cost: 0.121889
# Iteration 2727 | Cost: 0.121888
# Iteration 2728 | Cost: 0.121888
# Iteration 2729 | Cost: 0.121887
# Iteration 2730 | Cost: 0.121886
# Iteration 2731 | Cost: 0.121885
# Iteration 2732 | Cost: 0.121885
# Iteration 2733 | Cost: 0.121884
# Iteration 2734 | Cost: 0.121883
# Iteration 2735 | Cost: 0.121882
# Iteration 2736 | Cost: 0.121881
# Iteration 2737 | Cost: 0.121881
# Iteration 2738 | Cost: 0.121880
# Iteration 2739 | Cost: 0.121879
# Iteration 2740 | Cost: 0.121878
# Iteration 2741 | Cost: 0.121878
# Iteration 2742 | Cost: 0.121877
# Iteration 2743 | Cost: 0.121876
# Iteration 2744 | Cost: 0.121875
# Iteration 2745 | Cost: 0.121874
# Iteration 2746 | Cost: 0.121874
# Iteration 2747 | Cost: 0.121873
# Iteration 2748 | Cost: 0.121872
# Iteration 2749 | Cost: 0.121871
# Iteration 2750 | Cost: 0.121871
# Iteration 2751 | Cost: 0.121870
# Iteration 2752 | Cost: 0.121869
# Iteration 2753 | Cost: 0.121868
# Iteration 2754 | Cost: 0.121868
# Iteration 2755 | Cost: 0.121867
# Iteration 2756 | Cost: 0.121866
# Iteration 2757 | Cost: 0.121865
# Iteration 2758 | Cost: 0.121864
# Iteration 2759 | Cost: 0.121864
# Iteration 2760 | Cost: 0.121863
# Iteration 2761 | Cost: 0.121862
# Iteration 2762 | Cost: 0.121861
# Iteration 2763 | Cost: 0.121861
# Iteration 2764 | Cost: 0.121860
# Iteration 2765 | Cost: 0.121859
# Iteration 2766 | Cost: 0.121858
# Iteration 2767 | Cost: 0.121858
# Iteration 2768 | Cost: 0.121857
# Iteration 2769 | Cost: 0.121856
# Iteration 2770 | Cost: 0.121855
# Iteration 2771 | Cost: 0.121855
# Iteration 2772 | Cost: 0.121854
# Iteration 2773 | Cost: 0.121853
# Iteration 2774 | Cost: 0.121852
# Iteration 2775 | Cost: 0.121851
# Iteration 2776 | Cost: 0.121851
# Iteration 2777 | Cost: 0.121850
# Iteration 2778 | Cost: 0.121849
# Iteration 2779 | Cost: 0.121848
# Iteration 2780 | Cost: 0.121848
# Iteration 2781 | Cost: 0.121847
# Iteration 2782 | Cost: 0.121846
# Iteration 2783 | Cost: 0.121845
# Iteration 2784 | Cost: 0.121845
# Iteration 2785 | Cost: 0.121844
# Iteration 2786 | Cost: 0.121843
# Iteration 2787 | Cost: 0.121842
# Iteration 2788 | Cost: 0.121842
# Iteration 2789 | Cost: 0.121841
# Iteration 2790 | Cost: 0.121840
# Iteration 2791 | Cost: 0.121839
# Iteration 2792 | Cost: 0.121839
# Iteration 2793 | Cost: 0.121838
# Iteration 2794 | Cost: 0.121837
# Iteration 2795 | Cost: 0.121836
# Iteration 2796 | Cost: 0.121836
# Iteration 2797 | Cost: 0.121835
# Iteration 2798 | Cost: 0.121834
# Iteration 2799 | Cost: 0.121833
# Iteration 2800 | Cost: 0.121833
# Iteration 2801 | Cost: 0.121832
# Iteration 2802 | Cost: 0.121831
# Iteration 2803 | Cost: 0.121830
# Iteration 2804 | Cost: 0.121830
# Iteration 2805 | Cost: 0.121829
# Iteration 2806 | Cost: 0.121828
# Iteration 2807 | Cost: 0.121827
# Iteration 2808 | Cost: 0.121827
# Iteration 2809 | Cost: 0.121826
# Iteration 2810 | Cost: 0.121825
# Iteration 2811 | Cost: 0.121824
# Iteration 2812 | Cost: 0.121824
# Iteration 2813 | Cost: 0.121823
# Iteration 2814 | Cost: 0.121822
# Iteration 2815 | Cost: 0.121821
# Iteration 2816 | Cost: 0.121821
# Iteration 2817 | Cost: 0.121820
# Iteration 2818 | Cost: 0.121819
# Iteration 2819 | Cost: 0.121818
# Iteration 2820 | Cost: 0.121818
# Iteration 2821 | Cost: 0.121817
# Iteration 2822 | Cost: 0.121816
# Iteration 2823 | Cost: 0.121815
# Iteration 2824 | Cost: 0.121815
# Iteration 2825 | Cost: 0.121814
# Iteration 2826 | Cost: 0.121813
# Iteration 2827 | Cost: 0.121812
# Iteration 2828 | Cost: 0.121812
# Iteration 2829 | Cost: 0.121811
# Iteration 2830 | Cost: 0.121810
# Iteration 2831 | Cost: 0.121809
# Iteration 2832 | Cost: 0.121809
# Iteration 2833 | Cost: 0.121808
# Iteration 2834 | Cost: 0.121807
# Iteration 2835 | Cost: 0.121807
# Iteration 2836 | Cost: 0.121806
# Iteration 2837 | Cost: 0.121805
# Iteration 2838 | Cost: 0.121804
# Iteration 2839 | Cost: 0.121804
# Iteration 2840 | Cost: 0.121803
# Iteration 2841 | Cost: 0.121802
# Iteration 2842 | Cost: 0.121801
# Iteration 2843 | Cost: 0.121801
# Iteration 2844 | Cost: 0.121800
# Iteration 2845 | Cost: 0.121799
# Iteration 2846 | Cost: 0.121798
# Iteration 2847 | Cost: 0.121798
# Iteration 2848 | Cost: 0.121797
# Iteration 2849 | Cost: 0.121796
# Iteration 2850 | Cost: 0.121796
# Iteration 2851 | Cost: 0.121795
# Iteration 2852 | Cost: 0.121794
# Iteration 2853 | Cost: 0.121793
# Iteration 2854 | Cost: 0.121793
# Iteration 2855 | Cost: 0.121792
# Iteration 2856 | Cost: 0.121791
# Iteration 2857 | Cost: 0.121790
# Iteration 2858 | Cost: 0.121790
# Iteration 2859 | Cost: 0.121789
# Iteration 2860 | Cost: 0.121788
# Iteration 2861 | Cost: 0.121788
# Iteration 2862 | Cost: 0.121787
# Iteration 2863 | Cost: 0.121786
# Iteration 2864 | Cost: 0.121785
# Iteration 2865 | Cost: 0.121785
# Iteration 2866 | Cost: 0.121784
# Iteration 2867 | Cost: 0.121783
# Iteration 2868 | Cost: 0.121782
# Iteration 2869 | Cost: 0.121782
# Iteration 2870 | Cost: 0.121781
# Iteration 2871 | Cost: 0.121780
# Iteration 2872 | Cost: 0.121780
# Iteration 2873 | Cost: 0.121779
# Iteration 2874 | Cost: 0.121778
# Iteration 2875 | Cost: 0.121777
# Iteration 2876 | Cost: 0.121777
# Iteration 2877 | Cost: 0.121776
# Iteration 2878 | Cost: 0.121775
# Iteration 2879 | Cost: 0.121774
# Iteration 2880 | Cost: 0.121774
# Iteration 2881 | Cost: 0.121773
# Iteration 2882 | Cost: 0.121772
# Iteration 2883 | Cost: 0.121772
# Iteration 2884 | Cost: 0.121771
# Iteration 2885 | Cost: 0.121770
# Iteration 2886 | Cost: 0.121769
# Iteration 2887 | Cost: 0.121769
# Iteration 2888 | Cost: 0.121768
# Iteration 2889 | Cost: 0.121767
# Iteration 2890 | Cost: 0.121767
# Iteration 2891 | Cost: 0.121766
# Iteration 2892 | Cost: 0.121765
# Iteration 2893 | Cost: 0.121764
# Iteration 2894 | Cost: 0.121764
# Iteration 2895 | Cost: 0.121763
# Iteration 2896 | Cost: 0.121762
# Iteration 2897 | Cost: 0.121762
# Iteration 2898 | Cost: 0.121761
# Iteration 2899 | Cost: 0.121760
# Iteration 2900 | Cost: 0.121759
# Iteration 2901 | Cost: 0.121759
# Iteration 2902 | Cost: 0.121758
# Iteration 2903 | Cost: 0.121757
# Iteration 2904 | Cost: 0.121757
# Iteration 2905 | Cost: 0.121756
# Iteration 2906 | Cost: 0.121755
# Iteration 2907 | Cost: 0.121754
# Iteration 2908 | Cost: 0.121754
# Iteration 2909 | Cost: 0.121753
# Iteration 2910 | Cost: 0.121752
# Iteration 2911 | Cost: 0.121752
# Iteration 2912 | Cost: 0.121751
# Iteration 2913 | Cost: 0.121750
# Iteration 2914 | Cost: 0.121750
# Iteration 2915 | Cost: 0.121749
# Iteration 2916 | Cost: 0.121748
# Iteration 2917 | Cost: 0.121747
# Iteration 2918 | Cost: 0.121747
# Iteration 2919 | Cost: 0.121746
# Iteration 2920 | Cost: 0.121745
# Iteration 2921 | Cost: 0.121745
# Iteration 2922 | Cost: 0.121744
# Iteration 2923 | Cost: 0.121743
# Iteration 2924 | Cost: 0.121742
# Iteration 2925 | Cost: 0.121742
# Iteration 2926 | Cost: 0.121741
# Iteration 2927 | Cost: 0.121740
# Iteration 2928 | Cost: 0.121740
# Iteration 2929 | Cost: 0.121739
# Iteration 2930 | Cost: 0.121738
# Iteration 2931 | Cost: 0.121738
# Iteration 2932 | Cost: 0.121737
# Iteration 2933 | Cost: 0.121736
# Iteration 2934 | Cost: 0.121735
# Iteration 2935 | Cost: 0.121735
# Iteration 2936 | Cost: 0.121734
# Iteration 2937 | Cost: 0.121733
# Iteration 2938 | Cost: 0.121733
# Iteration 2939 | Cost: 0.121732
# Iteration 2940 | Cost: 0.121731
# Iteration 2941 | Cost: 0.121731
# Iteration 2942 | Cost: 0.121730
# Iteration 2943 | Cost: 0.121729
# Iteration 2944 | Cost: 0.121728
# Iteration 2945 | Cost: 0.121728
# Iteration 2946 | Cost: 0.121727
# Iteration 2947 | Cost: 0.121726
# Iteration 2948 | Cost: 0.121726
# Iteration 2949 | Cost: 0.121725
# Iteration 2950 | Cost: 0.121724
# Iteration 2951 | Cost: 0.121724
# Iteration 2952 | Cost: 0.121723
# Iteration 2953 | Cost: 0.121722
# Iteration 2954 | Cost: 0.121722
# Iteration 2955 | Cost: 0.121721
# Iteration 2956 | Cost: 0.121720
# Iteration 2957 | Cost: 0.121719
# Iteration 2958 | Cost: 0.121719
# Iteration 2959 | Cost: 0.121718
# Iteration 2960 | Cost: 0.121717
# Iteration 2961 | Cost: 0.121717
# Iteration 2962 | Cost: 0.121716
# Iteration 2963 | Cost: 0.121715
# Iteration 2964 | Cost: 0.121715
# Iteration 2965 | Cost: 0.121714
# Iteration 2966 | Cost: 0.121713
# Iteration 2967 | Cost: 0.121713
# Iteration 2968 | Cost: 0.121712
# Iteration 2969 | Cost: 0.121711
# Iteration 2970 | Cost: 0.121710
# Iteration 2971 | Cost: 0.121710
# Iteration 2972 | Cost: 0.121709
# Iteration 2973 | Cost: 0.121708
# Iteration 2974 | Cost: 0.121708
# Iteration 2975 | Cost: 0.121707
# Iteration 2976 | Cost: 0.121706
# Iteration 2977 | Cost: 0.121706
# Iteration 2978 | Cost: 0.121705
# Iteration 2979 | Cost: 0.121704
# Iteration 2980 | Cost: 0.121704
# Iteration 2981 | Cost: 0.121703
# Iteration 2982 | Cost: 0.121702
# Iteration 2983 | Cost: 0.121702
# Iteration 2984 | Cost: 0.121701
# Iteration 2985 | Cost: 0.121700
# Iteration 2986 | Cost: 0.121700
# Iteration 2987 | Cost: 0.121699
# Iteration 2988 | Cost: 0.121698
# Iteration 2989 | Cost: 0.121697
# Iteration 2990 | Cost: 0.121697
# Iteration 2991 | Cost: 0.121696
# Iteration 2992 | Cost: 0.121695
# Iteration 2993 | Cost: 0.121695
# Iteration 2994 | Cost: 0.121694
# Iteration 2995 | Cost: 0.121693
# Iteration 2996 | Cost: 0.121693
# Iteration 2997 | Cost: 0.121692
# Iteration 2998 | Cost: 0.121691
# Iteration 2999 | Cost: 0.121691

# %%
# accuracy FLDA + SOFTMAX Quad Kernel= 0.82

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareFMNISTData()

# %%
y_pred = multiClassLogisticRegression(X_test, X_train, y_train, 10, 500, alpha = 0.0000001, beta = 0.999)
# Out:
# (59998, 785)
# Iteration 0 | Cost: 0.487148
# Iteration 1 | Cost: 0.483560
# Iteration 2 | Cost: 0.477252
# Iteration 3 | Cost: 0.469505
# Iteration 4 | Cost: 0.461482
# Iteration 5 | Cost: 0.454001
# Iteration 6 | Cost: 0.447503
# Iteration 7 | Cost: 0.441818
# Iteration 8 | Cost: 0.435932
# Iteration 9 | Cost: 0.428289
# Iteration 10 | Cost: 0.417559
# Iteration 11 | Cost: 0.403260
# Iteration 12 | Cost: 0.385852
# Iteration 13 | Cost: 0.366408
# Iteration 14 | Cost: 0.346219
# Iteration 15 | Cost: 0.326621
# Iteration 16 | Cost: 0.308977
# Iteration 17 | Cost: 0.294417
# Iteration 18 | Cost: 0.283379
# Iteration 19 | Cost: 0.275394
# Iteration 20 | Cost: 0.269361
# Iteration 21 | Cost: 0.264057
# Iteration 22 | Cost: 0.258595
# Iteration 23 | Cost: 0.252692
# Iteration 24 | Cost: 0.246649
# Iteration 25 | Cost: 0.241044
# Iteration 26 | Cost: 0.236336
# Iteration 27 | Cost: 0.232622
# Iteration 28 | Cost: 0.229696
# Iteration 29 | Cost: 0.227254
# Iteration 30 | Cost: 0.225097
# Iteration 31 | Cost: 0.223210
# Iteration 32 | Cost: 0.221729
# Iteration 33 | Cost: 0.220829
# Iteration 34 | Cost: 0.220594
# Iteration 35 | Cost: 0.220937
# Iteration 36 | Cost: 0.221600
# Iteration 37 | Cost: 0.222226
# Iteration 38 | Cost: 0.222464
# Iteration 39 | Cost: 0.222055
# Iteration 40 | Cost: 0.220890
# Iteration 41 | Cost: 0.219023
# Iteration 42 | Cost: 0.216649
# Iteration 43 | Cost: 0.214046
# Iteration 44 | Cost: 0.211502
# Iteration 45 | Cost: 0.209247
# Iteration 46 | Cost: 0.207407
# Iteration 47 | Cost: 0.205998
# Iteration 48 | Cost: 0.204967
# Iteration 49 | Cost: 0.204233
# Iteration 50 | Cost: 0.203723
# Iteration 51 | Cost: 0.203384
# Iteration 52 | Cost: 0.203196
# Iteration 53 | Cost: 0.203163
# Iteration 54 | Cost: 0.203292
# Iteration 55 | Cost: 0.203573
# Iteration 56 | Cost: 0.203966
# Iteration 57 | Cost: 0.204393
# Iteration 58 | Cost: 0.204754
# Iteration 59 | Cost: 0.204950
# Iteration 60 | Cost: 0.204901
# Iteration 61 | Cost: 0.204566
# Iteration 62 | Cost: 0.203942
# Iteration 63 | Cost: 0.203062
# Iteration 64 | Cost: 0.201980
# Iteration 65 | Cost: 0.200762
# Iteration 66 | Cost: 0.199469
# Iteration 67 | Cost: 0.198150
# Iteration 68 | Cost: 0.196841
# Iteration 69 | Cost: 0.195565
# Iteration 70 | Cost: 0.194333
# Iteration 71 | Cost: 0.193152
# Iteration 72 | Cost: 0.192027
# Iteration 73 | Cost: 0.190964
# Iteration 74 | Cost: 0.189976
# Iteration 75 | Cost: 0.189076
# Iteration 76 | Cost: 0.188284
# Iteration 77 | Cost: 0.187622
# Iteration 78 | Cost: 0.187109
# Iteration 79 | Cost: 0.186752
# Iteration 80 | Cost: 0.186543
# Iteration 81 | Cost: 0.186455
# Iteration 82 | Cost: 0.186439
# Iteration 83 | Cost: 0.186437
# Iteration 84 | Cost: 0.186389
# Iteration 85 | Cost: 0.186245
# Iteration 86 | Cost: 0.185977
# Iteration 87 | Cost: 0.185581
# Iteration 88 | Cost: 0.185078
# Iteration 89 | Cost: 0.184504
# Iteration 90 | Cost: 0.183901
# Iteration 91 | Cost: 0.183311
# Iteration 92 | Cost: 0.182760
# Iteration 93 | Cost: 0.182260
# Iteration 94 | Cost: 0.181807
# Iteration 95 | Cost: 0.181386
# Iteration 96 | Cost: 0.180974
# Iteration 97 | Cost: 0.180549
# Iteration 98 | Cost: 0.180096
# Iteration 99 | Cost: 0.179609
# Iteration 100 | Cost: 0.179092
# Iteration 101 | Cost: 0.178561
# Iteration 102 | Cost: 0.178039
# Iteration 103 | Cost: 0.177556
# Iteration 104 | Cost: 0.177139
# Iteration 105 | Cost: 0.176806
# Iteration 106 | Cost: 0.176562
# Iteration 107 | Cost: 0.176398
# Iteration 108 | Cost: 0.176285
# Iteration 109 | Cost: 0.176184
# Iteration 110 | Cost: 0.176049
# Iteration 111 | Cost: 0.175838
# Iteration 112 | Cost: 0.175519
# Iteration 113 | Cost: 0.175075
# Iteration 114 | Cost: 0.174507
# Iteration 115 | Cost: 0.173835
# Iteration 116 | Cost: 0.173092
# Iteration 117 | Cost: 0.172318
# Iteration 118 | Cost: 0.171555
# Iteration 119 | Cost: 0.170838
# Iteration 120 | Cost: 0.170191
# Iteration 121 | Cost: 0.169625
# Iteration 122 | Cost: 0.169135
# Iteration 123 | Cost: 0.168708
# Iteration 124 | Cost: 0.168324
# Iteration 125 | Cost: 0.167962
# Iteration 126 | Cost: 0.167606
# Iteration 127 | Cost: 0.167246
# Iteration 128 | Cost: 0.166884
# Iteration 129 | Cost: 0.166527
# Iteration 130 | Cost: 0.166192
# Iteration 131 | Cost: 0.165903
# Iteration 132 | Cost: 0.165681
# Iteration 133 | Cost: 0.165544
# Iteration 134 | Cost: 0.165503
# Iteration 135 | Cost: 0.165554
# Iteration 136 | Cost: 0.165681
# Iteration 137 | Cost: 0.165855
# Iteration 138 | Cost: 0.166040
# Iteration 139 | Cost: 0.166197
# Iteration 140 | Cost: 0.166290
# Iteration 141 | Cost: 0.166297
# Iteration 142 | Cost: 0.166209
# Iteration 143 | Cost: 0.166036
# Iteration 144 | Cost: 0.165800
# Iteration 145 | Cost: 0.165535
# Iteration 146 | Cost: 0.165277
# Iteration 147 | Cost: 0.165057
# Iteration 148 | Cost: 0.164896
# Iteration 149 | Cost: 0.164803
# Iteration 150 | Cost: 0.164773
# Iteration 151 | Cost: 0.164791
# Iteration 152 | Cost: 0.164837
# Iteration 153 | Cost: 0.164887
# Iteration 154 | Cost: 0.164923
# Iteration 155 | Cost: 0.164932
# Iteration 156 | Cost: 0.164907
# Iteration 157 | Cost: 0.164854
# Iteration 158 | Cost: 0.164784
# Iteration 159 | Cost: 0.164715
# Iteration 160 | Cost: 0.164669
# Iteration 161 | Cost: 0.164667
# Iteration 162 | Cost: 0.164726
# Iteration 163 | Cost: 0.164856
# Iteration 164 | Cost: 0.165053
# Iteration 165 | Cost: 0.165303
# Iteration 166 | Cost: 0.165581
# Iteration 167 | Cost: 0.165853
# Iteration 168 | Cost: 0.166085
# Iteration 169 | Cost: 0.166246
# Iteration 170 | Cost: 0.166316
# Iteration 171 | Cost: 0.166288
# Iteration 172 | Cost: 0.166168
# Iteration 173 | Cost: 0.165979
# Iteration 174 | Cost: 0.165747
# Iteration 175 | Cost: 0.165504
# Iteration 176 | Cost: 0.165277
# Iteration 177 | Cost: 0.165086
# Iteration 178 | Cost: 0.164942
# Iteration 179 | Cost: 0.164842
# Iteration 180 | Cost: 0.164779
# Iteration 181 | Cost: 0.164738
# Iteration 182 | Cost: 0.164703
# Iteration 183 | Cost: 0.164663
# Iteration 184 | Cost: 0.164608
# Iteration 185 | Cost: 0.164536
# Iteration 186 | Cost: 0.164451
# Iteration 187 | Cost: 0.164366
# Iteration 188 | Cost: 0.164294
# Iteration 189 | Cost: 0.164255
# Iteration 190 | Cost: 0.164265
# Iteration 191 | Cost: 0.164338
# Iteration 192 | Cost: 0.164482
# Iteration 193 | Cost: 0.164694
# Iteration 194 | Cost: 0.164961
# Iteration 195 | Cost: 0.165262
# Iteration 196 | Cost: 0.165571
# Iteration 197 | Cost: 0.165856
# Iteration 198 | Cost: 0.166088
# Iteration 199 | Cost: 0.166246
# Iteration 200 | Cost: 0.166316
# Iteration 201 | Cost: 0.166295
# Iteration 202 | Cost: 0.166191
# Iteration 203 | Cost: 0.166023
# Iteration 204 | Cost: 0.165813
# Iteration 205 | Cost: 0.165586
# Iteration 206 | Cost: 0.165366
# Iteration 207 | Cost: 0.165171
# Iteration 208 | Cost: 0.165010
# Iteration 209 | Cost: 0.164887
# Iteration 210 | Cost: 0.164796
# Iteration 211 | Cost: 0.164728
# Iteration 212 | Cost: 0.164670
# Iteration 213 | Cost: 0.164607
# Iteration 214 | Cost: 0.164527
# Iteration 215 | Cost: 0.164424
# Iteration 216 | Cost: 0.164292
# Iteration 217 | Cost: 0.164132
# Iteration 218 | Cost: 0.163952
# Iteration 219 | Cost: 0.163760
# Iteration 220 | Cost: 0.163569
# Iteration 221 | Cost: 0.163391
# Iteration 222 | Cost: 0.163238
# Iteration 223 | Cost: 0.163115
# Iteration 224 | Cost: 0.163024
# Iteration 225 | Cost: 0.162961
# Iteration 226 | Cost: 0.162913
# Iteration 227 | Cost: 0.162867
# Iteration 228 | Cost: 0.162805
# Iteration 229 | Cost: 0.162712
# Iteration 230 | Cost: 0.162574
# Iteration 231 | Cost: 0.162383
# Iteration 232 | Cost: 0.162140
# Iteration 233 | Cost: 0.161850
# Iteration 234 | Cost: 0.161524
# Iteration 235 | Cost: 0.161181
# Iteration 236 | Cost: 0.160839
# Iteration 237 | Cost: 0.160516
# Iteration 238 | Cost: 0.160227
# Iteration 239 | Cost: 0.159986
# Iteration 240 | Cost: 0.159798
# Iteration 241 | Cost: 0.159663
# Iteration 242 | Cost: 0.159578
# Iteration 243 | Cost: 0.159537
# Iteration 244 | Cost: 0.159531
# Iteration 245 | Cost: 0.159549
# Iteration 246 | Cost: 0.159583
# Iteration 247 | Cost: 0.159627
# Iteration 248 | Cost: 0.159676
# Iteration 249 | Cost: 0.159729
# Iteration 250 | Cost: 0.159787
# Iteration 251 | Cost: 0.159853
# Iteration 252 | Cost: 0.159932
# Iteration 253 | Cost: 0.160029
# Iteration 254 | Cost: 0.160148
# Iteration 255 | Cost: 0.160292
# Iteration 256 | Cost: 0.160460
# Iteration 257 | Cost: 0.160649
# Iteration 258 | Cost: 0.160854
# Iteration 259 | Cost: 0.161063
# Iteration 260 | Cost: 0.161267
# Iteration 261 | Cost: 0.161453
# Iteration 262 | Cost: 0.161610
# Iteration 263 | Cost: 0.161728
# Iteration 264 | Cost: 0.161801
# Iteration 265 | Cost: 0.161829
# Iteration 266 | Cost: 0.161813
# Iteration 267 | Cost: 0.161762
# Iteration 268 | Cost: 0.161685
# Iteration 269 | Cost: 0.161596
# Iteration 270 | Cost: 0.161508
# Iteration 271 | Cost: 0.161435
# Iteration 272 | Cost: 0.161386
# Iteration 273 | Cost: 0.161368
# Iteration 274 | Cost: 0.161386
# Iteration 275 | Cost: 0.161440
# Iteration 276 | Cost: 0.161528
# Iteration 277 | Cost: 0.161646
# Iteration 278 | Cost: 0.161786
# Iteration 279 | Cost: 0.161943
# Iteration 280 | Cost: 0.162110
# Iteration 281 | Cost: 0.162282
# Iteration 282 | Cost: 0.162455
# Iteration 283 | Cost: 0.162625
# Iteration 284 | Cost: 0.162791
# Iteration 285 | Cost: 0.162954
# Iteration 286 | Cost: 0.163114
# Iteration 287 | Cost: 0.163275
# Iteration 288 | Cost: 0.163439
# Iteration 289 | Cost: 0.163608
# Iteration 290 | Cost: 0.163783
# Iteration 291 | Cost: 0.163966
# Iteration 292 | Cost: 0.164154
# Iteration 293 | Cost: 0.164343
# Iteration 294 | Cost: 0.164528
# Iteration 295 | Cost: 0.164703
# Iteration 296 | Cost: 0.164858
# Iteration 297 | Cost: 0.164985
# Iteration 298 | Cost: 0.165076
# Iteration 299 | Cost: 0.165126
# Iteration 300 | Cost: 0.165131
# Iteration 301 | Cost: 0.165091
# Iteration 302 | Cost: 0.165008
# Iteration 303 | Cost: 0.164887
# Iteration 304 | Cost: 0.164737
# Iteration 305 | Cost: 0.164567
# Iteration 306 | Cost: 0.164388
# Iteration 307 | Cost: 0.164210
# Iteration 308 | Cost: 0.164041
# Iteration 309 | Cost: 0.163888
# Iteration 310 | Cost: 0.163756
# Iteration 311 | Cost: 0.163648
# Iteration 312 | Cost: 0.163562
# Iteration 313 | Cost: 0.163498
# Iteration 314 | Cost: 0.163450
# Iteration 315 | Cost: 0.163416
# Iteration 316 | Cost: 0.163389
# Iteration 317 | Cost: 0.163366
# Iteration 318 | Cost: 0.163343
# Iteration 319 | Cost: 0.163317
# Iteration 320 | Cost: 0.163287
# Iteration 321 | Cost: 0.163253
# Iteration 322 | Cost: 0.163218
# Iteration 323 | Cost: 0.163182
# Iteration 324 | Cost: 0.163149
# Iteration 325 | Cost: 0.163121
# Iteration 326 | Cost: 0.163101
# Iteration 327 | Cost: 0.163089
# Iteration 328 | Cost: 0.163086
# Iteration 329 | Cost: 0.163088
# Iteration 330 | Cost: 0.163092
# Iteration 331 | Cost: 0.163094
# Iteration 332 | Cost: 0.163085
# Iteration 333 | Cost: 0.163059
# Iteration 334 | Cost: 0.163008
# Iteration 335 | Cost: 0.162925
# Iteration 336 | Cost: 0.162805
# Iteration 337 | Cost: 0.162645
# Iteration 338 | Cost: 0.162442
# Iteration 339 | Cost: 0.162198
# Iteration 340 | Cost: 0.161916
# Iteration 341 | Cost: 0.161602
# Iteration 342 | Cost: 0.161264
# Iteration 343 | Cost: 0.160909
# Iteration 344 | Cost: 0.160545
# Iteration 345 | Cost: 0.160182
# Iteration 346 | Cost: 0.159826
# Iteration 347 | Cost: 0.159484
# Iteration 348 | Cost: 0.159158
# Iteration 349 | Cost: 0.158853
# Iteration 350 | Cost: 0.158567
# Iteration 351 | Cost: 0.158300
# Iteration 352 | Cost: 0.158050
# Iteration 353 | Cost: 0.157814
# Iteration 354 | Cost: 0.157588
# Iteration 355 | Cost: 0.157369
# Iteration 356 | Cost: 0.157154
# Iteration 357 | Cost: 0.156942
# Iteration 358 | Cost: 0.156731
# Iteration 359 | Cost: 0.156522
# Iteration 360 | Cost: 0.156317
# Iteration 361 | Cost: 0.156118
# Iteration 362 | Cost: 0.155929
# Iteration 363 | Cost: 0.155752
# Iteration 364 | Cost: 0.155592
# Iteration 365 | Cost: 0.155449
# Iteration 366 | Cost: 0.155325
# Iteration 367 | Cost: 0.155219
# Iteration 368 | Cost: 0.155129
# Iteration 369 | Cost: 0.155050
# Iteration 370 | Cost: 0.154976
# Iteration 371 | Cost: 0.154901
# Iteration 372 | Cost: 0.154816
# Iteration 373 | Cost: 0.154714
# Iteration 374 | Cost: 0.154589
# Iteration 375 | Cost: 0.154438
# Iteration 376 | Cost: 0.154257
# Iteration 377 | Cost: 0.154048
# Iteration 378 | Cost: 0.153812
# Iteration 379 | Cost: 0.153557
# Iteration 380 | Cost: 0.153288
# Iteration 381 | Cost: 0.153014
# Iteration 382 | Cost: 0.152742
# Iteration 383 | Cost: 0.152481
# Iteration 384 | Cost: 0.152236
# Iteration 385 | Cost: 0.152012
# Iteration 386 | Cost: 0.151812
# Iteration 387 | Cost: 0.151636
# Iteration 388 | Cost: 0.151484
# Iteration 389 | Cost: 0.151352
# Iteration 390 | Cost: 0.151236
# Iteration 391 | Cost: 0.151133
# Iteration 392 | Cost: 0.151038
# Iteration 393 | Cost: 0.150947
# Iteration 394 | Cost: 0.150858
# Iteration 395 | Cost: 0.150769
# Iteration 396 | Cost: 0.150680
# Iteration 397 | Cost: 0.150593
# Iteration 398 | Cost: 0.150511
# Iteration 399 | Cost: 0.150438
# Iteration 400 | Cost: 0.150378
# Iteration 401 | Cost: 0.150336
# Iteration 402 | Cost: 0.150316
# Iteration 403 | Cost: 0.150321
# Iteration 404 | Cost: 0.150351
# Iteration 405 | Cost: 0.150405
# Iteration 406 | Cost: 0.150480
# Iteration 407 | Cost: 0.150569
# Iteration 408 | Cost: 0.150664
# Iteration 409 | Cost: 0.150756
# Iteration 410 | Cost: 0.150835
# Iteration 411 | Cost: 0.150892
# Iteration 412 | Cost: 0.150918
# Iteration 413 | Cost: 0.150910
# Iteration 414 | Cost: 0.150864
# Iteration 415 | Cost: 0.150782
# Iteration 416 | Cost: 0.150669
# Iteration 417 | Cost: 0.150530
# Iteration 418 | Cost: 0.150375
# Iteration 419 | Cost: 0.150212
# Iteration 420 | Cost: 0.150050
# Iteration 421 | Cost: 0.149896
# Iteration 422 | Cost: 0.149755
# Iteration 423 | Cost: 0.149631
# Iteration 424 | Cost: 0.149524
# Iteration 425 | Cost: 0.149432
# Iteration 426 | Cost: 0.149354
# Iteration 427 | Cost: 0.149285
# Iteration 428 | Cost: 0.149223
# Iteration 429 | Cost: 0.149164
# Iteration 430 | Cost: 0.149107
# Iteration 431 | Cost: 0.149051
# Iteration 432 | Cost: 0.148998
# Iteration 433 | Cost: 0.148950
# Iteration 434 | Cost: 0.148911
# Iteration 435 | Cost: 0.148886
# Iteration 436 | Cost: 0.148880
# Iteration 437 | Cost: 0.148899
# Iteration 438 | Cost: 0.148944
# Iteration 439 | Cost: 0.149020
# Iteration 440 | Cost: 0.149124
# Iteration 441 | Cost: 0.149255
# Iteration 442 | Cost: 0.149405
# Iteration 443 | Cost: 0.149566
# Iteration 444 | Cost: 0.149730
# Iteration 445 | Cost: 0.149884
# Iteration 446 | Cost: 0.150018
# Iteration 447 | Cost: 0.150123
# Iteration 448 | Cost: 0.150190
# Iteration 449 | Cost: 0.150217
# Iteration 450 | Cost: 0.150201
# Iteration 451 | Cost: 0.150145
# Iteration 452 | Cost: 0.150055
# Iteration 453 | Cost: 0.149938
# Iteration 454 | Cost: 0.149803
# Iteration 455 | Cost: 0.149661
# Iteration 456 | Cost: 0.149522
# Iteration 457 | Cost: 0.149392
# Iteration 458 | Cost: 0.149278
# Iteration 459 | Cost: 0.149184
# Iteration 460 | Cost: 0.149111
# Iteration 461 | Cost: 0.149058
# Iteration 462 | Cost: 0.149023
# Iteration 463 | Cost: 0.149001
# Iteration 464 | Cost: 0.148989
# Iteration 465 | Cost: 0.148982
# Iteration 466 | Cost: 0.148977
# Iteration 467 | Cost: 0.148972
# Iteration 468 | Cost: 0.148965
# Iteration 469 | Cost: 0.148958
# Iteration 470 | Cost: 0.148950
# Iteration 471 | Cost: 0.148945
# Iteration 472 | Cost: 0.148945
# Iteration 473 | Cost: 0.148952
# Iteration 474 | Cost: 0.148970
# Iteration 475 | Cost: 0.148999
# Iteration 476 | Cost: 0.149040
# Iteration 477 | Cost: 0.149092
# Iteration 478 | Cost: 0.149151
# Iteration 479 | Cost: 0.149214
# Iteration 480 | Cost: 0.149274
# Iteration 481 | Cost: 0.149323
# Iteration 482 | Cost: 0.149354
# Iteration 483 | Cost: 0.149362
# Iteration 484 | Cost: 0.149339
# Iteration 485 | Cost: 0.149283
# Iteration 486 | Cost: 0.149192
# Iteration 487 | Cost: 0.149066
# Iteration 488 | Cost: 0.148910
# Iteration 489 | Cost: 0.148729
# Iteration 490 | Cost: 0.148528
# Iteration 491 | Cost: 0.148316
# Iteration 492 | Cost: 0.148100
# Iteration 493 | Cost: 0.147886
# Iteration 494 | Cost: 0.147681
# Iteration 495 | Cost: 0.147488
# Iteration 496 | Cost: 0.147310
# Iteration 497 | Cost: 0.147147
# Iteration 498 | Cost: 0.147000
# Iteration 499 | Cost: 0.146866

# %%
# accuracy SOFTMAX + Linear Kernel 0.8132

# %%
(X_train, y_train, X_val, y_val, X_test, y_test) = prepareFMNISTData()
print("Data Ready")
W_FLDA = np.real(multiClassFLDA(X_train, y_train))
X_train = np.dot(X_train, W_FLDA.T)
X_test = np.dot(X_test, W_FLDA.T)

X_train = X_train[:1000,:]
y_train = y_train[:1000]
X_test = X_test[:400,:]
y_test = y_test[:400]

numClasses = 10
numFeatures = X_train.shape[1]
y_pred = []


print("Data Ready")
for index in range(numClasses):    

    y_train_index = (y_train==index)*2 - 1
    y_test_index = (y_test == index)*2 - 1

    clf = SVM(kernel = linear_kernel, C = 1)
    clf.fit(X_train, y_train_index)
    y_pred_index = clf.predict(X_test)
    y_pred.append(y_pred_index)
            
y_pred = np.array(y_pred).T
# Out:
# Data Ready
# Data Ready
#      pcost       dcost       gap    pres   dres
#  0: -1.4094e+02 -2.0778e+03  1e+04  3e+00  5e-11
#  1: -9.3583e+01 -1.1493e+03  2e+03  3e-01  4e-11
#  2: -7.8609e+01 -3.0876e+02  3e+02  5e-02  3e-11
#  3: -7.8191e+01 -1.9945e+02  2e+02  2e-02  3e-11
#  4: -8.0328e+01 -1.3258e+02  6e+01  8e-03  3e-11
#  5: -8.1873e+01 -1.1132e+02  3e+01  3e-03  3e-11
#  6: -8.3062e+01 -1.0594e+02  3e+01  2e-03  3e-11
#  7: -8.3730e+01 -9.9697e+01  2e+01  5e-04  3e-11
#  8: -8.5510e+01 -9.6151e+01  1e+01  3e-04  3e-11
#  9: -8.6561e+01 -9.3713e+01  7e+00  1e-04  4e-11
# 10: -8.7165e+01 -9.2332e+01  5e+00  7e-05  4e-11
# 11: -8.7838e+01 -9.1119e+01  3e+00  4e-05  4e-11
# 12: -8.8351e+01 -8.9917e+01  2e+00  3e-06  5e-11
# 13: -8.8720e+01 -8.9454e+01  7e-01  6e-07  4e-11
# 14: -8.8948e+01 -8.9175e+01  2e-01  1e-07  4e-11
# 15: -8.9049e+01 -8.9063e+01  1e-02  6e-09  4e-11
# 16: -8.9054e+01 -8.9058e+01  3e-03  1e-09  4e-11
# 17: -8.9056e+01 -8.9056e+01  5e-05  1e-11  4e-11
# Optimal solution found.
# 93 support vectors out of 1000 points
# -1.3661395456991134
#      pcost       dcost       gap    pres   dres
#  0: -3.5750e+01 -2.3939e+03  2e+04  3e+00  4e-11
#  1: -2.0747e+01 -1.3297e+03  2e+03  3e-01  4e-11
#  2: -1.0590e+01 -2.2622e+02  3e+02  4e-02  2e-11
#  3: -7.3873e+00 -8.7911e+01  1e+02  1e-02  1e-11
#  4: -6.6744e+00 -4.3617e+01  5e+01  6e-03  9e-12
#  5: -6.1906e+00 -3.6862e+01  4e+01  4e-03  1e-11
#  6: -6.1310e+00 -2.2958e+01  2e+01  2e-03  8e-12
#  7: -6.0496e+00 -1.8055e+01  2e+01  1e-03  8e-12
#  8: -5.9316e+00 -1.6683e+01  2e+01  1e-03  8e-12
#  9: -5.6008e+00 -1.4618e+01  1e+01  8e-04  7e-12
# 10: -5.3137e+00 -1.3099e+01  1e+01  6e-04  7e-12
# 11: -5.0379e+00 -7.9893e+00  4e+00  1e-04  8e-12
# 12: -5.1563e+00 -6.5831e+00  2e+00  2e-05  7e-12
# 13: -5.4042e+00 -6.0696e+00  7e-01  6e-06  7e-12
# 14: -5.4678e+00 -5.9074e+00  5e-01  2e-06  8e-12
# 15: -5.6232e+00 -5.6824e+00  6e-02  2e-07  7e-12
# 16: -5.6284e+00 -5.6717e+00  4e-02  2e-07  7e-12
# 17: -5.6308e+00 -5.6659e+00  4e-02  7e-08  8e-12
# 18: -5.6437e+00 -5.6493e+00  6e-03  2e-10  9e-12
# 19: -5.6463e+00 -5.6464e+00  2e-04  5e-12  8e-12
# 20: -5.6463e+00 -5.6463e+00  2e-06  5e-14  1e-11
# Optimal solution found.
# 13 support vectors out of 1000 points
# -3.76933786098593
#      pcost       dcost       gap    pres   dres
#  0: -2.1996e+02 -2.3111e+03  1e+04  3e+00  5e-11
#  1: -1.4796e+02 -1.3882e+03  2e+03  4e-01  4e-11
#  2: -1.3334e+02 -3.6737e+02  3e+02  4e-02  3e-11
#  3: -1.4106e+02 -2.5425e+02  1e+02  1e-02  3e-11
#  4: -1.4519e+02 -2.1979e+02  9e+01  8e-03  3e-11
#  5: -1.4861e+02 -1.9986e+02  6e+01  5e-03  3e-11
#  6: -1.5236e+02 -1.8095e+02  3e+01  2e-03  3e-11
#  7: -1.5283e+02 -1.7631e+02  2e+01  8e-04  4e-11
#  8: -1.5475e+02 -1.6942e+02  2e+01  4e-04  4e-11
#  9: -1.5546e+02 -1.6824e+02  1e+01  3e-04  3e-11
# 10: -1.5685e+02 -1.6494e+02  8e+00  1e-04  4e-11
# 11: -1.5702e+02 -1.6444e+02  8e+00  1e-04  4e-11
# 12: -1.5805e+02 -1.6222e+02  4e+00  1e-05  4e-11
# 13: -1.5824e+02 -1.6181e+02  4e+00  9e-06  4e-11
# 14: -1.5854e+02 -1.6128e+02  3e+00  5e-06  4e-11
# 15: -1.5869e+02 -1.6104e+02  2e+00  3e-06  4e-11
# 16: -1.5884e+02 -1.6083e+02  2e+00  2e-06  3e-11
# 17: -1.5926e+02 -1.6028e+02  1e+00  1e-06  4e-11
# 18: -1.5947e+02 -1.6001e+02  5e-01  4e-07  4e-11
# 19: -1.5965e+02 -1.5978e+02  1e-01  7e-08  5e-11
# 20: -1.5970e+02 -1.5972e+02  2e-02  8e-09  4e-11
# 21: -1.5971e+02 -1.5971e+02  4e-04  2e-10  5e-11
# 22: -1.5971e+02 -1.5971e+02  4e-06  2e-12  4e-11
# Optimal solution found.
# 165 support vectors out of 1000 points
# -1.170554324982695
#      pcost       dcost       gap    pres   dres
#  0: -1.2001e+02 -1.9501e+03  1e+04  3e+00  4e-11
#  1: -7.9022e+01 -1.0620e+03  2e+03  3e-01  3e-11
#  2: -6.1452e+01 -3.3796e+02  5e+02  8e-02  2e-11
#  3: -5.5115e+01 -1.5018e+02  1e+02  2e-02  2e-11
#  4: -5.3525e+01 -1.0017e+02  6e+01  8e-03  2e-11
#  5: -5.4401e+01 -8.0229e+01  3e+01  3e-03  2e-11
#  6: -5.6094e+01 -7.0051e+01  2e+01  9e-04  2e-11
#  7: -5.6305e+01 -6.7487e+01  1e+01  3e-04  2e-11
#  8: -5.7477e+01 -6.4991e+01  8e+00  2e-04  2e-11
#  9: -5.8072e+01 -6.2994e+01  5e+00  2e-05  3e-11
# 10: -5.8687e+01 -6.1993e+01  3e+00  8e-06  3e-11
# 11: -5.9418e+01 -6.0871e+01  1e+00  4e-16  3e-11
# 12: -6.0063e+01 -6.0146e+01  8e-02  6e-15  3e-11
# 13: -6.0091e+01 -6.0113e+01  2e-02  8e-15  3e-11
# 14: -6.0100e+01 -6.0104e+01  4e-03  4e-15  2e-11
# 15: -6.0101e+01 -6.0102e+01  1e-03  1e-14  2e-11
# 16: -6.0101e+01 -6.0101e+01  1e-05  1e-14  3e-11
# Optimal solution found.
# 64 support vectors out of 1000 points
# -1.559625463465113
#      pcost       dcost       gap    pres   dres
#  0: -1.9577e+02 -2.2638e+03  1e+04  3e+00  5e-11
#  1: -1.3131e+02 -1.3407e+03  2e+03  3e-01  4e-11
#  2: -1.1504e+02 -3.4351e+02  3e+02  4e-02  3e-11
#  3: -1.2049e+02 -2.0848e+02  1e+02  1e-02  3e-11
#  4: -1.2269e+02 -1.8058e+02  7e+01  5e-03  4e-11
#  5: -1.2562e+02 -1.6737e+02  5e+01  3e-03  3e-11
#  6: -1.2889e+02 -1.5277e+02  3e+01  1e-03  4e-11
#  7: -1.2956e+02 -1.5074e+02  2e+01  9e-04  4e-11
#  8: -1.3133e+02 -1.4450e+02  1e+01  5e-04  4e-11
#  9: -1.3177e+02 -1.4388e+02  1e+01  3e-04  4e-11
# 10: -1.3200e+02 -1.4257e+02  1e+01  2e-04  4e-11
# 11: -1.3292e+02 -1.4068e+02  8e+00  1e-04  4e-11
# 12: -1.3360e+02 -1.3887e+02  5e+00  6e-05  4e-11
# 13: -1.3388e+02 -1.3813e+02  4e+00  3e-05  4e-11
# 14: -1.3413e+02 -1.3780e+02  4e+00  2e-05  4e-11
# 15: -1.3501e+02 -1.3653e+02  2e+00  4e-06  4e-11
# 16: -1.3549e+02 -1.3591e+02  4e-01  1e-06  4e-11
# 17: -1.3557e+02 -1.3581e+02  2e-01  4e-07  4e-11
# 18: -1.3557e+02 -1.3581e+02  2e-01  3e-07  4e-11
# 19: -1.3558e+02 -1.3579e+02  2e-01  1e-07  4e-11
# 20: -1.3561e+02 -1.3576e+02  2e-01  8e-08  4e-11
# 21: -1.3560e+02 -1.3576e+02  2e-01  6e-08  4e-11
# 22: -1.3567e+02 -1.3568e+02  7e-03  2e-09  5e-11
# 23: -1.3568e+02 -1.3568e+02  2e-03  3e-10  4e-11
# 24: -1.3568e+02 -1.3568e+02  6e-05  7e-12  5e-11
# Optimal solution found.
# 143 support vectors out of 1000 points
# -2.2712121982266407
#      pcost       dcost       gap    pres   dres
#  0: -1.6187e+02 -2.1595e+03  1e+04  3e+00  5e-11
#  1: -1.0377e+02 -1.2423e+03  2e+03  3e-01  4e-11
#  2: -7.7707e+01 -3.3266e+02  4e+02  6e-02  2e-11
#  3: -7.3208e+01 -1.3990e+02  9e+01  1e-02  2e-11
#  4: -7.4189e+01 -1.1376e+02  5e+01  6e-03  1e-11
#  5: -7.5931e+01 -9.6717e+01  2e+01  2e-03  2e-11
#  6: -7.7179e+01 -9.0783e+01  2e+01  1e-03  2e-11
#  7: -7.8229e+01 -8.6986e+01  9e+00  5e-04  2e-11
#  8: -7.8996e+01 -8.4796e+01  6e+00  3e-04  2e-11
#  9: -7.9463e+01 -8.3171e+01  4e+00  9e-05  2e-11
# 10: -8.0017e+01 -8.2270e+01  2e+00  5e-05  2e-11
# 11: -8.0409e+01 -8.1542e+01  1e+00  1e-05  2e-11
# 12: -8.0647e+01 -8.1188e+01  5e-01  3e-06  2e-11
# 13: -8.0848e+01 -8.0950e+01  1e-01  3e-07  2e-11
# 14: -8.0895e+01 -8.0899e+01  3e-03  1e-08  2e-11
# 15: -8.0897e+01 -8.0897e+01  4e-05  1e-10  2e-11
# Optimal solution found.
# 85 support vectors out of 1000 points
# 0.047700105000513165
#      pcost       dcost       gap    pres   dres
#  0: -2.3211e+02 -2.2512e+03  1e+04  3e+00  6e-11
#  1: -1.5501e+02 -1.3403e+03  2e+03  3e-01  4e-11
#  2: -1.4056e+02 -3.8746e+02  3e+02  4e-02  3e-11
#  3: -1.4700e+02 -2.7526e+02  2e+02  2e-02  3e-11
#  4: -1.5314e+02 -2.1792e+02  7e+01  7e-03  3e-11
#  5: -1.5586e+02 -2.0483e+02  5e+01  4e-03  3e-11
#  6: -1.5889e+02 -1.8990e+02  3e+01  2e-03  3e-11
#  7: -1.6107e+02 -1.8295e+02  2e+01  1e-03  3e-11
#  8: -1.6279e+02 -1.7854e+02  2e+01  7e-04  3e-11
#  9: -1.6371e+02 -1.7579e+02  1e+01  4e-04  3e-11
# 10: -1.6400e+02 -1.7214e+02  8e+00  1e-14  4e-11
# 11: -1.6455e+02 -1.7147e+02  7e+00  2e-14  3e-11
# 12: -1.6608e+02 -1.6934e+02  3e+00  2e-14  4e-11
# 13: -1.6691e+02 -1.6824e+02  1e+00  9e-15  4e-11
# 14: -1.6695e+02 -1.6815e+02  1e+00  9e-15  4e-11
# 15: -1.6738e+02 -1.6763e+02  3e-01  1e-14  4e-11
# 16: -1.6741e+02 -1.6759e+02  2e-01  1e-14  4e-11
# 17: -1.6746e+02 -1.6753e+02  7e-02  6e-15  4e-11
# 18: -1.6749e+02 -1.6750e+02  1e-02  2e-15  4e-11
# 19: -1.6749e+02 -1.6749e+02  1e-04  3e-15  4e-11
# Optimal solution found.
# 172 support vectors out of 1000 points
# -0.9512492699089738
#      pcost       dcost       gap    pres   dres
#  0: -1.0054e+02 -2.0436e+03  1e+04  3e+00  3e-11
#  1: -6.6524e+01 -1.1199e+03  2e+03  3e-01  2e-11
#  2: -5.2134e+01 -2.6892e+02  3e+02  5e-02  2e-11
#  3: -4.9905e+01 -1.0698e+02  8e+01  1e-02  2e-11
#  4: -5.1293e+01 -8.5793e+01  5e+01  6e-03  2e-11
#  5: -5.1485e+01 -7.5983e+01  3e+01  3e-03  2e-11
#  6: -5.1862e+01 -7.0788e+01  2e+01  2e-03  1e-11
#  7: -5.3470e+01 -6.3542e+01  1e+01  6e-04  2e-11
#  8: -5.3350e+01 -6.2866e+01  1e+01  5e-04  2e-11
#  9: -5.3972e+01 -6.0697e+01  7e+00  2e-04  2e-11
# 10: -5.4277e+01 -5.9472e+01  5e+00  1e-04  1e-11
# 11: -5.4529e+01 -5.8824e+01  4e+00  1e-04  2e-11
# 12: -5.5238e+01 -5.7405e+01  2e+00  4e-05  2e-11
# 13: -5.5655e+01 -5.6671e+01  1e+00  9e-06  2e-11
# 14: -5.5881e+01 -5.6344e+01  5e-01  4e-06  2e-11
# 15: -5.5910e+01 -5.6300e+01  4e-01  3e-06  2e-11
# 16: -5.5930e+01 -5.6222e+01  3e-01  6e-15  2e-11
# 17: -5.5989e+01 -5.6161e+01  2e-01  5e-16  2e-11
# 18: -5.6032e+01 -5.6115e+01  8e-02  4e-15  2e-11
# 19: -5.6071e+01 -5.6074e+01  4e-03  7e-15  2e-11
# 20: -5.6073e+01 -5.6073e+01  4e-05  6e-15  2e-11
# Optimal solution found.
# 63 support vectors out of 1000 points
# -2.2651575213926667
#      pcost       dcost       gap    pres   dres
#  0: -8.7082e+01 -2.1094e+03  1e+04  3e+00  4e-11
#  1: -5.5009e+01 -1.1728e+03  2e+03  3e-01  3e-11
#  2: -3.9088e+01 -2.9847e+02  4e+02  6e-02  2e-11
#  3: -3.3921e+01 -1.7302e+02  2e+02  3e-02  1e-11
#  4: -3.1334e+01 -1.1695e+02  1e+02  2e-02  1e-11
#  5: -3.0899e+01 -7.5580e+01  6e+01  7e-03  1e-11
#  6: -3.1023e+01 -4.6128e+01  2e+01  1e-03  1e-11
#  7: -3.1514e+01 -4.1149e+01  1e+01  6e-04  1e-11
#  8: -3.2289e+01 -3.7468e+01  6e+00  2e-04  1e-11
#  9: -3.2973e+01 -3.5611e+01  3e+00  6e-05  1e-11
# 10: -3.3317e+01 -3.4925e+01  2e+00  2e-05  1e-11
# 11: -3.3835e+01 -3.4221e+01  4e-01  1e-06  1e-11
# 12: -3.3959e+01 -3.4079e+01  1e-01  4e-07  1e-11
# 13: -3.3961e+01 -3.4072e+01  1e-01  3e-07  1e-11
# 14: -3.3967e+01 -3.4068e+01  1e-01  2e-07  1e-11
# 15: -3.3980e+01 -3.4052e+01  7e-02  6e-08  1e-11
# 16: -3.3981e+01 -3.4048e+01  7e-02  5e-08  1e-11
# 17: -3.4010e+01 -3.4018e+01  8e-03  4e-15  2e-11
# 18: -3.4014e+01 -3.4014e+01  8e-05  7e-15  1e-11
# 19: -3.4014e+01 -3.4014e+01  8e-07  6e-15  2e-11
# Optimal solution found.
# 37 support vectors out of 1000 points
# -2.7961166250962566
#      pcost       dcost       gap    pres   dres
#  0: -7.0845e+01 -2.0224e+03  1e+04  3e+00  3e-11
#  1: -4.6153e+01 -1.0689e+03  2e+03  3e-01  2e-11
#  2: -3.4034e+01 -1.9478e+02  2e+02  4e-02  2e-11
#  3: -3.1533e+01 -1.1427e+02  1e+02  2e-02  1e-11
#  4: -2.9652e+01 -9.1720e+01  1e+02  1e-02  1e-11
#  5: -2.7380e+01 -8.1648e+01  8e+01  9e-03  1e-11
#  6: -2.5781e+01 -7.3999e+01  7e+01  7e-03  1e-11
#  7: -2.5317e+01 -5.1903e+01  4e+01  3e-03  1e-11
#  8: -2.5331e+01 -3.9162e+01  2e+01  1e-03  1e-11
#  9: -2.5357e+01 -3.5117e+01  1e+01  6e-04  1e-11
# 10: -2.5919e+01 -3.1132e+01  6e+00  3e-04  1e-11
# 11: -2.5994e+01 -3.0658e+01  5e+00  1e-04  1e-11
# 12: -2.5852e+01 -3.0482e+01  5e+00  1e-04  1e-11
# 13: -2.5992e+01 -2.9365e+01  3e+00  3e-05  1e-11
# 14: -2.6688e+01 -2.8248e+01  2e+00  1e-05  1e-11
# 15: -2.6860e+01 -2.7951e+01  1e+00  5e-06  1e-11
# 16: -2.6984e+01 -2.7781e+01  8e-01  3e-06  1e-11
# 17: -2.7000e+01 -2.7745e+01  8e-01  2e-06  1e-11
# 18: -2.7259e+01 -2.7429e+01  2e-01  5e-08  2e-11
# 19: -2.7337e+01 -2.7345e+01  9e-03  2e-09  2e-11
# 20: -2.7341e+01 -2.7341e+01  9e-05  2e-11  2e-11
# 21: -2.7341e+01 -2.7341e+01  9e-07  2e-13  2e-11
# Optimal solution found.
# 34 support vectors out of 1000 points
# -5.80144411804741

# %% [markdown]
# # River Data Regression
#     - Have to estimate y for each x, a regression Task
#
#    ## Data
#        - y vs x
#        - Very clean scatter, no visible noise!!
#        - Graph has 3 extremas and goes to infinite of small/large x
#        - Might be generated using a 4th degree polynomial
#
#    ## Ideas
#         - Linear Regression: Use a 4th degree polynomial Kernel
#             - Optimize using gradient descent
#             - Solve using the Normal Formula
#             - Find 4th degree Lagrange interpolating polynomial

# %%
def prepareRiverData():
    riverData = pd.read_csv("updatedRiverData.csv")
    X = np.array([riverData.values[:,0]]).T
    y = riverData.values[:,1]
    
    n = X.shape[0]
    np.random.seed(42)
    indices = np.random.permutation(n)
    trainingIndex = indices[:int(5*n/6)]
    testIndex = indices[int(5*n/6):]

    X_train = X[trainingIndex]
    y_train = y[trainingIndex]
    X_test = X[testIndex]
    y_test = y[testIndex]
    
    return (X_train, y_train, X_test, y_test)

def gradientDescent(x, y, W, alpha = 0.0001, numIterations=1000000, tol = 1e-6, verbose = False, lam= 0, beta = 0):
    m = x.shape[0]
    print("No. of Training Samples ", m)
    J_hist = []
    v = np.zeros(W.shape)
    for i in range(0, numIterations):
        hypothesis = np.dot(x, W)
        loss = hypothesis - y
        cost = np.sum(loss ** 2) / (2 * m)
        J_hist.append(cost)            

        if(i>10 and np.abs(J_hist[i]-J_hist[i-5])<tol): break

        gradient = np.dot(x.transpose(), loss) / m #gradient
        v = beta*v + alpha*gradient
        W = W - v

        if(verbose): 
            print("Iteration %d | Cost: %f" % (i, cost))
            #print("Weights: ", W)
            #print("Gradient: ", gradient)
            #print("Momentum: ", v)
        

    return (W, J_hist)
    
def polynomialKernel(X, n):
    poly = np.hstack((np.ones((X.shape[0],1)),X))
    for i in range(2,n+1):
        poly = np.hstack((poly, np.float_power(X,i)))
    return poly

def MSE(y_pred, y):
    m = y_pred.shape[0]
    loss = y_pred - y
    cost = np.sum(loss ** 2) / (2 * m)
    return cost
    
def MAE(y_pred, y):
    m = y_pred.shape[0]
    loss = y_pred - y
    cost = np.sum(np.abs(loss)) / (2 * m)
    return cost

# %% [markdown]
# ### Data looks like Polynomial + Noise
# - We can try to seperate the two components, and analyse in greater detail

# %%
# %matplotlib inline
#4th degree polynomial fit
(X_train, y_train, X_test, y_test) = prepareRiverData()

e = 1
y_mean = [np.mean(y_train[np.where([abs(X_train-x)<=e])[1]]) for x in X_train.flatten()]
y_noises = [y_train[np.where([abs(X_train-x)<=e])[1]] - np.mean(y_train[np.where([abs(X_train-x)<=e])[1]]) for x in X_train.flatten()]
y_noise = y_train - y_mean

plt.scatter(X_train, y_train, label = 'Data')
plt.scatter(X_train, y_mean, label = 'Means')
plt.title("Data with approximated means")
plt.legend()

# %%
fig = plt.hist(y_noises[5], color = 'blue', edgecolor = 'black', bins = int(10), histtype = 'stepfilled', density = True)
plt.show()
means = [np.mean(y_noises[i]) for i in range(len(y_noises))]
variances = [np.std(y_noises[i]) for i in range(len(y_noises))]
plt.scatter(X_train, means, label = 'Mean of Noise')
plt.scatter(X_train, variances, label = 'Standard Deviation of Noise' )
plt.title('Visualization of noise, for each x')
plt.legend()

# %% [markdown]
# # Noise
#     - The individual noise elements corresponding to each x are also normals, with approximately the same standard deviation (around 5).
#     - A logical extension would be the assumption that the noise is independent of x, and by doing so, we can find a common sigma for the general noise

# %%
fig = plt.hist(y_noise, color = 'blue', edgecolor = 'black', bins = int(100), histtype = 'stepfilled', density = True)
plt.title('Overall Noise')
print("Noise has variance = ", np.var(y_noise))
print("Noise has mean = ", np.mean(y_noise))
# Out:
# Noise has variance =  25.25341859689801
# Noise has mean =  0.005267226211603027

# %%
fig = plt.hist(y_noise, color = 'blue', edgecolor = 'black', bins = int(100), histtype = 'stepfilled', density = True)
print("Mean is ", np.mean(y_noise))
print("Mean is ", np.mean(y_noise))
# Out:
# Mean is  0.005267226211603027
# Mean is  0.005267226211603027

# %% [markdown]
# # Gradient Descent
#     - Progressively try polynomial kernels (linear, quad, tri, tetra)
#     - Instead of random initialization, use weight n'th polynomial as initialization for n+1'th polynomial

# %%
(X_train, y_train, X_test, y_test) = prepareRiverData()
X_train_linear = polynomialKernel(X_train,1)

W  = np.zeros(X_train_linear.shape[1], dtype = float)
(W1,J_hist) = gradientDescent(X_train_linear, y_train, W, alpha=0.0001, numIterations=10000, beta=0.95, tol = 1e-4)
# Out:
# No. of Training Samples  8333

# %%
y_pred = np.dot(W1, X_train_linear.T)
plt.scatter(X_train, y_train)
plt.scatter(X_train, y_pred)

# %%
(X_train, y_train, X_test, y_test) = prepareRiverData()
X_train_quad = polynomialKernel(X_train,2)

W1 = np.hstack((W1,0))
(W2,J_hist) = gradientDescent(X_train_quad, y_train, W1, alpha=0.00000001, numIterations=10000, beta=0.999, tol = 1e-10, verbose = False)
# Out:
# No. of Training Samples  8333

# %%
y_pred = np.dot(W2, X_train_quad.T)

plt.scatter(X_train, y_train)
plt.scatter(X_train, y_pred)
plt.grid(True)

# %%
(X_train, y_train, X_test, y_test) = prepareRiverData()
X_train_tri = polynomialKernel(X_train,3)

W2 = np.hstack((W2,0))
(W3,J_hist) = gradientDescent(X_train_tri, y_train, W2, alpha=0.000000000007, numIterations=10000, beta=0.9977, tol = 1e-10, verbose = False)
# Out:
# No. of Training Samples  8333

# %%
y_pred = np.dot(W3, X_train_tri.T)

plt.scatter(X_train, y_train)
plt.scatter(X_train, y_pred)
plt.grid(True)

#Stuck in a local optima

# %%
(X_train, y_train, X_test, y_test) = prepareRiverData()
X_train_tetra = polynomialKernel(X_train,4)

W3 = np.hstack((W3,0))
(W4,J_hist) = gradientDescent(X_train_tetra, y_train, W3, alpha=0.0000000000000007, numIterations=10000, beta=0.99, tol = 1e-10, verbose = False)
# Out:
# No. of Training Samples  8333

# %%
y_pred = np.dot(W4, X_train_tetra.T)
plt.scatter(X_train, y_train)
plt.scatter(X_train, y_pred)

# %% [markdown]
# ### Gradient Descent Fails
#     - Gradient descent gets stuck at local optima when trained this way
#     - Need ways to get around this. Thinking still.
#
# ### Lagrange Interpolation
#     - Fit a 4th degree polynomial on data
#     - How to choose 5 good points?
#     - Try fitting higher degree polynomial just in case

# %%
#4th degree polynomial fit
(X_train, y_train, X_test, y_test) = prepareRiverData()
xList = [0,25,50,75,100]
e = 0.5


yList = [np.mean(y_train[np.where([abs(X_train-x)<=e])[1]]) for x in xList]

from scipy.interpolate import lagrange
poly = lagrange(xList,yList)
W_lagrange = np.flip(poly.c)


X_train_tetra = polynomialKernel(X_train,4)
y_pred = np.dot(W_lagrange, X_train_tetra.T)
plt.scatter(X_train, y_train, alpha = 1, marker= ',', label = 'Given Data')
plt.scatter(X_train, y_pred, alpha = 1, marker = '.', label = 'Lagrange Interpolation Polynomial')
plt.title('Lagrange Interpolation on River Data')
plt.legend()
plt.xlabel('Distance (in Metres)')
plt.ylabel('Oxygen Levels (in Kg/m3)')
plt.grid(True)


#TEST
X_test_tetra = polynomialKernel(X_test, 4)
y_pred = np.dot(W_lagrange, X_test_tetra.T)
print("Mean Squared Error on Test Data = ", MSE(y_pred, y_test))
print("Mean Absolute Error on Test Data = ", MAE(y_pred, y_test))
print("Weights are ", W_lagrange)
# Out:
# Mean Squared Error on Test Data =  12.933656418124013
# Mean Absolute Error on Test Data =  2.012105605851383
# Weights are  [ 4.99540090e+01 -3.82654303e+00  1.50018531e-01 -2.15636675e-03
#   1.03037796e-05]

# %% [markdown]
# # Gradient Descent Graphing
#     - Can show presence of local optima by starting optimizations randomly, and looking at convergence to different losses

# %%
(X_train, y_train, X_test, y_test) = prepareRiverData()
X_train_quad = polynomialKernel(X_train,2)

W1a = W1
(W2a,J_hist1) = gradientDescent(X_train_quad, y_train, W1a, alpha=0.00000001, numIterations=20000, beta=0.999, tol = 1e-10, verbose = False)

W1b = np.zeros(W1.shape)
(W2b,J_hist2) = gradientDescent(X_train_quad, y_train, W1b, alpha=0.00000001, numIterations=20000, beta=0.999, tol = 1e-10, verbose = False)

W1c = W1/2
(W2c,J_hist3) = gradientDescent(X_train_quad, y_train, W1c, alpha=0.00000001, numIterations=20000, beta=0.999, tol = 1e-10, verbose = False)

W1d = W1/3
(W2d,J_hist4) = gradientDescent(X_train_quad, y_train, W1d, alpha=0.00000001, numIterations=20000, beta=0.999, tol = 1e-10, verbose = False)

W1e = W1/4
(W2e,J_hist5) = gradientDescent(X_train_quad, y_train, W1e, alpha=0.00000001, numIterations=20000, beta=0.999, tol = 1e-10, verbose = False)

W1f = -W1/5
(W2f,J_hist6) = gradientDescent(X_train_quad, y_train, W1f, alpha=0.00000001, numIterations=20000, beta=0.999, tol = 1e-10, verbose = False)

W1g = W1*-1
(W2g,J_hist7) = gradientDescent(X_train_quad, y_train, W1g, alpha=0.00000001, numIterations=20000, beta=0.999, tol = 1e-10, verbose = False)
# Out:
# No. of Training Samples  8333
# No. of Training Samples  8333
# No. of Training Samples  8333
# No. of Training Samples  8333
# No. of Training Samples  8333
# No. of Training Samples  8333
# No. of Training Samples  8333

# %%
plt.plot(J_hist1, label = '1st Initilization')
plt.plot(J_hist2, label = '2nd Initialization')
plt.plot(J_hist3, label = '3rd Initialization')
plt.plot(J_hist4, label = '4th Initialization')
plt.plot(J_hist5, label = '5th Initialization')
plt.plot(J_hist6, label = '6th Initialization')
plt.plot(J_hist7, label = '7th Initialization')
plt.title('Gradient Descent on different initializations')
plt.xlabel('Iterations')
plt.ylabel('MSE loss')
plt.legend()
plt.yscale('log')

# %% [markdown]
# # Normal Formula

# %%
(X_train, y_train, X_test, y_test) = prepareRiverData()
X_train_tetra = polynomialKernel(X_train,4)
X_test_tetra = polynomialKernel(X_test,4)

W_normal = np.matmul(np.matmul(np.linalg.inv(np.matmul(X_train_tetra.T, X_train_tetra)),X_train_tetra.T), y_train)

y_pred = np.dot(W_normal, X_test_tetra.T)
print("Mean Squared Error (Test) on applying Normal Formula: ", MSE(y_pred, y_test))
print("Mean Absolute Error (Test) on applying Normal Formula: ", MAE(y_pred, y_test))
print("Weights are ", W_normal)
# Out:
# Mean Squared Error (Test) on applying Normal Formula:  12.7157174904493
# Mean Absolute Error (Test) on applying Normal Formula:  1.9982615359745992
# Weights are  [ 5.11169939e+01 -3.79792375e+00  1.45849979e-01 -2.07744283e-03
#   9.88769349e-06]

# %%
plt.scatter(X_train, y_train, alpha = 1, marker= ',', label = 'Given Data')
plt.scatter(X_train, np.dot(W_normal, X_train_tetra.T), alpha = 1, marker = '.', label = 'Normal Formula found Polynomial')
plt.scatter(X_train, np.dot(W_lagrange, X_train_tetra.T), alpha = 1, marker = '.', label = 'Lagrange Interpolation Polynomial')
plt.title('Normal Formula to solve OLS on River Data')
plt.legend()
plt.xlabel('Distance (in Metres)')
plt.ylabel('Oxygen Levels (in Kg/m3)')
# Out:
# Text(0, 0.5, 'Oxygen Levels (in Kg/m3)')
